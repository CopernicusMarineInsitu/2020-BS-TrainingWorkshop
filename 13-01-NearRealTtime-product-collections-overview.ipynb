# %% [markdown]
# ![header](https://i.imgur.com/I4ake6d.jpg)

# %% [markdown]
# # IN SITU BLACK SEA TRAINING

# %% [markdown]
# <div style="text-align: right"><i> 13-01-Part-one-out-of-five </i></div>

# %% [markdown]
# ***
# # An overview of  the BS `NRT` product/dataset

# %% [markdown]
# ***
# **General Note 1**: Execute each cell through the <button class="btn btn-default btn-xs"><i class="icon-play fa fa-play"></i></button> button from the top MENU (or keyboard shortcut `Shift` + `Enter`).<br>
# <br>
# **General Note 2**: If, for any reason, the kernel is not working anymore, in the top MENU, click on the <button class="btn btn-default btn-xs"><i class="fa fa-repeat icon-repeat"></i></button> button. Then, in the top MENU, click on "Cell" and select "Run All Above Selected Cell".<br>
# ***

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc">
#     <ul class="toc-item">
#         <li><span><a href="#1.-Introduction" data-toc-modified-id="1.-Introduction">1. Introduction</a></span></li>
#         <li>
#             <span><a href="#2.-Setup" data-toc-modified-id="2.-Setup">2. Setup</a></span>
#             <ul>
#                 <li><span><a href="#2.1.-Python-packages" data-toc-modified-id="2.1.-Python-packages">2.1. Python packages</a></span></li>
#                 <li><span><a href="#2.2.-Copernicus-Database" data-toc-modified-id="2.2.-Copernicus-Database">2.2. Copernicus database</a></span></li>
#                 <li><span><a href="#2.3.-Auxiliary-functions" data-toc-modified-id="2.3-Setup">2.2. Auxiliary functions</a></span></li>
#             </ul>
#         </li>
#         <li>
#             <span><a href="#3.-COLLECTION-OVERVIEW" data-toc-modified-id="3.-COLLECTION-OVERVIEW">3. Collection overview</a></span>
#             <ul>
#                 <li><span><a href="#3.1.-Getting-started" data-toc-modified-id="3.1.-Getting-started-packages">3.1. Getting started</a></span></li>
#                 <li><span><a href="#3.2.-Choosing-collection" data-toc-modified-id="3.2.-Chosing-collection">3.2. Choosing collection</a></span></li>
#                 <li>
#                     <span><a href="#3.3.-Overview" data-toc-modified-id="3.3.-Overview">3.3. Overview</a></span>
#                     <ul>
#                 <li><span><a href="#3.3.1.-Platforms" data-toc-modified-id="3.3.1.-Platforms">3.3.1. Platforms</a></span></li>
#                 <li><span><a href="#3.3.2.-Source-types" data-toc-modified-id="3.3.2.-Source-types">3.3.2. Source types (data types)</a></span></li>
#                 <li><span><a href="#3.3.3.-Feature-types" data-toc-modified-id="3.3.3.-Feature-types">3.3.3. Feature (file types)</a></span></li>
#                 <li><span><a href="#3.3.4.-Parameters" data-toc-modified-id="3.3.4.-Parameters">3.3.4. Parameters</a></span></li>
#                 <li><span><a href="#3.3.5.-Providers" data-toc-modified-id="3.3.5.-Providers">3.3.5. Providers</a></span></li>
#             </ul>
#                 </li>
#             </ul>
#         </li>
#         <li><span><a href="#4.-Wrap-up" data-toc-modified-id="4.-Wrap-up">4. Wrap-up</a></span></li>
#         <li><span><a href="#5.-Next-tutorial" data-toc-modified-id="5.-Next-tutorial">5. Next tutorial</a></span></li>
#     </ul>
# </div>

# %% [markdown]
# ***

# %% [markdown]
# ## 1. Introduction
#
# This notebook focus on getting an overview of the files available in the different collections (`latest`, `monthly` and `history`) available within the In Situ Near Real Time product/dataset covering the Black Sea: `INSITU_BS_NRT_OBSERVATIONS_013_034`. Click [here](https://resources.marine.copernicus.eu/?option=com_csw&task=results?option=com_csw&view=details&product_id=INSITU_BS_NRT_OBSERVATIONS_013_034) to  view the dedicated section of this product within the [CMEMS Catalog](http://marine.copernicus.eu/services-portfolio/access-to-products/).

# %% [markdown]
# Any In Situ NRT product/dataset is just a bunch of netcdf files produced by the platforms (*drifters, profilers, gliders, moorings, HF-radars, vessels etc*) deployed in a certain seas (in this case, the Black Sea); so many files that navigation/subsetting can be challenging.

# %% [markdown]
# | ![BS.gif](img/BS.gif)|
# |:--:|
# | *GIF of the location (point or trajectory) of the platforms providing near real time data in the BS area since 1922* |

# %% [markdown]
# To smooth the process of data discovery to users, the In Situ TAC provides a set of `index files` that describe the aforementioned file collections. In addition to these index files, it is also possible to find further info regarding each platform contributting with files on the `index_platform.txt`.

# %% [markdown]
# | Index |  Description |
# | ------- | ----------- |
# | `index_latest.txt`  |  List of available files within the latest collection + metadata |
# | `index_monthly.txt`   | List of available files within the monthly collection + metadata |
# | `index_history.txt`   |  List of available files within the history collection + metadata |
# | `index_platform.txt`   | Full list of platforms + metadata |

# %% [markdown]
# Check more about these files in the <a href="https://archimer.ifremer.fr/doc/00324/43494/" target="_blank">Product User Manual</a>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>OBJECTIVE</b>
#
# ***
# To discover which platforms, file types, data types, parameters and providers are to be expected in a specific collection of the BS NRT product/dataset by using the aforementioned index files.

# %% [markdown]
# ## 2. Setup

# %% [markdown]
# ### 2.1. Python packages

# %% [markdown]
# For the notebook to properly run we need to first load the next packages available from the Jupyter Notebook Ecosystem. Please run the `next cell`:

# %%
import os
import warnings
warnings.filterwarnings("ignore")
import IPython
from shapely.geometry import box 
import ftputil
import pandas as pd
import folium
from folium import plugins
import json2html
from json2html import *
# %matplotlib inline

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# If any of them raises any error it means you need to install the module first. For doing so please:
# 1. Open a new cell in the notebook
# 2. Run <i>`!conda install packageName --yes`</i> or <i>`!conda install -c conda-forge packageName --yes`</i> or <i>`!pip install packageName`</i>
# 3. Import again!
# <br><br>
# Example: <i>how-to-solve import error for json2html module </i>
#
# ![region.png](img/errorImporting.gif)

# %% [markdown]
# ### 2.2. Copernicus Database

# %% [markdown]
# Please `set next your CMEMS User credentials` in the next cell and `run the cell` afterwards:

# %%
usr = 'inputHereYourCMEMSUser'
pas = 'inputHereYourCMEMSPassword'

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# **Don't you have credentials yet?**
# <br>Please go [here](https://resources.marine.copernicus.eu/?option=com_sla) to get the above credentials to be able to access CMEMS secured FTP servers hosting CMEMS data products.

# %% [markdown]
# As stated before, we will focus on the Near Real Time product/dataset covering the Black Sea so, please `run the next` to load the info defining such product/dataset:

# %%
dataset = {
    'host': 'nrt.cmems-du.eu',#ftp host => nrt.cmems-du.eu for Near Real Time products
    'product': 'INSITU_BS_NRT_OBSERVATIONS_013_034',#name of the In Situ Near Real Time product in the BS area
    'name': 'bs_multiparameter_nrt',#name of the dataset available in the above In Situ Near Real Time product
    'index_files': ['index_latest.txt', 'index_monthly.txt', 'index_history.txt'],#files describing the content of the lastest, monthly and history netCDF file collections available withint he above dataset
    'index_platform': 'index_platform.txt',#files describing the netwotk of platforms contributting with files in the abve collections
}

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# In case you want to explore any other In Situ NRT product/dataset just set the above definitions accordingly and you will be able to reproduce the analysis we will perform next.

# %% [markdown]
# ### 2.3. Auxiliary functions

# %% [markdown]
# For exploring the product/dataset we will use a set of files called `index files` located in the CMEMS FTP server.

# %% [markdown]
# 1. **Download the index files**.
# In order to download the most updated version of these files we will use the next function. <br>Please `run the next cell` to load it (te funtion) in memory for later use:

# %%
def getIndexFiles(usr,pas,dataset,path2indexes):
    #Provides the index files available at the ftp server
    indexes = dataset['index_files'] + [dataset['index_platform']]
    with ftputil.FTPHost(dataset['host'], usr, pas) as ftp_host:  # connect to CMEMS FTP
        for index in indexes:
            remotefile= "/".join(['Core',dataset['product'],dataset['name'],index])
            print('.....Downloading ' + index)
            localfile = os.path.join(path2indexes,index)
            ftp_host.download(remotefile,localfile)  # remote, local
    print('Ready!')

# %% [markdown]
# 2. **Index files reader**.
# In order to load the information contained in *each* of the files we will use the next function. <br>Please `run the next cell` to load it in memory for later use:

# %%
def readIndexFileFromCWD(path2file):
    #Load as pandas dataframe the file in the provided path
    with open(path2file, 'rb') as f:
        filename = os.path.basename(path2file)
        print('...Loading info from: '+filename)
        raw_index_info = pd.read_csv(path2file, skiprows=5)
    return raw_index_info

# %% [markdown]
# 3. **Index files merger**.
# In order to load the information contained in *all* the indexes in a one single entity we will use the next function. <br>Please `run the next cell` to load it in memory for later use:

# %%
def getIndexFilesInfo(usr, pas, dataset,path2indexes):
    # Load and merge in a single entity all the information contained on each file descriptor of a given dataset
    # 1) Loading the index platform info as dataframe
    path2file = os.path.join(path2indexes, dataset['index_platform'])
    indexPlatform = readIndexFileFromCWD(path2file)
    indexPlatform.rename(columns={indexPlatform.columns[0]: "platform_code" }, inplace = True)
    indexPlatform = indexPlatform.drop_duplicates(subset='platform_code', keep="first")
    # 2) Loading the index files info as dataframes
    netcdf_collections = []
    for filename in dataset['index_files']:
        path2file = os.path.join(path2indexes,filename)
        indexFile = readIndexFileFromCWD(path2file)
        netcdf_collections.append(indexFile)
    netcdf_collections = pd.concat(netcdf_collections)
    # 3) creating new columns: derived info
    netcdf_collections['netcdf'] = netcdf_collections['file_name'].str.split('/').str[-1]
    netcdf_collections['file_type'] = netcdf_collections['netcdf'].str.split('.').str[0].str.split('_').str[1]
    netcdf_collections['data_type'] = netcdf_collections['netcdf'].str.split('.').str[0].str.split('_').str[2]
    netcdf_collections['platform_code'] = netcdf_collections['netcdf'].str.split('.').str[0].str.split('_').str[3]
    # 4) Merging the information of all files
    headers = ['platform_code','wmo_platform_code', 'institution_edmo_code', 'last_latitude_observation', 'last_longitude_observation','last_date_observation']
    result = pd.merge(netcdf_collections,indexPlatform[headers],on='platform_code')
    print('Ready!')
    return result

# %% [markdown]
# ## 3. COLLECTION OVERVIEW

# %% [markdown]
# ### 3.1. Getting started

# %% [markdown]
# For the analysis to be carried out we need the most recent version of the index files. By default we will save them into the `index_files` folder available in the `data` folder. Nevertheless if you rather use a different one set it next:

# %%
path2indexes= os.path.join(os.getcwd(),'data','index_files')#default path to save the files

# %% [markdown]
# Although in such folder we have provided already a copy of the files, **if you are running this notebook later than April 2020** please `Run the next` cell and download again the index files:

# %%
getIndexFiles(usr,pas,dataset,path2indexes)
# Out:
# .....Downloading index_latest.txt
# .....Downloading index_monthly.txt
# .....Downloading index_history.txt
# .....Downloading index_platform.txt
# Ready!

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# **Are you getting a `permission denied` error?**
# <br>Please be aware that no `writes` are authorized in the 'shared_notebook' folder. Make sure you run this on you own space after copying the notebooks form shared_notebooks. If you are still facing a problem contact us trough [Mattermost](https://chat-cmems.mercator-ocean.fr/).

# %% [markdown]
# Let's load now into a dataframe the info contained in such files: `run the next cell!`

# %%
info = getIndexFilesInfo(usr, pas, dataset, path2indexes)
# Out:
# ...Loading info from: index_platform.txt
# ...Loading info from: index_latest.txt
# ...Loading info from: index_monthly.txt
# ...Loading info from: index_history.txt
# Ready!

# %% [markdown]
# `Run now the next cell` to see the information just loaded above:

# %%
info.transpose()
# Out:
#                                                                          0     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-13T06:00:00Z
# time_coverage_end                                        2021-01-13T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:00Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210113.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          1     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-14T06:00:00Z
# time_coverage_end                                        2021-01-14T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:09Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210114.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          2     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-15T12:00:00Z
# time_coverage_end                                        2021-01-15T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:17Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210115.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          3     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-16T06:00:00Z
# time_coverage_end                                        2021-01-16T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:24Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210116.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          4     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-17T06:00:00Z
# time_coverage_end                                        2021-01-17T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:32Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210117.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          5     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-18T06:00:00Z
# time_coverage_end                                        2021-01-18T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:40Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210118.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          6     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-19T06:00:00Z
# time_coverage_end                                        2021-01-19T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:48Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210119.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          7     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-20T06:00:00Z
# time_coverage_end                                        2021-01-20T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:56Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210120.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          8     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-21T06:00:00Z
# time_coverage_end                                        2021-01-21T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:30:04Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210121.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          9     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-22T06:00:00Z
# time_coverage_end                                        2021-01-22T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:30:11Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210122.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
#
#                                                                          3319  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     42.924
# geospatial_lat_max                                                     43.897
# geospatial_lon_min                                                     30.778
# geospatial_lon_max                                                     32.304
# time_coverage_start                                      2002-01-02T14:29:00Z
# time_coverage_end                                        2002-02-19T12:21:00Z
# institution                                 Naval Oceanographic Office (NAVO)
# date_update                                              2019-09-28T15:31:38Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61543.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61543
# wmo_platform_code                                                       61543
# institution_edmo_code                                                    3577
# last_latitude_observation                                              43.531
# last_longitude_observation                                             31.526
# last_date_observation                                    2002-02-19T12:21:00Z
#
#                                                                          3320  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     43.407
# geospatial_lat_max                                                     43.700
# geospatial_lon_min                                                     30.848
# geospatial_lon_max                                                     30.928
# time_coverage_start                                      2002-01-02T14:28:00Z
# time_coverage_end                                        2002-01-04T03:58:00Z
# institution                                 Naval Oceanographic Office (NAVO)
# date_update                                              2019-09-28T15:33:33Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61545.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61545
# wmo_platform_code                                                       61545
# institution_edmo_code                                                    3577
# last_latitude_observation                                              43.407
# last_longitude_observation                                             30.928
# last_date_observation                                    2002-01-04T03:58:00Z
#
#                                                                          3321  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.526
# geospatial_lat_max                                                     44.122
# geospatial_lon_min                                                     29.011
# geospatial_lon_max                                                     38.579
# time_coverage_start                                      2002-01-02T14:29:00Z
# time_coverage_end                                        2002-04-06T09:05:00Z
# institution                                 Naval Oceanographic Office (NAVO)
# date_update                                              2019-09-28T15:33:33Z
# data_mode                                                                   R
# parameters                                                     DEPH PRES TEMP
# netcdf                                                      GL_PR_XX_61546.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61546
# wmo_platform_code                                                       61546
# institution_edmo_code                                                    3577
# last_latitude_observation                                              42.111
# last_longitude_observation                                             38.579
# last_date_observation                                    2002-04-06T09:05:00Z
#
#                                                                          3322  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     42.598
# geospatial_lat_max                                                     43.262
# geospatial_lon_min                                                     30.430
# geospatial_lon_max                                                     31.611
# time_coverage_start                                      2002-01-02T14:29:00Z
# time_coverage_end                                        2002-01-29T06:00:00Z
# institution                                 Naval Oceanographic Office (NAVO)
# date_update                                              2019-09-28T15:33:33Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61547.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61547
# wmo_platform_code                                                       61547
# institution_edmo_code                                                    3577
# last_latitude_observation                                              42.755
# last_longitude_observation                                             30.530
# last_date_observation                                    2002-01-29T06:00:00Z
#
#                                                                          3323  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     42.365
# geospatial_lat_max                                                     43.259
# geospatial_lon_min                                                     30.253
# geospatial_lon_max                                                     35.011
# time_coverage_start                                      2002-01-02T14:28:00Z
# time_coverage_end                                        2002-03-30T06:13:00Z
# institution                                               Unknown institution
# date_update                                              2019-09-28T15:33:33Z
# data_mode                                                                   R
# parameters                                                     DEPH PRES TEMP
# netcdf                                                      GL_PR_XX_61549.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61549
# wmo_platform_code                                                       61549
# institution_edmo_code
# last_latitude_observation                                              42.812
# last_longitude_observation                                             35.011
# last_date_observation                                    2002-03-30T06:13:00Z
#
#                                                                          3324  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     44.410
# geospatial_lat_max                                                     44.882
# geospatial_lon_min                                                     29.637
# geospatial_lon_max                                                     32.906
# time_coverage_start                                      2013-11-21T14:00:00Z
# time_coverage_end                                        2014-01-09T13:00:00Z
# institution                                               Unknown institution
# date_update                                              2019-09-28T15:33:28Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61687.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61687
# wmo_platform_code                                                       61687
# institution_edmo_code
# last_latitude_observation                                              44.625
# last_longitude_observation                                             29.785
# last_date_observation                                    2014-01-09T13:00:00Z
#
#                                                                          3325  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     43.365
# geospatial_lat_max                                                     44.139
# geospatial_lon_min                                                     29.460
# geospatial_lon_max                                                     32.679
# time_coverage_start                                      2009-08-03T07:30:00Z
# time_coverage_end                                        2012-12-18T13:00:00Z
# institution                                               Unknown institution
# date_update                                              2021-01-24T20:36:13Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61689.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61689
# wmo_platform_code                                                       61689
# institution_edmo_code
# last_latitude_observation                                              44.078
# last_longitude_observation                                             32.536
# last_date_observation                                    2012-12-18T13:00:00Z
#
#                                                                          3326  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.436
# geospatial_lat_max                                                     44.810
# geospatial_lon_min                                                     28.527
# geospatial_lon_max                                                     38.362
# time_coverage_start                                      2009-08-03T07:30:00Z
# time_coverage_end                                        2014-05-28T02:00:00Z
# institution                                               Unknown institution
# date_update                                              2021-01-24T20:36:13Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61690.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61690
# wmo_platform_code                                                       61690
# institution_edmo_code
# last_latitude_observation                                              43.254
# last_longitude_observation                                             38.260
# last_date_observation                                    2014-05-28T02:00:00Z
#
#                                                                          3327  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.279
# geospatial_lat_max                                                     44.828
# geospatial_lon_min                                                     28.080
# geospatial_lon_max                                                     33.937
# time_coverage_start                                      2009-08-03T07:30:00Z
# time_coverage_end                                        2014-03-11T01:00:00Z
# institution                                               Unknown institution
# date_update                                              2019-09-28T15:33:28Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61691.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61691
# wmo_platform_code                                                       61691
# institution_edmo_code
# last_latitude_observation                                              41.279
# last_longitude_observation                                             29.474
# last_date_observation                                    2014-03-11T01:00:00Z
#
#                                                                          3328
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       44.4
# geospatial_lat_max                                                       44.4
# geospatial_lon_min                                                       32.7
# geospatial_lon_max                                                       32.7
# time_coverage_start                                      1999-03-25T10:08:00Z
# time_coverage_end                                        1999-03-25T10:08:00Z
# institution                                                  Russia (Unknown)
# date_update                                              2020-01-28T05:08:23Z
# data_mode                                                                   R
# parameters                                                          PRES TEMP
# netcdf                                                       GL_PR_XX_UZFA.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            UZFA
# wmo_platform_code                                                        UZFA
# institution_edmo_code
# last_latitude_observation                                                44.4
# last_longitude_observation                                               32.7
# last_date_observation                                    1999-03-25T10:08:00Z
#
# [21 rows x 3329 columns]

# %% [markdown]
# Above you can see, on the left hand side, a number of metadata fields that describes the files available in each collection (latest, monthly and history) of the product, such as: ftplink to download it (file_name), geospatial bounding box (geospatial_lat/lon_min/max), temporal coverage (time_coverage_start/end) etc.
#
# You can also see a dedicated column for each file with its corresponding values for the aforementioned descriptive metadata fields.

# %% [markdown]
# We will use all this information next to have a glimpse to the content of one of the product/dataset netCDF files collections.

# %% [markdown]
# ### 3.2. Choosing collection

# %% [markdown]
# `Set in the next cell the collection` you wanna get an overview of and `run it` afterwards. <br> We have selected the 'history' by default but please feel free to change it:

# %%
targeted_collection = 'history'
targeted_collection_info = info[info['file_name'].str.contains(targeted_collection)]
targeted_collection_info.transpose()
# Out:
#                                                                          61    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.20
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.70
# geospatial_lon_max                                                      29.70
# time_coverage_start                                      2018-08-16T06:00:00Z
# time_coverage_end                                        2020-08-31T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-01-06T12:52:26Z
# data_mode                                                                   D
# parameters                                                          DEPH TEMP
# netcdf                                                      BS_TS_MO_15360.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          117   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      44.70
# geospatial_lat_max                                                      44.68
# geospatial_lon_min                                                      29.00
# geospatial_lon_max                                                      29.00
# time_coverage_start                                      2018-08-17T12:00:00Z
# time_coverage_end                                        2020-08-31T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-01-06T12:52:26Z
# data_mode                                                                   D
# parameters                                                          DEPH TEMP
# netcdf                                                      BS_TS_MO_15428.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15428
# wmo_platform_code                                                       15428
# institution_edmo_code
# last_latitude_observation                                               44.68
# last_longitude_observation                                              28.98
# last_date_observation                                    2021-02-11T12:00:00Z
#
#                                                                          179   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      44.20
# geospatial_lat_max                                                      44.22
# geospatial_lon_min                                                      28.60
# geospatial_lon_max                                                      28.60
# time_coverage_start                                      2018-08-16T06:00:00Z
# time_coverage_end                                        2020-04-30T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-01-06T12:52:26Z
# data_mode                                                                   D
# parameters                                                          DEPH TEMP
# netcdf                                                      BS_TS_MO_15480.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15480
# wmo_platform_code                                                       15480
# institution_edmo_code
# last_latitude_observation                                               44.22
# last_longitude_observation                                              28.63
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          235   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      43.80
# geospatial_lat_max                                                      43.80
# geospatial_lon_min                                                      28.60
# geospatial_lon_max                                                      28.60
# time_coverage_start                                      2018-08-16T12:00:00Z
# time_coverage_end                                        2020-08-31T12:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-01-06T12:52:27Z
# data_mode                                                                   D
# parameters                                                          DEPH TEMP
# netcdf                                                      BS_TS_MO_15499.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15499
# wmo_platform_code                                                       15499
# institution_edmo_code
# last_latitude_observation                                               43.80
# last_longitude_observation                                              28.58
# last_date_observation                                    2021-02-11T12:00:00Z
#
#                                                                          297   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      43.20
# geospatial_lat_max                                                      43.20
# geospatial_lon_min                                                      28.00
# geospatial_lon_max                                                      28.00
# time_coverage_start                                      2018-08-16T06:00:00Z
# time_coverage_end                                        2020-08-31T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-01-06T12:52:27Z
# data_mode                                                                   D
# parameters                                                          DEPH TEMP
# netcdf                                                      BS_TS_MO_15552.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15552
# wmo_platform_code                                                       15552
# institution_edmo_code                                                     961
# last_latitude_observation                                               43.20
# last_longitude_observation                                              27.95
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          359   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      42.50
# geospatial_lat_max                                                      42.50
# geospatial_lon_min                                                      27.50
# geospatial_lon_max                                                      27.50
# time_coverage_start                                      2018-08-16T06:00:00Z
# time_coverage_end                                        2020-08-31T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-01-06T12:52:27Z
# data_mode                                                                   D
# parameters                                                          DEPH TEMP
# netcdf                                                      BS_TS_MO_15655.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15655
# wmo_platform_code                                                       15655
# institution_edmo_code                                                     961
# last_latitude_observation                                               42.50
# last_longitude_observation                                              27.48
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          482   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     43.404
# geospatial_lat_max                                                     43.404
# geospatial_lon_min                                                     28.165
# geospatial_lon_max                                                     28.165
# time_coverage_start                                      2015-04-15T15:00:00Z
# time_coverage_end                                        2020-06-30T21:00:00Z
# institution                 Institute of Oceanology  Bulgarian Academy of ...
# date_update                                              2021-01-06T12:52:33Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                                    BS_TS_TG_Balchik.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                         Balchik
# wmo_platform_code
# institution_edmo_code                                                    1843
# last_latitude_observation                                              43.404
# last_longitude_observation                                             28.165
# last_date_observation                                    2021-02-12T13:18:00Z
#
#                                                                          513   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    43.8022
# geospatial_lat_max                                                    43.8022
# geospatial_lon_min                                                    28.6025
# geospatial_lon_max                                                    28.6025
# time_coverage_start                                      2016-01-04T10:30:00Z
# time_coverage_end                                        2016-12-30T12:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-01-06T12:52:36Z
# data_mode                                                                   D
# parameters                  DEPH TEMP FLU2 DOXY HCSP EWCT NSCT HCDT TUR4 A...
# netcdf                                                         BS_TS_MO_CG.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                              CG
# wmo_platform_code
# institution_edmo_code                                                     850
# last_latitude_observation                                             43.8022
# last_longitude_observation                                            28.6055
# last_date_observation                                    2021-01-25T11:00:00Z
#
#                                                                          585   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     44.318
# geospatial_lat_max                                                     44.318
# geospatial_lon_min                                                     30.417
# geospatial_lon_max                                                     30.417
# time_coverage_start                                      2014-01-01T00:00:00Z
# time_coverage_end                                        2020-05-31T23:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-01-06T12:52:40Z
# data_mode                                                                   D
# parameters                  DEPH TEMP PSAL FLU2 OSAT DOXY TUR4 HCDT HCSP R...
# netcdf                                                    BS_TS_MO_EUXRo02.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                         EUXRo02
# wmo_platform_code
# institution_edmo_code                                                     850
# last_latitude_observation                                              44.318
# last_longitude_observation                                             30.417
# last_date_observation                                    2021-01-25T11:00:00Z
#
#                                                                          657   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     43.980
# geospatial_lat_max                                                     43.980
# geospatial_lon_min                                                     29.936
# geospatial_lon_max                                                     29.936
# time_coverage_start                                      2014-01-01T00:00:00Z
# time_coverage_end                                        2020-05-31T23:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-01-06T12:52:42Z
# data_mode                                                                   D
# parameters                  DEPH TEMP PSAL FLU2 OSAT DOXY TUR4 HCDT HCSP R...
# netcdf                                                    BS_TS_MO_EUXRo03.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                         EUXRo03
# wmo_platform_code
# institution_edmo_code                                                     850
# last_latitude_observation                                              43.980
# last_longitude_observation                                             29.936
# last_date_observation                                    2021-01-25T11:00:00Z
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
#
#                                                                          3319  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     42.924
# geospatial_lat_max                                                     43.897
# geospatial_lon_min                                                     30.778
# geospatial_lon_max                                                     32.304
# time_coverage_start                                      2002-01-02T14:29:00Z
# time_coverage_end                                        2002-02-19T12:21:00Z
# institution                                 Naval Oceanographic Office (NAVO)
# date_update                                              2019-09-28T15:31:38Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61543.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61543
# wmo_platform_code                                                       61543
# institution_edmo_code                                                    3577
# last_latitude_observation                                              43.531
# last_longitude_observation                                             31.526
# last_date_observation                                    2002-02-19T12:21:00Z
#
#                                                                          3320  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     43.407
# geospatial_lat_max                                                     43.700
# geospatial_lon_min                                                     30.848
# geospatial_lon_max                                                     30.928
# time_coverage_start                                      2002-01-02T14:28:00Z
# time_coverage_end                                        2002-01-04T03:58:00Z
# institution                                 Naval Oceanographic Office (NAVO)
# date_update                                              2019-09-28T15:33:33Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61545.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61545
# wmo_platform_code                                                       61545
# institution_edmo_code                                                    3577
# last_latitude_observation                                              43.407
# last_longitude_observation                                             30.928
# last_date_observation                                    2002-01-04T03:58:00Z
#
#                                                                          3321  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.526
# geospatial_lat_max                                                     44.122
# geospatial_lon_min                                                     29.011
# geospatial_lon_max                                                     38.579
# time_coverage_start                                      2002-01-02T14:29:00Z
# time_coverage_end                                        2002-04-06T09:05:00Z
# institution                                 Naval Oceanographic Office (NAVO)
# date_update                                              2019-09-28T15:33:33Z
# data_mode                                                                   R
# parameters                                                     DEPH PRES TEMP
# netcdf                                                      GL_PR_XX_61546.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61546
# wmo_platform_code                                                       61546
# institution_edmo_code                                                    3577
# last_latitude_observation                                              42.111
# last_longitude_observation                                             38.579
# last_date_observation                                    2002-04-06T09:05:00Z
#
#                                                                          3322  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     42.598
# geospatial_lat_max                                                     43.262
# geospatial_lon_min                                                     30.430
# geospatial_lon_max                                                     31.611
# time_coverage_start                                      2002-01-02T14:29:00Z
# time_coverage_end                                        2002-01-29T06:00:00Z
# institution                                 Naval Oceanographic Office (NAVO)
# date_update                                              2019-09-28T15:33:33Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61547.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61547
# wmo_platform_code                                                       61547
# institution_edmo_code                                                    3577
# last_latitude_observation                                              42.755
# last_longitude_observation                                             30.530
# last_date_observation                                    2002-01-29T06:00:00Z
#
#                                                                          3323  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     42.365
# geospatial_lat_max                                                     43.259
# geospatial_lon_min                                                     30.253
# geospatial_lon_max                                                     35.011
# time_coverage_start                                      2002-01-02T14:28:00Z
# time_coverage_end                                        2002-03-30T06:13:00Z
# institution                                               Unknown institution
# date_update                                              2019-09-28T15:33:33Z
# data_mode                                                                   R
# parameters                                                     DEPH PRES TEMP
# netcdf                                                      GL_PR_XX_61549.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61549
# wmo_platform_code                                                       61549
# institution_edmo_code
# last_latitude_observation                                              42.812
# last_longitude_observation                                             35.011
# last_date_observation                                    2002-03-30T06:13:00Z
#
#                                                                          3324  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     44.410
# geospatial_lat_max                                                     44.882
# geospatial_lon_min                                                     29.637
# geospatial_lon_max                                                     32.906
# time_coverage_start                                      2013-11-21T14:00:00Z
# time_coverage_end                                        2014-01-09T13:00:00Z
# institution                                               Unknown institution
# date_update                                              2019-09-28T15:33:28Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61687.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61687
# wmo_platform_code                                                       61687
# institution_edmo_code
# last_latitude_observation                                              44.625
# last_longitude_observation                                             29.785
# last_date_observation                                    2014-01-09T13:00:00Z
#
#                                                                          3325  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     43.365
# geospatial_lat_max                                                     44.139
# geospatial_lon_min                                                     29.460
# geospatial_lon_max                                                     32.679
# time_coverage_start                                      2009-08-03T07:30:00Z
# time_coverage_end                                        2012-12-18T13:00:00Z
# institution                                               Unknown institution
# date_update                                              2021-01-24T20:36:13Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61689.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61689
# wmo_platform_code                                                       61689
# institution_edmo_code
# last_latitude_observation                                              44.078
# last_longitude_observation                                             32.536
# last_date_observation                                    2012-12-18T13:00:00Z
#
#                                                                          3326  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.436
# geospatial_lat_max                                                     44.810
# geospatial_lon_min                                                     28.527
# geospatial_lon_max                                                     38.362
# time_coverage_start                                      2009-08-03T07:30:00Z
# time_coverage_end                                        2014-05-28T02:00:00Z
# institution                                               Unknown institution
# date_update                                              2021-01-24T20:36:13Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61690.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61690
# wmo_platform_code                                                       61690
# institution_edmo_code
# last_latitude_observation                                              43.254
# last_longitude_observation                                             38.260
# last_date_observation                                    2014-05-28T02:00:00Z
#
#                                                                          3327  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.279
# geospatial_lat_max                                                     44.828
# geospatial_lon_min                                                     28.080
# geospatial_lon_max                                                     33.937
# time_coverage_start                                      2009-08-03T07:30:00Z
# time_coverage_end                                        2014-03-11T01:00:00Z
# institution                                               Unknown institution
# date_update                                              2019-09-28T15:33:28Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61691.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61691
# wmo_platform_code                                                       61691
# institution_edmo_code
# last_latitude_observation                                              41.279
# last_longitude_observation                                             29.474
# last_date_observation                                    2014-03-11T01:00:00Z
#
#                                                                          3328
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       44.4
# geospatial_lat_max                                                       44.4
# geospatial_lon_min                                                       32.7
# geospatial_lon_max                                                       32.7
# time_coverage_start                                      1999-03-25T10:08:00Z
# time_coverage_end                                        1999-03-25T10:08:00Z
# institution                                                  Russia (Unknown)
# date_update                                              2020-01-28T05:08:23Z
# data_mode                                                                   R
# parameters                                                          PRES TEMP
# netcdf                                                       GL_PR_XX_UZFA.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            UZFA
# wmo_platform_code                                                        UZFA
# institution_edmo_code
# last_latitude_observation                                                44.4
# last_longitude_observation                                               32.7
# last_date_observation                                    1999-03-25T10:08:00Z
#
# [21 rows x 356 columns]

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>IMPORTANT</b>
#
# ***
# Please remember available options:
# <ul>
#     <li><i>latest</i>: daily files from platforms (last 30 days of data)</li>
#     <li><i>monthly</i>: monthly files from platforms (last 5 years of data)</li>
#     <li><i>history</i>: one file per platform (all platform data)</li>
# </ul>

# %% [markdown]
# ### 3.3. Overview

# %% [markdown]
# #### 3.3.1. Platforms

# %% [markdown]
# Any Situ NRT products/datasets collections are composed by files reported by a network of platforms located in the area.

# %% [markdown]
# Let's `run the next cell` to know how many platforms are contributting to this product/dataset collection with files:

# %%
len(targeted_collection_info.groupby('platform_code').groups)
# Out:
# 333

# %% [markdown]
# Let's get a closer look to this list of platforms: `run the next cells`:

# %%
data_platforms = [{
    'code':code, 
    'provider(s)': files['institution_edmo_code'].iloc[0],
    'files': {
        'nfiles': len(files), 
        'feature(s)': [{'code': ftype, 'nfiles':len(files.groupby('file_type').get_group(ftype)),'sources(s)': [{'code': dtype, 'nfiles': len(files.groupby('file_type').get_group(ftype).groupby('data_type').get_group(dtype)), 'parameters': [param for param in sum([files.groupby('file_type').get_group(ftype).groupby('data_type').get_group(dtype)['parameters'].unique().tolist()],[])[0].split(' ') if '_' not in param and param not in ['DEPH', 'PRES'] and param != '']} for dtype in files[files['file_type']==ftype]['data_type'].unique().tolist()]} for ftype in files['file_type'].unique().tolist()]}
} for code,files in targeted_collection_info.groupby(['platform_code'])]

# %%
IPython.display.HTML(json2html.convert(data_platforms))
# Out:
# <table border="1"><thead><tr><th>code</th><th>provider(s)</th><th>files</th></tr></thead><tbody><tr><td>100093</td><td>2688</td><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>TG</td><td>1</td><td><ul><li>SLEV</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr><tr><td>15360</td><td> </td><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>MO</td><td>1</td><td><ul><li>TEMP</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr><tr><td>15428</td><td> </td><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>MO</td><td>1</td><td><ul><li>TEMP</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr><tr><td>15480</td><td> </td><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>MO</td><td>1</td><td><ul><li>TEMP</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr><tr><td>15499</td><td> </td><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>MO</td><td>1</td><td><ul><li>TEMP</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr><tr><td>15552</td><td>961</td><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>MO</td><td>1</td><td><ul><li>TEMP</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr><tr><td>15655</td><td>961</td><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>MO</td><td>1</td><td><ul><li>TEMP</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr><tr><td>15AK</td><td>1843</td><td><table border="1"><tr><th>nfiles</th><td>3</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>3</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>CT</td><td>3</td><td><ul><li>TEMP</li><li>PSAL</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr><tr><td>1901200</td><td>120</td><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>s ...

# %% [markdown]
# Too much info? Let's see one in particular! `Run the next cells`:
# <a id='platform_selected'></a>

# %%
code = '7900596'

# %%
selection = [platform for platform in data_platforms if platform['code'] == code]
IPython.display.HTML(json2html.convert(selection))
# Out:
# <table border="1"><thead><tr><th>code</th><th>provider(s)</th><th>files</th></tr></thead><tbody><tr><td>7900596</td><td>1843</td><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>PF</td><td>1</td><td><ul><li>TEMP</li><li>PSAL</li><li>DOX2</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></tbody></table>

# %% [markdown]
# So far we can see that each platform:
# * Can have one or more providers - identified by a blank-separated list of one or more codes: the so called *edmo code* (we will see more about this later).
# * Produces different type of files (see above `PR` *type* bigram) from one or more data sources (see above `PF` *source* bigram) and containing more or less parameters (see *parameters* codes). We will se next more about this!

# %% [markdown]
# Ok but...where is it located? There are some geographical references that we can use to infer the location of the platform:
# * the bounding box of the produced files (this is, the spatial coverage - a rectangular simplification actually - of the data measured by the platform)
# * the last position reported.

# %% [markdown]
# Let's draw all them on a map to get an idea!: `run the next cell`

# %%
#initializing map
m = folium.Map(location=[39.0, 0], zoom_start=4)
#Loooping over each file produced by the platform above
for idx,file in targeted_collection_info[targeted_collection_info['platform_code'] == code].iterrows():
    #Bounding-box of each file to map as polygon
    upper_left = [file['geospatial_lat_max'], file['geospatial_lon_min']]
    upper_right = [file['geospatial_lat_max'], file['geospatial_lon_max']]
    lower_right = [file['geospatial_lat_min'], file['geospatial_lon_max']]
    lower_left = [file['geospatial_lat_min'], file['geospatial_lon_min']]
    edges = [upper_left, upper_right, lower_right, lower_left]
    m.add_child(folium.vector_layers.Polygon(locations=edges, popup='file bbox: '+file['netcdf']))
#Last reported position to map as marker
m.add_child(folium.Marker([file['last_latitude_observation'], file['last_longitude_observation']], popup=file['platform_code']+' last position' ))
#Zooming closer
m.fit_bounds(edges, max_zoom=6)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_afcce2879e054ebf96006203a38ab907%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_afcce2879e054ebf96006203a38ab907%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_afcce2879e054ebf96006203a38ab907%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_afcce2879e054ebf96006203a38ab907%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.0%2C%200.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs ...

# %% [markdown]
# On the next tutorial we will see how to use this very same geographical info to select only those files covering a specific area.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# **Don't you see the map?** Please open the notebook in a different browser (i.e Chrome!) as some have problems rendering folium maps.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b style="margin-right: 2em">IMPORTANT</b>
#
# ***
# **Are you a provider?**
# If you have a platform (or know about one) producing data in the area and it does not appear ont he list please **contact us** by emailing the corresponding Regional CMEMS In Situ TAC Service Desk [here](http://www.marineinsitu.eu/submit-data/) **or let the speaker know**!

# %% [markdown]
# #### 3.3.2. Source types

# %% [markdown]
# `Data sources` represents the elements that report oceanographic data. <br>So far the In Situ TAC distinguishes:

# %% [markdown]
# | code | description |
# | ------- | ------- |
# |BO | Bottle |
# |BA | Data from Bathy messages on GTS |
# |DB | Drifting buoys |
# |DC | Drifting buoy reporting calculated sea water current |
# |FB | FerryBox |
# |MO | Fixed buoys or mooring time series |
# |TG | Tide gauges |
# |GL | Gliders |
# |ML | Mini logger |
# |CT | Oceanographic CTD profiles | //historic index file el data_type es "oceanographic CTD profiles"
# |PF | Profiling floats vertical profiles |
# |RE | Recopesca |
# |RF | River flows |
# |SF | Scanfish profiles |
# |TS | Thermosalinograph data |
# |XB | XBT or XCTD profiles |
# |TE | Data from TESAC messages on GTS |
# |SM | Sea-mammals |
# |HF | High Frequency Radar |
# |SD | Saildrone |
# |VA | Vessel mounted ADCP |
# |XX | Unknown |

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To find the updated catalog of possible codes for data sources (`data types` in documentation) please check the <a href="https://archimer.ifremer.fr/doc/00324/43494/" target="_blank">Product User Manual</a>.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b style="margin-right: 2em">CHALLENGE</b> Do you find in there the data type of <a href="#platform_selected">the platform</a> we were looking at in the platform section?
#
# ***
# In the end the platform we are checking is a:
# * Profiler (PF)

# %% [markdown]
# Ok, this is the full list but; which ones are actually available in this product/dataset/collection?<br> `Run the next cell` to discover them:

# %%
targeted_collection_info['data_type'].unique().tolist()
# Out:
# ['MO', 'TG', 'PF', 'CT', 'FB', 'BO', 'DB', 'XX']

# %% [markdown]
# And, How many of each? `Run the next cells`...

# %%
data_types = [{
    'code':code,
    'platforms': {'nplatforms': len(files.groupby('platform_code')),'files': {'nfiles': len(files), 'features(s)': [{'code':ftype, 'nfiles': len(files.groupby('data_type').get_group(code).groupby('file_type').get_group(ftype)), 'nplatforms': len(files.groupby('data_type').get_group(code).groupby('platform_code'))} for ftype in files[files['data_type']==code]['file_type'].unique().tolist()]}}
} for code,files in targeted_collection_info.groupby(['data_type'])]

# %%
IPython.display.HTML(json2html.convert(data_types))
# Out:
# <table border="1"><thead><tr><th>code</th><th>platforms</th></tr></thead><tbody><tr><td>BO</td><td><table border="1"><tr><th>nplatforms</th><td>67</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>70</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>PR</td><td>70</td><td>67</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>CT</td><td><table border="1"><tr><th>nplatforms</th><td>158</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>174</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>PR</td><td>174</td><td>158</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>DB</td><td><table border="1"><tr><th>nplatforms</th><td>7</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>7</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>TS</td><td>7</td><td>7</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>FB</td><td><table border="1"><tr><th>nplatforms</th><td>2</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>4</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>TS</td><td>4</td><td>2</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>MO</td><td><table border="1"><tr><th>nplatforms</th><td>31</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>31</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>TS</td><td>31</td><td>31</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>PF</td><td><table border="1"><tr><th>nplatforms</th><td>44</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>44</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>PR</td><td>44</td><td>44</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>TG</td><td><table border="1"><tr><th>nplatforms</th><td>13</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>13</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>TS</td><td>13</td><td>13</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>XX</td><td><table border="1"><tr><th>nplatforms</th><td>13</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>13</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>PR</td><td>13</td><td>13</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr></tbody></table>

# %% [markdown]
# Too much info? Choose just one! `Run the next cell`:

# %%
code = 'PF'

# %%
selection = [dtype for dtype in data_types if dtype['code'] == code]
IPython.display.HTML(json2html.convert(selection))
# Out:
# <table border="1"><thead><tr><th>code</th><th>platforms</th></tr></thead><tbody><tr><td>PF</td><td><table border="1"><tr><th>nplatforms</th><td>44</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>44</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>PR</td><td>44</td><td>44</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr></tbody></table>

# %% [markdown]
# #### 3.3.3. Feature types

# %% [markdown]
# `Feature types` represents the shape of the data reported by a given platform data source. <br>So far the In Situ TAC distinguishes 4 feature types:

# %% [markdown]
# | code | description |
# | ------- | ------- |
# |TS | Time Serie or trajectories |
# |PR | Profile |
# |TV | Grided data - High Frequency Radar total velocity fields |
# |RV | Grided data - High Frequency Radar radial velocity fields |
# |WS | Wave spectra |

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To find the updated catalog of possible codes for feature types (`file types` in documentation) please check the <a href="https://archimer.ifremer.fr/doc/00324/43494/" target="_blank">Product User Manual</a>.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b style="margin-right: 2em">CHALLENGE</b>Do you find in there the feature types of <a href="#platform_selected">the platform</a> we were looking at in the platform section?
#
# ***
# * Profile / PR  - vertical measurements along the water column of certain oceanographic variables

# %% [markdown]
# Ok, this is the full list but; which ones are actually available in this product/dataset/collection?<br> `Run the next cell`to know!

# %%
targeted_collection_info['file_type'].unique().tolist()
# Out:
# ['TS', 'PR']

# %% [markdown]
# And, How many of each? `Run the next cells`...

# %%
file_types = [{
    'code':code,
    'platforms': {'nplatforms': len(files.groupby('platform_code')),'files': {'nfiles': len(files), 'sources(s)': [{'code':dtype, 'nfiles': len(files.groupby('file_type').get_group(code).groupby('data_type').get_group(dtype)), 'nplatforms': len(files.groupby('file_type').get_group(code).groupby('data_type').get_group(dtype).groupby('platform_code'))} for dtype in files[files['file_type']==code]['data_type'].unique().tolist()]}}
} for code,files in targeted_collection_info.groupby(['file_type'])]

# %%
IPython.display.HTML(json2html.convert(file_types))
# Out:
# <table border="1"><thead><tr><th>code</th><th>platforms</th></tr></thead><tbody><tr><td>PR</td><td><table border="1"><tr><th>nplatforms</th><td>282</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>301</td></tr><tr><th>sources(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>PF</td><td>44</td><td>44</td></tr><tr><td>CT</td><td>174</td><td>158</td></tr><tr><td>BO</td><td>70</td><td>67</td></tr><tr><td>XX</td><td>13</td><td>13</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>TS</td><td><table border="1"><tr><th>nplatforms</th><td>53</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>55</td></tr><tr><th>sources(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>MO</td><td>31</td><td>31</td></tr><tr><td>TG</td><td>13</td><td>13</td></tr><tr><td>FB</td><td>4</td><td>2</td></tr><tr><td>DB</td><td>7</td><td>7</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr></tbody></table>

# %% [markdown]
# #### 3.3.4. Parameters
# `parameters` represents the oceanographic variables measured by the platform and therefore present in its files. <br>So Far the In Situ TAC distinguishes the next ones (zoom with the -|+ controls if you do not see it properly): `run the next cell`

# %%
IPython.display.IFrame('https://archimer.ifremer.fr/doc/00422/53381/72333.pdf', width='100%', height=350)
# Out:
#         <iframe
#             width="100%"
#             height="350"
#             src="https://archimer.ifremer.fr/doc/00422/53381/72333.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To find the updated catalog of parameters please check <a href="https://archimer.ifremer.fr/doc/00422/53381/" target="_blank">this</a>.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b style="margin-right: 2em">CHALLENGE</b> Do you find in there the feature types of <a href="#platform_selected">the platform</a> we were looking at in the platform section?
#
# ***
# In the end the platform we are checking is a profiler reporting:
# * Profiles of Temperature, Salinity and Oxygen variables along the water column

# %% [markdown]
# Ok, this is the full list but; which ones are actually available in this product/dataset collection? `Run the next cell`and discover it!:

# %%
parameter_list = [param for param in list(set(sum([parameter.split(' ') for parameter in targeted_collection_info['parameters'].tolist()],[]))) if '_' not in param and param not in ['DEPH', 'PRES'] and param != '']
parameter_list
# Out:
# ['PSAL',
#  'LGHT',
#  'PHOS',
#  'ATMP',
#  'TEMP',
#  'ATMS',
#  'OSAT',
#  'GSPD',
#  'VTPK',
#  'VAVT',
#  'VPSP',
#  'DOXY',
#  'CDOM',
#  'ATPT',
#  'VHM0',
#  'SLEV',
#  'BBP532',
#  'VZMX',
#  'TUR4',
#  'BBP700',
#  'BISULFIDE',
#  'CHLT',
#  'HCDT',
#  'VPED',
#  'AMON',
#  'DRYT',
#  'ALK3',
#  'FLU2',
#  'DOX1',
#  'VGHS',
#  'HCSP',
#  'WSPD',
#  'NTRA',
#  'VEMH',
#  'PHPH',
#  'NSCT',
#  'VGTA',
#  'DOX2',
#  'VAVH',
#  'WDIR',
#  'RELH',
#  'DENS',
#  'VDIR',
#  'NTAW',
#  'EWCT',
#  'NTRI',
#  'ALKY',
#  'SLCA',
#  'CPHL']

# %% [markdown]
# And, How many of each? `Run the next cells`...

# %%
parameters = [{
    'code':code,
    'platforms':{
        'nplatforms': len(targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)].groupby('platform_code')),
        'files':{
            'nfiles': len(targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)]), 
            'feature(s)': [{'code': ftype, 'nplatforms': len(targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)].groupby('file_type').get_group(ftype).groupby('platform_code')), 'nfiles':len(targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)].groupby('file_type').get_group(ftype)),'sources(s)': [{'code': dtype, 'nplatforms' : len(targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)].groupby('file_type').get_group(ftype).groupby('data_type').get_group(dtype).groupby('platform_code')) ,'nfiles': len(targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)].groupby('file_type').get_group(ftype).groupby('data_type').get_group(dtype))} for dtype in targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)][targeted_collection_info['file_type']==ftype]['data_type'].unique().tolist()]} for ftype in targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)]['file_type'].unique().tolist()]
        }
    }
} for code in parameter_list]

# %%
IPython.display.HTML(json2html.convert(parameters))
# Out:
# <table border="1"><thead><tr><th>code</th><th>platforms</th></tr></thead><tbody><tr><td>PSAL</td><td><table border="1"><tr><th>nplatforms</th><td>266</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>287</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>6</td><td>8</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>MO</td><td>5</td><td>5</td></tr><tr><td>FB</td><td>1</td><td>3</td></tr></tbody></table></td></tr><tr><td>PR</td><td>260</td><td>279</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>PF</td><td>44</td><td>44</td></tr><tr><td>CT</td><td>150</td><td>166</td></tr><tr><td>BO</td><td>66</td><td>69</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>LGHT</td><td><table border="1"><tr><th>nplatforms</th><td>4</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>4</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>4</td><td>4</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>PF</td><td>4</td><td>4</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>PHOS</td><td><table border="1"><tr><th>nplatforms</th><td>44</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>44</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>44</td><td>44</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>CT</td><td>44</td><td>44</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>ATMP</td><td><table border="1"><tr><th>nplatforms</th><td>4</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>4</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>4</td><td>4</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>DB</td><td>4</td><td>4</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>TEMP</td><td><table border="1"><tr><th>nplatforms</th><td>311</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>333</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>33</td><td>35</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>MO</td><td>25</td><td>25</td></tr><tr><td>FB</td><td>1</td><td>3</td></tr><tr><td>DB</td><td>7</td><td>7</td></tr></tbody></table></td></tr><tr><td>PR</td><td>280</td><td>298</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>PF</td><td>44</td><td>44</td></tr><tr><td>CT</td><td>157</td><td>173</td></tr><tr><td>BO</td><td>66</td><td>68</td></tr><tr><td>XX</td><td>13</td><td>13</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>ATMS</td><td><table border="1"><tr><th>nplatforms</th><td>10</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>10</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>10</td><td>10</td><td><table border="1"><thead><tr><th>code< ...

# %% [markdown]
# Too much info? Choose one! `Run the next cells`...

# %%
code = 'TEMP'

# %%
selection = [param for param in parameters if param['code'] == code]
IPython.display.HTML(json2html.convert(selection))
# Out:
# <table border="1"><thead><tr><th>code</th><th>platforms</th></tr></thead><tbody><tr><td>TEMP</td><td><table border="1"><tr><th>nplatforms</th><td>311</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>333</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>33</td><td>35</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>MO</td><td>25</td><td>25</td></tr><tr><td>FB</td><td>1</td><td>3</td></tr><tr><td>DB</td><td>7</td><td>7</td></tr></tbody></table></td></tr><tr><td>PR</td><td>280</td><td>298</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>PF</td><td>44</td><td>44</td></tr><tr><td>CT</td><td>157</td><td>173</td></tr><tr><td>BO</td><td>66</td><td>68</td></tr><tr><td>XX</td><td>13</td><td>13</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr></tbody></table>

# %% [markdown]
# #### 3.3.5. Providers

# %% [markdown]
# Any Situ NRT products/datasets collections are composed by the files reported by a network of platforms located in the area. It is interesting always to know who are procuring these platforms and to aknowledge them!

# %% [markdown]
# Let's `run the next cell` to know how many *known* providers are contributting to this product/dataset collection with files:

# %%
providers_list = list(set(sum([str(provider).split(' ') for provider in targeted_collection_info['institution_edmo_code'].tolist() if str(provider).isdigit()],[])))
providers_list
# Out:
# ['731',
#  '540',
#  '4614',
#  '3577',
#  '1843',
#  '164',
#  '685',
#  '732',
#  '1054',
#  '1014',
#  '1368',
#  '2842',
#  '850',
#  '269',
#  '697',
#  '2688',
#  '961',
#  '486',
#  '191',
#  '681',
#  '120',
#  '727',
#  '733',
#  '3839',
#  '696']

# %% [markdown]
# Not clear at all, right? These numbers are identifiers provided by [SeaDatanet]('https://www.seadatanet.org/'). <br>
# Just check who is who by using SeaDataNet services: `run the next cell`!

# %%
code = '850' #change it by any other!
IPython.display.IFrame('https://edmo.seadatanet.org/report/'+code, width='100%', height=350)
# Out:
#         <iframe
#             width="100%"
#             height="350"
#             src="https://edmo.seadatanet.org/report/850"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# How much are they contributting to the product/datasetcollection?<br>`Run the next cells` to discover it!:

# %%
targeted_collection_info['institution_edmo_code'] = ' ' +targeted_collection_info['institution_edmo_code'].str.strip()+ ' '

# %%
providers = [{
    'code':code,
    'platforms':{
        'nplatforms': len(targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)].groupby('platform_code').groups.keys()),
        'files':{'nfiles': len(targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)]), 
        'feature(s)': [{'code': ftype, 'nplatforms':len(targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)].groupby('file_type').get_group(ftype).groupby('platform_code')), 'nfiles':len(targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)].groupby('file_type').get_group(ftype)),'sources(s)': [{'code': dtype, 'nplatforms': len(targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)].groupby('file_type').get_group(ftype).groupby('data_type').get_group(dtype).groupby('platform_code')), 'nfiles': len(targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)].groupby('file_type').get_group(ftype).groupby('data_type').get_group(dtype))} for dtype in targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)][targeted_collection_info['file_type']==ftype]['data_type'].unique().tolist()]} for ftype in targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)]['file_type'].unique().tolist()]}
    }
} for code in providers_list]

# %%
IPython.display.HTML(json2html.convert(providers))
# Out:
# <table border="1"><thead><tr><th>code</th><th>platforms</th></tr></thead><tbody><tr><td>731</td><td><table border="1"><tr><th>nplatforms</th><td>1</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>3</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>1</td><td>3</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>CT</td><td>1</td><td>3</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>540</td><td><table border="1"><tr><th>nplatforms</th><td>2</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>2</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>2</td><td>2</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>CT</td><td>2</td><td>2</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>4614</td><td><table border="1"><tr><th>nplatforms</th><td>4</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>4</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>4</td><td>4</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>PF</td><td>4</td><td>4</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>3577</td><td><table border="1"><tr><th>nplatforms</th><td>5</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>5</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>5</td><td>5</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>XX</td><td>5</td><td>5</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>1843</td><td><table border="1"><tr><th>nplatforms</th><td>21</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>23</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>8</td><td>8</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>TG</td><td>5</td><td>5</td></tr><tr><td>MO</td><td>2</td><td>2</td></tr><tr><td>FB</td><td>1</td><td>1</td></tr></tbody></table></td></tr><tr><td>PR</td><td>13</td><td>15</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>PF</td><td>12</td><td>12</td></tr><tr><td>CT</td><td>1</td><td>3</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>164</td><td><table border="1"><tr><th>nplatforms</th><td>1</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>1</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>BO</td><td>1</td><td>1</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>685</td><td><table border="1"><tr><th>nplatforms</th><td>1</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>3</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sou ...

# %% [markdown]
# Too much info? Choose one! `Run the next cells`...

# %%
code = '850'

# %%
selection = [provider for provider in providers if provider['code'] == code]
IPython.display.HTML(json2html.convert(selection))
# Out:
# <table border="1"><thead><tr><th>code</th><th>platforms</th></tr></thead><tbody><tr><td>850</td><td><table border="1"><tr><th>nplatforms</th><td>5</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>5</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>4</td><td>4</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>MO</td><td>4</td><td>4</td></tr></tbody></table></td></tr><tr><td>PR</td><td>1</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>PF</td><td>1</td><td>1</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr></tbody></table>

# %% [markdown]
# ---
#
# # 4. Wrap-up
#
# So far you should already know what to expect about this product/dataset/collection: platform network, file types, source types, parameters and providers.<br> `If you don't please ask us! it is the moment!`
# <br>In the next tutorial we will see how to retrieve the files comming from a certain platform, source, provider, matching a certain type of file or/and containing certain parameter. Ready? Let's go!

# %% [markdown]
# ---
#
# # 5. Next tutorial
#
# _Click on the hyperlink below to continue the training_
#
# [**13-02-NearRealTtime-product-subsetting-download.ipynb**](13-02-NearRealTtime-product-subsetting-download.ipynb)
