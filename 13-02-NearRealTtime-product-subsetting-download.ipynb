# %% [markdown]
# ![header](https://i.imgur.com/I4ake6d.jpg)

# %% [markdown]
# # IN SITU BLACK SEA TRAINING
# <div style="text-align: right"><i> 13-02-Part-two-out-of-five </i></div>

# %% [markdown]
# ***
# # BS `NRT` Product/dataset Subsetting & Download

# %% [markdown]
# ***
# **General Note 1**: Execute each cell through the <button class="btn btn-default btn-xs"><i class="icon-play fa fa-play"></i></button> button from the top MENU (or keyboard shortcut `Shift` + `Enter`).<br>
# <br>
# **General Note 2**: If, for any reason, the kernel is not working anymore, in the top MENU, click on the <button class="btn btn-default btn-xs"><i class="fa fa-repeat icon-repeat"></i></button> button. Then, in the top MENU, click on "Cell" and select "Run All Above Selected Cell".<br>
# ***

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc">
#     <ul class="toc-item">
#         <li><span><a href="#1.-Introduction" data-toc-modified-id="1.-Introduction">1. Introduction</a></span></li>
#         <li>
#             <span><a href="#2.-Setup" data-toc-modified-id="2.-Setup">2. Setup</a></span>
#             <ul>
#                 <li><span><a href="#2.1.-Python-packages" data-toc-modified-id="2.1.-Python-packages">2.1. Python packages</a></span></li>
#                 <li><span><a href="#2.2.-Copernicus-Database" data-toc-modified-id="2.2.-Copernicus-Database">2.2. Copernicus database</a></span></li>
#                 <li><span><a href="#2.3.-Auxiliary-functions" data-toc-modified-id="2.3.-Setup">2.3. Auxiliary functions</a></span></li>
#             </ul>
#         </li>
#         <li><span><a href="#3.-Getting-started" data-toc-modified-id="3.-Getting-started">3. Getting started</a></span></li>
#         <li><span><a href="#4.-Operations" data-toc-modified-id="4.-Operations">4. Operations</a></span>
#         <ul>
#             <li>
#             <span><a href="#4.1.-Subsetting" data-toc-modified-id="4.1.-Subsetting">4.1. Subsetting</a></span>
#             <ul>
#                 <li><span><a href="#4.1.1.-By-collection" data-toc-modified-id="4.1.1.-By-collection">4.1.1. By collection</a></span></li>
#                 <li><span><a href="#4.1.2.-By-time-range" data-toc-modified-id="4.1.2.-By-time-range">4.1.2. By time range</a></span></li>
#                 <li><span><a href="#4.1.3.-By-bounding-box" data-toc-modified-id="4.1.3.-By-bounding-box">4.1.3. By bounding-box</a></span></li>
#                 <li><span><a href="#4.1.4.-By-last-position" data-toc-modified-id="4.1.4.-By-last-position">4.1.4. By last position</a></span></li>
#                 <li><span><a href="#4.1.5.-By-data-type" data-toc-modified-id="4.1.5.-By-data-type">4.1.5. By data type</a></span></li>
#                 <li><span><a href="#4.1.6.-By-file-type" data-toc-modified-id="4.1.6.-By-file-type">4.1.6. By file type</a></span></li>
#                 <li><span><a href="#4.1.7.-By-parameter" data-toc-modified-id="4.1.7.-By-parameter">4.1.7. By parameter</a></span></li>
#                 <li><span><a href="#4.1.8.-By-platform-code" data-toc-modified-id="4.1.8.-By-platform-code">4.1.8. By platform code</a></span></li>
#                 <li><span><a href="#4.1.9.-By-provider" data-toc-modified-id="4.1.9.-By-provider">4.1.9. By provider</a></span></li>
#                 <li><span><a href="#4.1.10.-Subsetting-by-several-criterias-at-once" data-toc-modified-id="4.1.10.-Subsetting-by-several-criterias-at-once">4.1.10. By several criterias at once</a></span></li>
#             </ul>
#             </li>
#             <li><span><a href="#4.2.-Exporting" data-toc-modified-id="4.2.-Exporting">4.2. Exporting</a></span></li>
#             <li><span><a href="#4.3.-Downloading" data-toc-modified-id="4.3.-Downloading">4.3. Downloading</a></span></li>
#         </ul>
#         </li>
#         <li><span><a href="#5.-Wrap-up" data-toc-modified-id="5.-Wrap-up">5. Wrap-up</a></span></li>
#         <li><span><a href="#6.-Next-tutorial" data-toc-modified-id="6.-Next-tutorial">6. Next tutorial</a></span></li>
#     </ul>
# </div>

# %% [markdown]
# ***

# %% [markdown]
# ## 1. Introduction
#
# This notebook focus on selecting (subsetting) and downloading netCDF files from the available collections (`latest`, `monthly` and `history`) available within the In Situ Near Real Time product/dataset covering the Black Sea:`INSITU_BS_NRT_OBSERVATIONS_013_034`. Click [here](http://marine.copernicus.eu/services-portfolio/access-to-products/?option=com_csw&view=details&product_id=INSITU_BS_NRT_OBSERVATIONS_013_034) to  view the dedicated section of this product within the [CMEMS Catalog]('http://marine.copernicus.eu/services-portfolio/access-to-products/').

# %% [markdown]
# Any In Situ NRT product/dataset is just a bunch of netcdf files produced by the platforms (*drifters, profilers, gliders, moorings, HF-radars, vessels etc*) deployed in a certain area (in this case, the Black Sea); so many files that navigation/subsetting can be challenging.

# %% [markdown]
# | ![BS.gif](img/BS.gif)|
# |:--:|
# | *GIF of the location (point or trajectory) of the platforms providing near real time data in the BS area since 1922* |

# %% [markdown]
# To smooth the process of data discovery to users, the In Situ TAC provides a set of `index files` that describe the aforementioned netCDF collections. In addition to these index files, it is also possible to find further info regarding each platform contributting with files on the `index_platform.txt`.

# %% [markdown]
# | Index |  Description |
# | ------- | ----------- |
# | `index_latest.txt`  |  List of available files within the latest collection + metadata |
# | `index_monthly.txt`   | List of available files within the monthly collection + metadata |
# | `index_history.txt`   |  List of available files within the history collection + metadata |
# | `index_platform.txt`   | Full list of platforms + metadata |

# %% [markdown]
# Check more about these files in the <a href="https://archimer.ifremer.fr/doc/00324/43494/" target="_blank">Product User Manual</a>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>OBJECTIVE</b>
#
# ***
# To select and download only those netCDFs matching our needs from the whole original set of files that composes the BS NRT product/dataset by using the aforementioned index files.
# </div>

# %% [markdown]
# ## 2. Setup

# %% [markdown]
# ### 2.1. Python packages

# %% [markdown]
# For the notebook to properly run we need to first load the next packages available from the Jupyter Notebook Ecosystem. Please run the `next cell`:

# %%
import warnings
warnings.filterwarnings("ignore")

import IPython
import pandas as pd
import datetime
import random
import os
from collections import namedtuple
import ftputil
from shapely.geometry import box, Point
from urllib.parse import urlparse
import folium
from folium import plugins

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# If any of them raises any error it means you need to install the module first. For doing so please:
# 1. Open a new cell in the notebook
# 2. Run <i>`!conda install packageName --yes`</i> or <i>`!conda install -c conda-forge packageName --yes`</i> or <i>`!pip install packageName`</i>
# 3. Import again!
# <br><br>
# Example: <i>how-to-solve import error for json2html module </i>
#
# ![region.png](img/errorImporting.gif)
# </div>

# %% [markdown]
# ### 2.2. Copernicus Database

# %% [markdown]
# Please `set next your CMEMS User credentials` in the next cell and `run the cell` afterwards:

# %%
usr = 'inputHereYourCMEMSUser'
pas = 'inputHereYourCMEMSPassword'

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# **Don't you have credentials yet?** <br>Please go [here](https://resources.marine.copernicus.eu/?option=com_sla) to get the above credentials to be able to access CMEMS secured FTP server.
# </div>

# %% [markdown]
# As stated before, we will focus on the Near Real Time product/dataset covering the Iberian-Biscay-Ireland seas so, please `run the next` to load the info defining such product/dataset:

# %%
dataset = {
    'host': 'nrt.cmems-du.eu',#ftp host => nrt.cmems-du.eu for Near Real Time products
    'product': 'INSITU_BS_NRT_OBSERVATIONS_013_034',#name of the In Situ Near Real Time product in the BS area
    'name': 'bs_multiparameter_nrt',#name of the dataset available in the above In Situ Near Real Time product
    'index_files': ['index_latest.txt', 'index_monthly.txt', 'index_history.txt'],#files describing the content of the lastest, monthly and history netCDF file collections available withint he above dataset
    'index_platform': 'index_platform.txt',#files describing the netwotk of platforms contributting with files in the abve collections
}

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# In case you want to explore any other In Situ NRT product/dataset just set the above definitions accordingly and you will be able to reproduce the subsetting and downloading we will perform next.
# </div>

# %% [markdown]
# ### 2.3. Auxiliary functions

# %% [markdown]
# For exploring the product/dataset we will use a set of files called `index files` located in the CMEMS FTP server.

# %% [markdown]
# 1. **Download the index files**.
# In order to download the most updated version of these files we will use the next function. <br>Please `run the next cell` to load it (te funtion) in memory for later use:

# %%
def getIndexFiles(usr,pas,dataset,path2indexes):
    #Provides the index files available at the ftp server
    indexes = dataset['index_files'] + [dataset['index_platform']]
    with ftputil.FTPHost(dataset['host'], usr, pas) as ftp_host:  # connect to CMEMS FTP
        for index in indexes:
            remotefile= "/".join(['Core',dataset['product'],dataset['name'],index])
            print('.....Downloading ' + index)
            localfile = os.path.join(path2indexes,index)
            ftp_host.download(remotefile,localfile)  # remote, local
    print('Ready!')

# %% [markdown]
# 2. **Index files reader**.
# In order to load the information contained in *each* of the files we will use the next function. <br>Please `run the next cell` to load it in memory for later use:

# %%
def readIndexFileFromCWD(path2file):
    #Load as pandas dataframe the file in the provided path
    with open(path2file, 'rb') as f:
        filename = os.path.basename(path2file)
        print('...Loading info from: '+filename)
        raw_index_info = pd.read_csv(path2file, skiprows=5)
    return raw_index_info

# %% [markdown]
# 3. **Index files merger**.
# In order to load the information contained in *all* the indexes in a one single entity we will use the next function. <br>Please `run the next cell` to load it in memory for later use:

# %%
def getIndexFilesInfo(usr, pas, dataset,path2indexes):
    # Load and merge in a single entity all the information contained on each file descriptor of a given dataset
    # 1) Loading the index platform info as dataframe
    path2file = os.path.join(path2indexes, dataset['index_platform'])
    indexPlatform = readIndexFileFromCWD(path2file)
    indexPlatform.rename(columns={indexPlatform.columns[0]: "platform_code" }, inplace = True)
    indexPlatform = indexPlatform.drop_duplicates(subset='platform_code', keep="first")
    # 2) Loading the index files info as dataframes
    netcdf_collections = []
    for filename in dataset['index_files']:
        path2file = os.path.join(path2indexes,filename)
        indexFile = readIndexFileFromCWD(path2file)
        netcdf_collections.append(indexFile)
    netcdf_collections = pd.concat(netcdf_collections)
    # 3) creating new columns: derived info
    netcdf_collections['netcdf'] = netcdf_collections['file_name'].str.split('/').str[-1]
    netcdf_collections['file_type'] = netcdf_collections['netcdf'].str.split('.').str[0].str.split('_').str[1]
    netcdf_collections['data_type'] = netcdf_collections['netcdf'].str.split('.').str[0].str.split('_').str[2]
    netcdf_collections['platform_code'] = netcdf_collections['netcdf'].str.split('.').str[0].str.split('_').str[3]
    # 4) Merging the information of all files
    headers = ['platform_code','wmo_platform_code', 'institution_edmo_code', 'last_latitude_observation', 'last_longitude_observation','last_date_observation']
    result = pd.merge(netcdf_collections,indexPlatform[headers],on='platform_code')
    print('Ready!')
    return result

# %% [markdown]
# Also, let's load also the next functions as the are to be used later in the subsetting processing: `run the next cells`

# %% [markdown]
# <ul><li id="TemporalOverlap"><i>Time-Overlap</i> function definition</li></ul>

# %%
def timeOverlap(row, targeted_range):
    # Checks if a file contains data in the specified time range (targeted_range)
    date_format = "%Y-%m-%dT%H:%M:%SZ"
    targeted_ini = datetime.datetime.strptime(targeted_range.split('/')[0], date_format)
    targeted_end = datetime.datetime.strptime(targeted_range.split('/')[1], date_format)
    time_start = datetime.datetime.strptime(row['time_coverage_start'],date_format)
    time_end = datetime.datetime.strptime(row['time_coverage_end'],date_format)
    Range = namedtuple('Range', ['start', 'end'])
    r1 = Range(start=targeted_ini, end=targeted_end)
    r2 = Range(start=time_start, end=time_end)
    latest_start = max(r1.start, r2.start)
    earliest_end = min(r1.end, r2.end)
    delta = (earliest_end - latest_start).days + 1
    overlap = max(0, delta)
    if overlap != 0:
        return True
    else:
        return False

# %% [markdown]
# <ul><li id="SpatialOverlap"><i>Spatial-Overlap</i> function definition</li></ul>

# %%
def spatialOverlap(row, targeted_bbox):
    # Checks if a file contains data in the specified area (targeted_bbox)
    geospatial_lat_min = float(row['geospatial_lat_min'])
    geospatial_lat_max = float(row['geospatial_lat_max'])
    geospatial_lon_min = float(row['geospatial_lon_min'])
    geospatial_lon_max = float(row['geospatial_lon_max'])
    targeted_bounding_box = box(targeted_bbox[0], targeted_bbox[1],targeted_bbox[2], targeted_bbox[3])
    bounding_box = box(geospatial_lon_min, geospatial_lat_min,geospatial_lon_max, geospatial_lat_max)
    if targeted_bounding_box.intersects(bounding_box):  # check other rules on https://shapely.readthedocs.io/en/stable/manual.html
        return True
    else:
        return False

# %% [markdown]
# <ul><li id="LocationInRange"><i>LocationInRange</i> function definition</li></ul>

# %%
def lastLocationInRange(row, targeted_bbox):
    # Checks if a file has been produced by a platform whose last position is within the specified area (targeted_bbox)
    geospatial_lat = float(row['last_latitude_observation'])
    geospatial_lon = float(row['last_longitude_observation'])
    targeted_bounding_box = box(targeted_bbox[0], targeted_bbox[1],targeted_bbox[2], targeted_bbox[3])
    location = Point(geospatial_lon, geospatial_lat)
    if targeted_bounding_box.contains(location):#check other rules on https://shapely.readthedocs.io/en/stable/manual.html
        return True
    else:
        return False

# %% [markdown]
# ## 3. Getting started

# %% [markdown]
# For the analysis to be carried out we need the most recent version of the index files. By default we will save them into the `index_files` folder available in the `data` folder. Nevertheless if you rather use a different one set it next:

# %%
path2indexes= os.path.join(os.getcwd(),'data','index_files')#default path to save the files

# %% [markdown]
# Although in such folder we have provided already a copy of the files, **if you are running this notebook later than April 2020** please `Run the next` cell and download again the index files:

# %%
getIndexFiles(usr,pas,dataset,path2indexes)
# Out:
# .....Downloading index_latest.txt
# .....Downloading index_monthly.txt
# .....Downloading index_history.txt
# .....Downloading index_platform.txt
# Ready!

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# **Are you getting a `permission denied` error?**
# <br>Please be aware that no `writes` are authorized in the 'shared_notebook' folder. Make sure you run this on you own space after copying the notebooks form shared_notebooks. If you are still facing a problem contact us trough [Mattermost](https://chat-cmems.mercator-ocean.fr/).
# </div>

# %% [markdown]
# Let's load now into a dataframe the info contained in such files: `run the next cell!`

# %%
info = getIndexFilesInfo(usr, pas, dataset, path2indexes)
# Out:
# ...Loading info from: index_platform.txt
# ...Loading info from: index_latest.txt
# ...Loading info from: index_monthly.txt
# ...Loading info from: index_history.txt
# Ready!

# %% [markdown]
# `Run now the next cell` to see the information just loaded above:

# %%
info.transpose()
# Out:
#                                                                          0     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-13T06:00:00Z
# time_coverage_end                                        2021-01-13T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:00Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210113.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          1     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-14T06:00:00Z
# time_coverage_end                                        2021-01-14T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:09Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210114.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          2     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-15T12:00:00Z
# time_coverage_end                                        2021-01-15T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:17Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210115.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          3     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-16T06:00:00Z
# time_coverage_end                                        2021-01-16T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:24Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210116.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          4     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-17T06:00:00Z
# time_coverage_end                                        2021-01-17T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:32Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210117.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          5     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-18T06:00:00Z
# time_coverage_end                                        2021-01-18T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:40Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210118.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          6     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-19T06:00:00Z
# time_coverage_end                                        2021-01-19T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:48Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210119.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          7     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-20T06:00:00Z
# time_coverage_end                                        2021-01-20T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:56Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210120.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          8     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-21T06:00:00Z
# time_coverage_end                                        2021-01-21T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:30:04Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210121.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          9     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-22T06:00:00Z
# time_coverage_end                                        2021-01-22T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:30:11Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210122.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
#
#                                                                          3319  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     42.924
# geospatial_lat_max                                                     43.897
# geospatial_lon_min                                                     30.778
# geospatial_lon_max                                                     32.304
# time_coverage_start                                      2002-01-02T14:29:00Z
# time_coverage_end                                        2002-02-19T12:21:00Z
# institution                                 Naval Oceanographic Office (NAVO)
# date_update                                              2019-09-28T15:31:38Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61543.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61543
# wmo_platform_code                                                       61543
# institution_edmo_code                                                    3577
# last_latitude_observation                                              43.531
# last_longitude_observation                                             31.526
# last_date_observation                                    2002-02-19T12:21:00Z
#
#                                                                          3320  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     43.407
# geospatial_lat_max                                                     43.700
# geospatial_lon_min                                                     30.848
# geospatial_lon_max                                                     30.928
# time_coverage_start                                      2002-01-02T14:28:00Z
# time_coverage_end                                        2002-01-04T03:58:00Z
# institution                                 Naval Oceanographic Office (NAVO)
# date_update                                              2019-09-28T15:33:33Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61545.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61545
# wmo_platform_code                                                       61545
# institution_edmo_code                                                    3577
# last_latitude_observation                                              43.407
# last_longitude_observation                                             30.928
# last_date_observation                                    2002-01-04T03:58:00Z
#
#                                                                          3321  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.526
# geospatial_lat_max                                                     44.122
# geospatial_lon_min                                                     29.011
# geospatial_lon_max                                                     38.579
# time_coverage_start                                      2002-01-02T14:29:00Z
# time_coverage_end                                        2002-04-06T09:05:00Z
# institution                                 Naval Oceanographic Office (NAVO)
# date_update                                              2019-09-28T15:33:33Z
# data_mode                                                                   R
# parameters                                                     DEPH PRES TEMP
# netcdf                                                      GL_PR_XX_61546.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61546
# wmo_platform_code                                                       61546
# institution_edmo_code                                                    3577
# last_latitude_observation                                              42.111
# last_longitude_observation                                             38.579
# last_date_observation                                    2002-04-06T09:05:00Z
#
#                                                                          3322  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     42.598
# geospatial_lat_max                                                     43.262
# geospatial_lon_min                                                     30.430
# geospatial_lon_max                                                     31.611
# time_coverage_start                                      2002-01-02T14:29:00Z
# time_coverage_end                                        2002-01-29T06:00:00Z
# institution                                 Naval Oceanographic Office (NAVO)
# date_update                                              2019-09-28T15:33:33Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61547.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61547
# wmo_platform_code                                                       61547
# institution_edmo_code                                                    3577
# last_latitude_observation                                              42.755
# last_longitude_observation                                             30.530
# last_date_observation                                    2002-01-29T06:00:00Z
#
#                                                                          3323  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     42.365
# geospatial_lat_max                                                     43.259
# geospatial_lon_min                                                     30.253
# geospatial_lon_max                                                     35.011
# time_coverage_start                                      2002-01-02T14:28:00Z
# time_coverage_end                                        2002-03-30T06:13:00Z
# institution                                               Unknown institution
# date_update                                              2019-09-28T15:33:33Z
# data_mode                                                                   R
# parameters                                                     DEPH PRES TEMP
# netcdf                                                      GL_PR_XX_61549.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61549
# wmo_platform_code                                                       61549
# institution_edmo_code
# last_latitude_observation                                              42.812
# last_longitude_observation                                             35.011
# last_date_observation                                    2002-03-30T06:13:00Z
#
#                                                                          3324  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     44.410
# geospatial_lat_max                                                     44.882
# geospatial_lon_min                                                     29.637
# geospatial_lon_max                                                     32.906
# time_coverage_start                                      2013-11-21T14:00:00Z
# time_coverage_end                                        2014-01-09T13:00:00Z
# institution                                               Unknown institution
# date_update                                              2019-09-28T15:33:28Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61687.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61687
# wmo_platform_code                                                       61687
# institution_edmo_code
# last_latitude_observation                                              44.625
# last_longitude_observation                                             29.785
# last_date_observation                                    2014-01-09T13:00:00Z
#
#                                                                          3325  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     43.365
# geospatial_lat_max                                                     44.139
# geospatial_lon_min                                                     29.460
# geospatial_lon_max                                                     32.679
# time_coverage_start                                      2009-08-03T07:30:00Z
# time_coverage_end                                        2012-12-18T13:00:00Z
# institution                                               Unknown institution
# date_update                                              2021-01-24T20:36:13Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61689.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61689
# wmo_platform_code                                                       61689
# institution_edmo_code
# last_latitude_observation                                              44.078
# last_longitude_observation                                             32.536
# last_date_observation                                    2012-12-18T13:00:00Z
#
#                                                                          3326  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.436
# geospatial_lat_max                                                     44.810
# geospatial_lon_min                                                     28.527
# geospatial_lon_max                                                     38.362
# time_coverage_start                                      2009-08-03T07:30:00Z
# time_coverage_end                                        2014-05-28T02:00:00Z
# institution                                               Unknown institution
# date_update                                              2021-01-24T20:36:13Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61690.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61690
# wmo_platform_code                                                       61690
# institution_edmo_code
# last_latitude_observation                                              43.254
# last_longitude_observation                                             38.260
# last_date_observation                                    2014-05-28T02:00:00Z
#
#                                                                          3327  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.279
# geospatial_lat_max                                                     44.828
# geospatial_lon_min                                                     28.080
# geospatial_lon_max                                                     33.937
# time_coverage_start                                      2009-08-03T07:30:00Z
# time_coverage_end                                        2014-03-11T01:00:00Z
# institution                                               Unknown institution
# date_update                                              2019-09-28T15:33:28Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61691.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61691
# wmo_platform_code                                                       61691
# institution_edmo_code
# last_latitude_observation                                              41.279
# last_longitude_observation                                             29.474
# last_date_observation                                    2014-03-11T01:00:00Z
#
#                                                                          3328
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       44.4
# geospatial_lat_max                                                       44.4
# geospatial_lon_min                                                       32.7
# geospatial_lon_max                                                       32.7
# time_coverage_start                                      1999-03-25T10:08:00Z
# time_coverage_end                                        1999-03-25T10:08:00Z
# institution                                                  Russia (Unknown)
# date_update                                              2020-01-28T05:08:23Z
# data_mode                                                                   R
# parameters                                                          PRES TEMP
# netcdf                                                       GL_PR_XX_UZFA.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            UZFA
# wmo_platform_code                                                        UZFA
# institution_edmo_code
# last_latitude_observation                                                44.4
# last_longitude_observation                                               32.7
# last_date_observation                                    1999-03-25T10:08:00Z
#
# [21 rows x 3329 columns]

# %% [markdown]
# One of the most important fields in the above info is the `file_name`. This filed contains the full path to the file in the FTP server, saving users from having to know the actual FTP structure. As the above preview does not render such field completely, let's see the first file full path: `Run he next cell`

# %%
info['file_name'].tolist()[0]
# Out:
# 'ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSERVATIONS_013_034/bs_multiparameter_nrt/latest/20210113/BS_TS_MO_15360_20210113.nc'

# %% [markdown]
# Copy the path into the browser....the file will download straightaway!<br>
# Next we will aim:
# <ul><li>the `file_name` field (file path) for downloading operations</li>
#     <li> the other fileds (file metadata) for the subsetting operations</li>
# </ul>

# %% [markdown]
# ## 4. Operations

# %% [markdown]
# ### 4.1. Subsetting

# %% [markdown]
# Prior to <i>download</i> we need to select only those netCDF files that are of our interest.<br>There are many different criterias (if they contain a certain parameter, if they have covered a certain area, if they have data in a specific time range....).<br>Next we will see some examples...

# %% [markdown]
# #### 4.1.1. By collection

# %% [markdown]
# This restrict all available files to just one specific collection.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>IMPORTANT</b>
#
# ***
# Please remember available options:
# <ul>
#     <li><i>latest</i>: daily files from platforms (last 30 days of data)</li>
#     <li><i>monthly</i>: monthly files from platforms (last 5 years of data)</li>
#     <li><i>history</i>: one file per platform (all platform data)</li>
# </ul>
# </div>

# %% [markdown]
# `Set one collecion` next and `run the cells`:

# %%
targeted_collection = 'monthly' #try 'latest', 'monthly' or 'history'

# %%
condition = info['file_name'].str.contains(targeted_collection)
subset = info[condition]
subset.transpose()
# Out:
#                                                                          30    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.20
# geospatial_lat_max                                                      45.20
# geospatial_lon_min                                                      29.70
# geospatial_lon_max                                                      29.70
# time_coverage_start                                      2019-02-01T06:00:00Z
# time_coverage_end                                        2019-02-28T18:00:00Z
# institution                 NOAA / National Geophysical Data Center (NOAA/...
# date_update                                              2021-02-01T18:18:03Z
# data_mode                                                                   R
# parameters                                                DEPH TEMP VGHS VGTA
# netcdf                                               BS_TS_MO_15360_201807.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          31    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.20
# geospatial_lat_max                                                      45.20
# geospatial_lon_min                                                      29.70
# geospatial_lon_max                                                      29.70
# time_coverage_start                                      2018-08-16T06:00:00Z
# time_coverage_end                                        2018-08-31T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-01T18:18:18Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                               BS_TS_MO_15360_201808.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          32    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.20
# geospatial_lat_max                                                      45.20
# geospatial_lon_min                                                      29.70
# geospatial_lon_max                                                      29.70
# time_coverage_start                                      2018-09-01T06:00:00Z
# time_coverage_end                                        2018-09-30T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-01T18:18:34Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                               BS_TS_MO_15360_201809.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          33    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.20
# geospatial_lat_max                                                      45.20
# geospatial_lon_min                                                      29.70
# geospatial_lon_max                                                      29.70
# time_coverage_start                                      2018-10-01T06:00:00Z
# time_coverage_end                                        2018-10-31T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-01T18:18:48Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                               BS_TS_MO_15360_201810.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          34    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.20
# geospatial_lat_max                                                      45.20
# geospatial_lon_min                                                      29.70
# geospatial_lon_max                                                      29.70
# time_coverage_start                                      2018-11-01T06:00:00Z
# time_coverage_end                                        2018-11-30T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-01T18:19:03Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                               BS_TS_MO_15360_201811.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          35    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.20
# geospatial_lat_max                                                      45.20
# geospatial_lon_min                                                      29.70
# geospatial_lon_max                                                      29.70
# time_coverage_start                                      2018-12-01T06:00:00Z
# time_coverage_end                                        2018-12-31T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-01T18:19:18Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                               BS_TS_MO_15360_201812.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          36    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.20
# geospatial_lat_max                                                      45.20
# geospatial_lon_min                                                      29.70
# geospatial_lon_max                                                      29.70
# time_coverage_start                                      2019-01-01T06:00:00Z
# time_coverage_end                                        2019-01-31T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-01T18:19:32Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                               BS_TS_MO_15360_201901.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          37    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.20
# geospatial_lat_max                                                      45.20
# geospatial_lon_min                                                      29.70
# geospatial_lon_max                                                      29.70
# time_coverage_start                                      2019-02-01T06:00:00Z
# time_coverage_end                                        2019-02-28T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-01T18:19:47Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                               BS_TS_MO_15360_201902.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          38    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.20
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2019-03-06T06:00:00Z
# time_coverage_end                                        2019-03-05T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-01T18:20:02Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                               BS_TS_MO_15360_201903.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                                                                          39    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2019-04-01T06:00:00Z
# time_coverage_end                                        2019-04-30T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-01T18:20:16Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                               BS_TS_MO_15360_201904.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
#
#                                                                          3040  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    41.2922
# geospatial_lat_max                                                    41.2922
# geospatial_lon_min                                                    29.1656
# geospatial_lon_max                                                    29.1656
# time_coverage_start                                      2019-09-01T00:00:00Z
# time_coverage_end                                        2019-09-27T10:00:00Z
# institution                              Turkish State Meteorological Service
# date_update                                              2021-02-01T18:21:11Z
# data_mode                                                                   R
# parameters                                      DEPH VHM0 VZMX VPED VTZA VTPK
# netcdf                                               BS_TS_MO_17390_201909.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           17390
# wmo_platform_code                                                       17390
# institution_edmo_code                                                     176
# last_latitude_observation                                             41.2922
# last_longitude_observation                                            29.1656
# last_date_observation                                    2019-09-27T10:00:00Z
#
#                                                                          3041  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    43.2262
# geospatial_lat_max                                                    43.2262
# geospatial_lon_min                                                    28.0136
# geospatial_lon_max                                                    28.0136
# time_coverage_start                                      2019-08-01T00:02:47Z
# time_coverage_end                                        2019-08-31T23:57:18Z
# institution                                               Unknown institution
# date_update                                              2021-02-01T18:21:08Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                        BS_TS_TG_SD1013418031_201908.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                    SD1013418031
# wmo_platform_code
# institution_edmo_code
# last_latitude_observation                                             43.2262
# last_longitude_observation                                            28.0136
# last_date_observation                                    2019-10-31T23:58:47Z
#
#                                                                          3042  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    43.2262
# geospatial_lat_max                                                    43.2262
# geospatial_lon_min                                                    28.0136
# geospatial_lon_max                                                    28.0136
# time_coverage_start                                      2019-09-01T00:02:26Z
# time_coverage_end                                        2019-09-30T23:54:05Z
# institution                                               Unknown institution
# date_update                                              2021-02-01T18:21:18Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                        BS_TS_TG_SD1013418031_201909.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                    SD1013418031
# wmo_platform_code
# institution_edmo_code
# last_latitude_observation                                             43.2262
# last_longitude_observation                                            28.0136
# last_date_observation                                    2019-10-31T23:58:47Z
#
#                                                                          3043  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    43.2262
# geospatial_lat_max                                                    43.2262
# geospatial_lon_min                                                    28.0136
# geospatial_lon_max                                                    28.0136
# time_coverage_start                                      2019-10-01T00:04:19Z
# time_coverage_end                                        2019-10-31T23:58:47Z
# institution                                               Unknown institution
# date_update                                              2021-02-01T18:21:28Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                        BS_TS_TG_SD1013418031_201910.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                    SD1013418031
# wmo_platform_code
# institution_edmo_code
# last_latitude_observation                                             43.2262
# last_longitude_observation                                            28.0136
# last_date_observation                                    2019-10-31T23:58:47Z
#
#                                                                          3044  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   42.98113
# geospatial_lat_max                                                   43.03550
# geospatial_lon_min                                                   28.14636
# geospatial_lon_max                                                   28.23378
# time_coverage_start                                      2020-08-04T15:56:00Z
# time_coverage_end                                        2020-08-31T07:17:00Z
# institution                                                         Euro-Argo
# date_update                                              2021-02-02T13:16:14Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# netcdf                                             GL_PR_PF_6903865_202008.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6903865
# wmo_platform_code                                                     6903865
# institution_edmo_code                                                    4614
# last_latitude_observation                                            41.73716
# last_longitude_observation                                           29.36033
# last_date_observation                                    2020-10-23T09:42:20Z
#
#                                                                          3045  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   42.31381
# geospatial_lat_max                                                   43.03825
# geospatial_lon_min                                                   28.12732
# geospatial_lon_max                                                   28.81385
# time_coverage_start                                      2020-09-01T06:02:20Z
# time_coverage_end                                        2020-09-30T07:08:00Z
# institution                                                         Euro-Argo
# date_update                                              2021-02-02T13:16:14Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# netcdf                                             GL_PR_PF_6903865_202009.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6903865
# wmo_platform_code                                                     6903865
# institution_edmo_code                                                    4614
# last_latitude_observation                                            41.73716
# last_longitude_observation                                           29.36033
# last_date_observation                                    2020-10-23T09:42:20Z
#
#                                                                          3046  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   41.73716
# geospatial_lat_max                                                   42.28960
# geospatial_lon_min                                                   28.83680
# geospatial_lon_max                                                   29.36033
# time_coverage_start                                      2020-10-01T06:25:20Z
# time_coverage_end                                        2020-10-23T09:42:20Z
# institution                                                         Euro-Argo
# date_update                                              2021-02-03T13:13:44Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# netcdf                                             GL_PR_PF_6903865_202010.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6903865
# wmo_platform_code                                                     6903865
# institution_edmo_code                                                    4614
# last_latitude_observation                                            41.73716
# last_longitude_observation                                           29.36033
# last_date_observation                                    2020-10-23T09:42:20Z
#
#                                                                          3047  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   41.16307
# geospatial_lat_max                                                   41.16307
# geospatial_lon_min                                                   29.90438
# geospatial_lon_max                                                   29.90438
# time_coverage_start                                      2020-11-15T09:48:38Z
# time_coverage_end                                        2020-11-15T09:48:38Z
# institution                                                         Euro-Argo
# date_update                                              2021-02-03T13:13:42Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# netcdf                                             GL_PR_PF_6903865_202011.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6903865
# wmo_platform_code                                                     6903865
# institution_edmo_code                                                    4614
# last_latitude_observation                                            41.73716
# last_longitude_observation                                           29.36033
# last_date_observation                                    2020-10-23T09:42:20Z
#
#                                                                          3049  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    43.1754
# geospatial_lat_max                                                    42.5069
# geospatial_lon_min                                                    27.9090
# geospatial_lon_max                                                    27.9090
# time_coverage_start                                      2020-11-16T09:53:31Z
# time_coverage_end                                        2020-11-30T23:54:01Z
# institution                 Institute of Oceanology Bulgarian Academy of S...
# date_update                                              2021-02-01T18:23:27Z
# data_mode                                                                   R
# parameters                       DEPH TEMP VHM0 VTPK VMDR VPED VPSP WSPD WDIR
# netcdf                                            BS_TS_MO_SPOT0776_202011.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                        SPOT0776
# wmo_platform_code
# institution_edmo_code                                                    1843
# last_latitude_observation                                             42.5071
# last_longitude_observation                                            27.6350
# last_date_observation                                    2020-12-30T17:06:55Z
#
#                                                                          3050
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    42.5069
# geospatial_lat_max                                                    42.5071
# geospatial_lon_min                                                    27.6349
# geospatial_lon_max                                                    27.6349
# time_coverage_start                                      2020-12-01T00:24:01Z
# time_coverage_end                                        2020-12-30T17:06:55Z
# institution                 Institute of Oceanology Bulgarian Academy of S...
# date_update                                              2021-02-01T18:23:39Z
# data_mode                                                                   R
# parameters                       DEPH TEMP VHM0 VTPK VMDR VPED VPSP WSPD WDIR
# netcdf                                            BS_TS_MO_SPOT0776_202012.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                        SPOT0776
# wmo_platform_code
# institution_edmo_code                                                    1843
# last_latitude_observation                                             42.5071
# last_longitude_observation                                            27.6350
# last_date_observation                                    2020-12-30T17:06:55Z
#
# [21 rows x 2339 columns]

# %% [markdown]
# <div class="alert alert-block alert-info"">
# <b>TIP</b>
#
# ***
# To check if the above output only list the files coming from a certain collection (the one set as targeted_collection') just check the `netcdf` column
# <ul><li>'latest' timestamp: netcdf file name ends with a YYYYMMDD</li></ul>
# <ul><li>'monthly' timestamp: netcdf file name ends with a YYYYMM</li></ul>
# <ul><li>'history' timestamp: netcdf file name ends with a YYYY or none timestamp</li></ul>
# </div>

# %% [markdown]
# #### 4.1.2. By time range

# %% [markdown]
# Let's select only the files containing data within the next range of dates. <br>Please `set the start/end dates` you are interested in `and run the cells bellow`:

# %%
targeted_range = '2018-01-01T00:00:00Z/2019-01-01T23:59:59Z' #set your own!

# %%
info['timeOverlap'] = info.apply(timeOverlap,targeted_range=targeted_range,axis=1)
condition = info['timeOverlap'] == True
subset = info[condition]
subset.transpose()
# Out:
#                                                                          31    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.20
# geospatial_lat_max                                                      45.20
# geospatial_lon_min                                                      29.70
# geospatial_lon_max                                                      29.70
# time_coverage_start                                      2018-08-16T06:00:00Z
# time_coverage_end                                        2018-08-31T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-01T18:18:18Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                               BS_TS_MO_15360_201808.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
# timeOverlap                                                              True
#
#                                                                          32    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.20
# geospatial_lat_max                                                      45.20
# geospatial_lon_min                                                      29.70
# geospatial_lon_max                                                      29.70
# time_coverage_start                                      2018-09-01T06:00:00Z
# time_coverage_end                                        2018-09-30T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-01T18:18:34Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                               BS_TS_MO_15360_201809.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
# timeOverlap                                                              True
#
#                                                                          33    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.20
# geospatial_lat_max                                                      45.20
# geospatial_lon_min                                                      29.70
# geospatial_lon_max                                                      29.70
# time_coverage_start                                      2018-10-01T06:00:00Z
# time_coverage_end                                        2018-10-31T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-01T18:18:48Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                               BS_TS_MO_15360_201810.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
# timeOverlap                                                              True
#
#                                                                          34    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.20
# geospatial_lat_max                                                      45.20
# geospatial_lon_min                                                      29.70
# geospatial_lon_max                                                      29.70
# time_coverage_start                                      2018-11-01T06:00:00Z
# time_coverage_end                                        2018-11-30T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-01T18:19:03Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                               BS_TS_MO_15360_201811.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
# timeOverlap                                                              True
#
#                                                                          35    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.20
# geospatial_lat_max                                                      45.20
# geospatial_lon_min                                                      29.70
# geospatial_lon_max                                                      29.70
# time_coverage_start                                      2018-12-01T06:00:00Z
# time_coverage_end                                        2018-12-31T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-01T18:19:18Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                               BS_TS_MO_15360_201812.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
# timeOverlap                                                              True
#
#                                                                          36    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.20
# geospatial_lat_max                                                      45.20
# geospatial_lon_min                                                      29.70
# geospatial_lon_max                                                      29.70
# time_coverage_start                                      2019-01-01T06:00:00Z
# time_coverage_end                                        2019-01-31T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-01T18:19:32Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                               BS_TS_MO_15360_201901.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
# timeOverlap                                                              True
#
#                                                                          61    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.20
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.70
# geospatial_lon_max                                                      29.70
# time_coverage_start                                      2018-08-16T06:00:00Z
# time_coverage_end                                        2020-08-31T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-01-06T12:52:26Z
# data_mode                                                                   D
# parameters                                                          DEPH TEMP
# netcdf                                                      BS_TS_MO_15360.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
# timeOverlap                                                              True
#
#                                                                          87    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      44.70
# geospatial_lat_max                                                      44.70
# geospatial_lon_min                                                      29.00
# geospatial_lon_max                                                      29.00
# time_coverage_start                                      2018-08-17T12:00:00Z
# time_coverage_end                                        2018-08-31T12:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-01T18:18:19Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                               BS_TS_MO_15428_201808.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15428
# wmo_platform_code                                                       15428
# institution_edmo_code
# last_latitude_observation                                               44.68
# last_longitude_observation                                              28.98
# last_date_observation                                    2021-02-11T12:00:00Z
# timeOverlap                                                              True
#
#                                                                          88    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      44.70
# geospatial_lat_max                                                      44.70
# geospatial_lon_min                                                      29.00
# geospatial_lon_max                                                      29.00
# time_coverage_start                                      2018-09-01T12:00:00Z
# time_coverage_end                                        2018-09-30T12:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-01T18:18:34Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                               BS_TS_MO_15428_201809.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15428
# wmo_platform_code                                                       15428
# institution_edmo_code
# last_latitude_observation                                               44.68
# last_longitude_observation                                              28.98
# last_date_observation                                    2021-02-11T12:00:00Z
# timeOverlap                                                              True
#
#                                                                          89    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      44.70
# geospatial_lat_max                                                      44.70
# geospatial_lon_min                                                      29.00
# geospatial_lon_max                                                      29.00
# time_coverage_start                                      2018-10-01T12:00:00Z
# time_coverage_end                                        2018-10-31T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-01T18:18:49Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                               BS_TS_MO_15428_201810.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15428
# wmo_platform_code                                                       15428
# institution_edmo_code
# last_latitude_observation                                               44.68
# last_longitude_observation                                              28.98
# last_date_observation                                    2021-02-11T12:00:00Z
# timeOverlap                                                              True
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
#
#                                                                          3022  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       46.1
# geospatial_lat_max                                                       46.1
# geospatial_lon_min                                                       30.5
# geospatial_lon_max                                                       30.5
# time_coverage_start                                      2019-01-01T00:00:00Z
# time_coverage_end                                        2019-01-31T18:00:00Z
# institution                 NOAA / National Geophysical Data Center (NOAA/...
# date_update                                              2021-02-01T18:19:37Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP VGHS DRYT WSPD GSPD
# netcdf                                               BS_TS_MO_98004_201901.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           98004
# wmo_platform_code                                                       98004
# institution_edmo_code
# last_latitude_observation                                                46.1
# last_longitude_observation                                               30.5
# last_date_observation                                    2019-04-14T18:00:00Z
# timeOverlap                                                              True
#
#                                                                          3026  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       46.9
# geospatial_lat_max                                                       46.9
# geospatial_lon_min                                                       31.9
# geospatial_lon_max                                                       31.9
# time_coverage_start                                      2018-06-01T00:00:00Z
# time_coverage_end                                        2018-06-30T18:00:00Z
# institution                 NOAA / National Geophysical Data Center (NOAA/...
# date_update                                              2021-02-01T18:17:50Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP VGHS DRYT WSPD GSPD
# netcdf                                               BS_TS_MO_98027_201806.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           98027
# wmo_platform_code                                                       98027
# institution_edmo_code
# last_latitude_observation                                                46.9
# last_longitude_observation                                               31.9
# last_date_observation                                    2019-04-14T18:00:00Z
# timeOverlap                                                              True
#
#                                                                          3027  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       46.9
# geospatial_lat_max                                                       46.9
# geospatial_lon_min                                                       31.9
# geospatial_lon_max                                                       31.9
# time_coverage_start                                      2018-07-01T00:00:00Z
# time_coverage_end                                        2018-07-31T18:00:00Z
# institution                 NOAA / National Geophysical Data Center (NOAA/...
# date_update                                              2021-02-01T18:18:08Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP VGHS DRYT WSPD GSPD
# netcdf                                               BS_TS_MO_98027_201807.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           98027
# wmo_platform_code                                                       98027
# institution_edmo_code
# last_latitude_observation                                                46.9
# last_longitude_observation                                               31.9
# last_date_observation                                    2019-04-14T18:00:00Z
# timeOverlap                                                              True
#
#                                                                          3028  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       46.9
# geospatial_lat_max                                                       46.9
# geospatial_lon_min                                                       31.9
# geospatial_lon_max                                                       31.9
# time_coverage_start                                      2018-08-01T00:00:00Z
# time_coverage_end                                        2018-08-31T18:00:00Z
# institution                 NOAA / National Geophysical Data Center (NOAA/...
# date_update                                              2021-02-01T18:18:23Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP VGHS DRYT WSPD GSPD
# netcdf                                               BS_TS_MO_98027_201808.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           98027
# wmo_platform_code                                                       98027
# institution_edmo_code
# last_latitude_observation                                                46.9
# last_longitude_observation                                               31.9
# last_date_observation                                    2019-04-14T18:00:00Z
# timeOverlap                                                              True
#
#                                                                          3029  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       46.9
# geospatial_lat_max                                                       46.9
# geospatial_lon_min                                                       31.9
# geospatial_lon_max                                                       31.9
# time_coverage_start                                      2018-09-01T00:00:00Z
# time_coverage_end                                        2018-09-30T18:00:00Z
# institution                 NOAA / National Geophysical Data Center (NOAA/...
# date_update                                              2021-02-01T18:18:39Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP VGHS DRYT WSPD GSPD
# netcdf                                               BS_TS_MO_98027_201809.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           98027
# wmo_platform_code                                                       98027
# institution_edmo_code
# last_latitude_observation                                                46.9
# last_longitude_observation                                               31.9
# last_date_observation                                    2019-04-14T18:00:00Z
# timeOverlap                                                              True
#
#                                                                          3030  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       46.9
# geospatial_lat_max                                                       46.9
# geospatial_lon_min                                                       31.9
# geospatial_lon_max                                                       31.9
# time_coverage_start                                      2018-10-01T00:00:00Z
# time_coverage_end                                        2018-10-31T18:00:00Z
# institution                 NOAA / National Geophysical Data Center (NOAA/...
# date_update                                              2021-02-01T18:18:53Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP VGHS DRYT WSPD GSPD
# netcdf                                               BS_TS_MO_98027_201810.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           98027
# wmo_platform_code                                                       98027
# institution_edmo_code
# last_latitude_observation                                                46.9
# last_longitude_observation                                               31.9
# last_date_observation                                    2019-04-14T18:00:00Z
# timeOverlap                                                              True
#
#                                                                          3031  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       46.9
# geospatial_lat_max                                                       46.9
# geospatial_lon_min                                                       31.9
# geospatial_lon_max                                                       31.9
# time_coverage_start                                      2018-11-01T00:00:00Z
# time_coverage_end                                        2018-11-30T18:00:00Z
# institution                 NOAA / National Geophysical Data Center (NOAA/...
# date_update                                              2021-02-01T18:19:08Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP VGHS DRYT WSPD GSPD
# netcdf                                               BS_TS_MO_98027_201811.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           98027
# wmo_platform_code                                                       98027
# institution_edmo_code
# last_latitude_observation                                                46.9
# last_longitude_observation                                               31.9
# last_date_observation                                    2019-04-14T18:00:00Z
# timeOverlap                                                              True
#
#                                                                          3032  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       46.9
# geospatial_lat_max                                                       46.9
# geospatial_lon_min                                                       31.9
# geospatial_lon_max                                                       31.9
# time_coverage_start                                      2018-12-01T00:00:00Z
# time_coverage_end                                        2018-12-31T18:00:00Z
# institution                 NOAA / National Geophysical Data Center (NOAA/...
# date_update                                              2021-02-01T18:19:22Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP VGHS DRYT WSPD GSPD
# netcdf                                               BS_TS_MO_98027_201812.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           98027
# wmo_platform_code                                                       98027
# institution_edmo_code
# last_latitude_observation                                                46.9
# last_longitude_observation                                               31.9
# last_date_observation                                    2019-04-14T18:00:00Z
# timeOverlap                                                              True
#
#                                                                          3033  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       46.9
# geospatial_lat_max                                                       46.9
# geospatial_lon_min                                                       31.9
# geospatial_lon_max                                                       31.9
# time_coverage_start                                      2019-01-01T00:00:00Z
# time_coverage_end                                        2019-01-31T18:00:00Z
# institution                 NOAA / National Geophysical Data Center (NOAA/...
# date_update                                              2021-02-01T18:19:37Z
# data_mode                                                                   R
# parameters                                      DEPH TEMP VGHS DRYT WSPD GSPD
# netcdf                                               BS_TS_MO_98027_201901.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           98027
# wmo_platform_code                                                       98027
# institution_edmo_code
# last_latitude_observation                                                46.9
# last_longitude_observation                                               31.9
# last_date_observation                                    2019-04-14T18:00:00Z
# timeOverlap                                                              True
#
#                                                                          3037
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     42.551
# geospatial_lat_max                                                     42.551
# geospatial_lon_min                                                     27.639
# geospatial_lon_max                                                     27.639
# time_coverage_start                                      2018-06-01T00:01:00Z
# time_coverage_end                                        2018-06-04T14:57:00Z
# institution                 Institute of Oceanology  Bulgarian Academy of ...
# date_update                                              2021-02-01T18:18:00Z
# data_mode                                                                   R
# parameters                                                DEPH TEMP PSAL SLEV
# netcdf                                             BS_TS_TG_Pomorie_201806.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                         Pomorie
# wmo_platform_code
# institution_edmo_code                                                    1843
# last_latitude_observation                                              42.551
# last_longitude_observation                                             27.639
# last_date_observation                                    2018-06-04T14:57:00Z
# timeOverlap                                                              True
#
# [22 rows x 644 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the above output only list the files containing data within a certain time range (the one set as 'targeted_range') just check `time_coverage_start` and `time_coverage_end` columns.
# </div>

# %% [markdown]
# #### 4.1.3. By bounding-box

# %% [markdown]
# Let's look for files containing data from a specific area.<br>`Please set your own area limits` next `and run the cell`:

# %%
targeted_geospatial_lat_min = 43.0  # enter min latitude of your bounding box
targeted_geospatial_lat_max = 45.0  # enter max latitude of your bounding box
targeted_geospatial_lon_min = 28.0  # enter min longitude of your bounding box
targeted_geospatial_lon_max = 30.0  # enter max longitude of your bounding box
targeted_bbox = [targeted_geospatial_lon_min, targeted_geospatial_lat_min, targeted_geospatial_lon_max, targeted_geospatial_lat_max]  # (minx, miny, maxx, maxy)

# %% [markdown]
# Let's see the area you have set before: `run the next cell`

# %%
m = folium.Map(location=[39.0, 0], zoom_start=4)
upper_left = [targeted_geospatial_lat_max, targeted_geospatial_lon_min]
upper_right = [targeted_geospatial_lat_max, targeted_geospatial_lon_max]
lower_right = [targeted_geospatial_lat_min, targeted_geospatial_lon_max]
lower_left = [targeted_geospatial_lat_min, targeted_geospatial_lon_min]
edges_ = [upper_left, upper_right, lower_right, lower_left]
m.add_child(folium.vector_layers.Polygon(locations=edges_))
#Zooming closer
m.fit_bounds(edges_, max_zoom=5)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e88e8bae9792454fb087f03ee70b4249%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e88e8bae9792454fb087f03ee70b4249%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e88e8bae9792454fb087f03ee70b4249%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e88e8bae9792454fb087f03ee70b4249%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.0%2C%200.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# If you do not see any map when running the next cell please change your navigator (try chrome!).
# </div>

# %% [markdown]
# `Run the next cell` to obtain the subset of files with data in such area:

# %%
info['spatialOverlap'] = info.apply(spatialOverlap,targeted_bbox=targeted_bbox,axis=1)
condition = info['spatialOverlap'] == True
subset = info[condition]
subset.transpose()
# Out:
#                                                                          62    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      44.68
# geospatial_lat_max                                                      44.68
# geospatial_lon_min                                                      28.98
# geospatial_lon_max                                                      28.98
# time_coverage_start                                      2021-01-13T06:00:00Z
# time_coverage_end                                        2021-01-13T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:01Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15428_20210113.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15428
# wmo_platform_code                                                       15428
# institution_edmo_code
# last_latitude_observation                                               44.68
# last_longitude_observation                                              28.98
# last_date_observation                                    2021-02-11T12:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                          63    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      44.68
# geospatial_lat_max                                                      44.68
# geospatial_lon_min                                                      28.98
# geospatial_lon_max                                                      28.98
# time_coverage_start                                      2021-01-14T06:00:00Z
# time_coverage_end                                        2021-01-14T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:09Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15428_20210114.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15428
# wmo_platform_code                                                       15428
# institution_edmo_code
# last_latitude_observation                                               44.68
# last_longitude_observation                                              28.98
# last_date_observation                                    2021-02-11T12:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                          64    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      44.68
# geospatial_lat_max                                                      44.68
# geospatial_lon_min                                                      28.98
# geospatial_lon_max                                                      28.98
# time_coverage_start                                      2021-01-15T12:00:00Z
# time_coverage_end                                        2021-01-15T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:17Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15428_20210115.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15428
# wmo_platform_code                                                       15428
# institution_edmo_code
# last_latitude_observation                                               44.68
# last_longitude_observation                                              28.98
# last_date_observation                                    2021-02-11T12:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                          65    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      44.68
# geospatial_lat_max                                                      44.68
# geospatial_lon_min                                                      28.98
# geospatial_lon_max                                                      28.98
# time_coverage_start                                      2021-01-16T12:00:00Z
# time_coverage_end                                        2021-01-16T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:25Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15428_20210116.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15428
# wmo_platform_code                                                       15428
# institution_edmo_code
# last_latitude_observation                                               44.68
# last_longitude_observation                                              28.98
# last_date_observation                                    2021-02-11T12:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                          66    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      44.68
# geospatial_lat_max                                                      44.68
# geospatial_lon_min                                                      28.98
# geospatial_lon_max                                                      28.98
# time_coverage_start                                      2021-01-17T12:00:00Z
# time_coverage_end                                        2021-01-17T12:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:32Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15428_20210117.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15428
# wmo_platform_code                                                       15428
# institution_edmo_code
# last_latitude_observation                                               44.68
# last_longitude_observation                                              28.98
# last_date_observation                                    2021-02-11T12:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                          67    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      44.68
# geospatial_lat_max                                                      44.68
# geospatial_lon_min                                                      28.98
# geospatial_lon_max                                                      28.98
# time_coverage_start                                      2021-01-18T12:00:00Z
# time_coverage_end                                        2021-01-18T12:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:40Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15428_20210118.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15428
# wmo_platform_code                                                       15428
# institution_edmo_code
# last_latitude_observation                                               44.68
# last_longitude_observation                                              28.98
# last_date_observation                                    2021-02-11T12:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                          68    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      44.68
# geospatial_lat_max                                                      44.68
# geospatial_lon_min                                                      28.98
# geospatial_lon_max                                                      28.98
# time_coverage_start                                      2021-01-19T12:00:00Z
# time_coverage_end                                        2021-01-19T12:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:48Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15428_20210119.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15428
# wmo_platform_code                                                       15428
# institution_edmo_code
# last_latitude_observation                                               44.68
# last_longitude_observation                                              28.98
# last_date_observation                                    2021-02-11T12:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                          69    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      44.68
# geospatial_lat_max                                                      44.68
# geospatial_lon_min                                                      28.98
# geospatial_lon_max                                                      28.98
# time_coverage_start                                      2021-01-20T12:00:00Z
# time_coverage_end                                        2021-01-20T12:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:56Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15428_20210120.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15428
# wmo_platform_code                                                       15428
# institution_edmo_code
# last_latitude_observation                                               44.68
# last_longitude_observation                                              28.98
# last_date_observation                                    2021-02-11T12:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                          70    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      44.68
# geospatial_lat_max                                                      44.68
# geospatial_lon_min                                                      28.98
# geospatial_lon_max                                                      28.98
# time_coverage_start                                      2021-01-25T12:00:00Z
# time_coverage_end                                        2021-01-25T12:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:30:33Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15428_20210125.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15428
# wmo_platform_code                                                       15428
# institution_edmo_code
# last_latitude_observation                                               44.68
# last_longitude_observation                                              28.98
# last_date_observation                                    2021-02-11T12:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                          71    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      44.68
# geospatial_lat_max                                                      44.68
# geospatial_lon_min                                                      28.98
# geospatial_lon_max                                                      28.98
# time_coverage_start                                      2021-01-28T06:00:00Z
# time_coverage_end                                        2021-01-28T12:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:30:51Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15428_20210128.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15428
# wmo_platform_code                                                       15428
# institution_edmo_code
# last_latitude_observation                                               44.68
# last_longitude_observation                                              28.98
# last_date_observation                                    2021-02-11T12:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
# spatialOverlap              ...
#
#                                                                          3308  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.214
# geospatial_lat_max                                                     43.466
# geospatial_lon_min                                                     28.554
# geospatial_lon_max                                                     41.421
# time_coverage_start                                      2012-06-08T12:55:00Z
# time_coverage_end                                        2015-04-21T06:48:00Z
# institution                 OGS Istituto Nazionale di Oceanografia e di Ge...
# date_update                                              2019-12-22T19:39:18Z
# data_mode                                                                   D
# parameters                  PRES TEMP PSAL PRES_ADJUSTED PRES_ADJUSTED_ERR...
# netcdf                                                    GL_PR_PF_6901959.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901959
# wmo_platform_code                                                     6901959
# institution_edmo_code                                                     120
# last_latitude_observation                                              43.271
# last_longitude_observation                                             40.021
# last_date_observation                                    2015-04-21T06:48:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                          3309  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     42.093
# geospatial_lat_max                                                     43.216
# geospatial_lon_min                                                     27.821
# geospatial_lon_max                                                     29.638
# time_coverage_start                                      2012-06-09T11:45:00Z
# time_coverage_end                                        2012-10-14T06:15:00Z
# institution                 OGS Istituto Nazionale di Oceanografia e di Ge...
# date_update                                              2019-05-07T22:55:39Z
# data_mode                                                                   D
# parameters                  PRES TEMP PSAL PRES_ADJUSTED PRES_ADJUSTED_ERR...
# netcdf                                                    GL_PR_PF_6901960.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901960
# wmo_platform_code                                                     6901960
# institution_edmo_code                                                     120
# last_latitude_observation                                              42.263
# last_longitude_observation                                             27.821
# last_date_observation                                    2012-10-09T06:27:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                          3310  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.269
# geospatial_lat_max                                                     44.829
# geospatial_lon_min                                                     29.028
# geospatial_lon_max                                                     40.889
# time_coverage_start                                      2012-11-06T22:50:00Z
# time_coverage_end                                        2015-09-19T06:57:00Z
# institution                 OGS Istituto Nazionale di Oceanografia e di Ge...
# date_update                                              2020-02-23T18:37:33Z
# data_mode                                                                   D
# parameters                  PRES TEMP PSAL PRES_ADJUSTED PRES_ADJUSTED_ERR...
# netcdf                                                    GL_PR_PF_6901961.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901961
# wmo_platform_code                                                     6901961
# institution_edmo_code                                                     120
# last_latitude_observation                                              42.166
# last_longitude_observation                                             39.798
# last_date_observation                                    2015-09-19T06:57:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                          3311  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.024
# geospatial_lat_max                                                     44.738
# geospatial_lon_min                                                     28.409
# geospatial_lon_max                                                     41.492
# time_coverage_start                                      2012-08-17T05:34:00Z
# time_coverage_end                                        2015-07-20T06:41:00Z
# institution                 OGS Istituto Nazionale di Oceanografia e di Ge...
# date_update                                              2020-02-23T18:37:34Z
# data_mode                                                                   D
# parameters                  PRES PSAL_ADJUSTED_ERROR PSAL PRES_ADJUSTED_ER...
# netcdf                                                    GL_PR_PF_6901962.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901962
# wmo_platform_code                                                     6901962
# institution_edmo_code                                                     120
# last_latitude_observation                                              42.776
# last_longitude_observation                                             41.245
# last_date_observation                                    2015-07-20T06:41:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                          3313  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   41.19950
# geospatial_lat_max                                                   44.40115
# geospatial_lon_min                                                   28.45000
# geospatial_lon_max                                                   36.83396
# time_coverage_start                                      2009-06-06T11:17:29Z
# time_coverage_end                                        2012-11-27T12:22:22Z
# institution                 Helmholtz-Zentrum Geesthacht - Centre for Mate...
# date_update                                              2019-09-28T08:30:39Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# netcdf                                                    GL_PR_PF_7900466.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900466
# wmo_platform_code                                                     7900466
# institution_edmo_code                                                    2842
# last_latitude_observation                                            41.97348
# last_longitude_observation                                           36.83396
# last_date_observation                                    2012-11-27T12:22:22Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                          3321  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.526
# geospatial_lat_max                                                     44.122
# geospatial_lon_min                                                     29.011
# geospatial_lon_max                                                     38.579
# time_coverage_start                                      2002-01-02T14:29:00Z
# time_coverage_end                                        2002-04-06T09:05:00Z
# institution                                 Naval Oceanographic Office (NAVO)
# date_update                                              2019-09-28T15:33:33Z
# data_mode                                                                   R
# parameters                                                     DEPH PRES TEMP
# netcdf                                                      GL_PR_XX_61546.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61546
# wmo_platform_code                                                       61546
# institution_edmo_code                                                    3577
# last_latitude_observation                                              42.111
# last_longitude_observation                                             38.579
# last_date_observation                                    2002-04-06T09:05:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                          3324  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     44.410
# geospatial_lat_max                                                     44.882
# geospatial_lon_min                                                     29.637
# geospatial_lon_max                                                     32.906
# time_coverage_start                                      2013-11-21T14:00:00Z
# time_coverage_end                                        2014-01-09T13:00:00Z
# institution                                               Unknown institution
# date_update                                              2019-09-28T15:33:28Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61687.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61687
# wmo_platform_code                                                       61687
# institution_edmo_code
# last_latitude_observation                                              44.625
# last_longitude_observation                                             29.785
# last_date_observation                                    2014-01-09T13:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                          3325  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     43.365
# geospatial_lat_max                                                     44.139
# geospatial_lon_min                                                     29.460
# geospatial_lon_max                                                     32.679
# time_coverage_start                                      2009-08-03T07:30:00Z
# time_coverage_end                                        2012-12-18T13:00:00Z
# institution                                               Unknown institution
# date_update                                              2021-01-24T20:36:13Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61689.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61689
# wmo_platform_code                                                       61689
# institution_edmo_code
# last_latitude_observation                                              44.078
# last_longitude_observation                                             32.536
# last_date_observation                                    2012-12-18T13:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                          3326  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.436
# geospatial_lat_max                                                     44.810
# geospatial_lon_min                                                     28.527
# geospatial_lon_max                                                     38.362
# time_coverage_start                                      2009-08-03T07:30:00Z
# time_coverage_end                                        2014-05-28T02:00:00Z
# institution                                               Unknown institution
# date_update                                              2021-01-24T20:36:13Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61690.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61690
# wmo_platform_code                                                       61690
# institution_edmo_code
# last_latitude_observation                                              43.254
# last_longitude_observation                                             38.260
# last_date_observation                                    2014-05-28T02:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                          3327
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.279
# geospatial_lat_max                                                     44.828
# geospatial_lon_min                                                     28.080
# geospatial_lon_max                                                     33.937
# time_coverage_start                                      2009-08-03T07:30:00Z
# time_coverage_end                                        2014-03-11T01:00:00Z
# institution                                               Unknown institution
# date_update                                              2019-09-28T15:33:28Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_PR_XX_61691.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                           61691
# wmo_platform_code                                                       61691
# institution_edmo_code
# last_latitude_observation                                              41.279
# last_longitude_observation                                             29.474
# last_date_observation                                    2014-03-11T01:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
# [23 rows x 772 columns]

# %% [markdown]
# Let's check now if the bbox of the above files truely overlaps with the targeted area!: `run the next cells`

# %%
numberOfFiles = 300 #we will check just a sample of files not all as there might be too many

# %%
m = folium.Map(location=[39.0, 0], zoom_start=6)
m.add_child(folium.vector_layers.Polygon(locations=edges_))
for platform, files in subset[:numberOfFiles].groupby(['platform_code', 'data_type']):
    color = "%06x" % random.randint(0, 0xFFFFFF)
    for i in range(0, len(files)):
        netcdf = files.iloc[i]['file_name'].split('/')[-1]
        upper_left = [
            files.iloc[i]['geospatial_lat_max'],
            files.iloc[i]['geospatial_lon_min']
        ]
        upper_right = [
            files.iloc[i]['geospatial_lat_max'],
            files.iloc[i]['geospatial_lon_max']
        ]
        lower_right = [
            files.iloc[i]['geospatial_lat_min'],
            files.iloc[i]['geospatial_lon_max']
        ]
        lower_left = [
            files.iloc[i]['geospatial_lat_min'],
            files.iloc[i]['geospatial_lon_min']
        ]
        edges = [upper_left, upper_right, lower_right, lower_left]
        popup_info = '<b>netcdf</b>: ' + files.iloc[i]['netcdf']
        m.add_child(folium.vector_layers.Polygon(locations=edges,color='#' + color,popup=(folium.Popup(popup_info))))
        m.fit_bounds(edges, max_zoom=6)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_9cf9c4572cd5413eac00dd7842c4b162%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9cf9c4572cd5413eac00dd7842c4b162%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_9cf9c4572cd5413eac00dd7842c4b162%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_9cf9c4572cd5413eac00dd7842c4b162%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.0%2C%200.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# If you do not see any map when running the next cell please change your navigator (try chrome!).
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if everything went well, just check if the files bbox is indeed at some point within the one you were interested in (targeted bbox)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>IMPORTANT</b>
#
# ***
# If you are not satisfied with the resulting output (i.e you want to get only the files whose bbox is completely within the targeted area) please revisit the [definition of the SpatialOverlap](#SpatialOverlap) function and replace the rule applied (`intersects`) by any of the available ones [here](https://shapely.readthedocs.io/en/stable/manual.html#binary-predicates)
# </div>

# %% [markdown]
# #### 4.1.4. By last position

# %% [markdown]
# Let's look for files produced by a platform whose last position is within a specific area.<br>`Please set your own area limits` next `and run the cell`:

# %%
targeted_geospatial_lat_min = 45.0  # enter min latitude of your bounding box
targeted_geospatial_lat_max = 48.0  # enter max latitude of your bounding box
targeted_geospatial_lon_min = 34.5  # enter min longitude of your bounding box
targeted_geospatial_lon_max = 40.0  # enter max longitude of your bounding box
targeted_bbox = [targeted_geospatial_lon_min, targeted_geospatial_lat_min, targeted_geospatial_lon_max, targeted_geospatial_lat_max]  # (minx, miny, maxx, maxy)

# %% [markdown]
# Let's see the area you have set before: `run the next cell`

# %%
m = folium.Map(location=[39.0, 0], zoom_start=4)
upper_left = [targeted_geospatial_lat_max, targeted_geospatial_lon_min]
upper_right = [targeted_geospatial_lat_max, targeted_geospatial_lon_max]
lower_right = [targeted_geospatial_lat_min, targeted_geospatial_lon_max]
lower_left = [targeted_geospatial_lat_min, targeted_geospatial_lon_min]
edges_ = [upper_left, upper_right, lower_right, lower_left]
m.add_child(folium.vector_layers.Polygon(locations=edges_))
#Zooming closer
m.fit_bounds(edges_, max_zoom=5)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7f99d196e79140988bb0d29a68be1f7e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7f99d196e79140988bb0d29a68be1f7e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7f99d196e79140988bb0d29a68be1f7e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_7f99d196e79140988bb0d29a68be1f7e%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.0%2C%200.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# If you do not see any map when running the next cell please change your navigator (try chrome!).
# </div>

# %% [markdown]
# `Run the next cell` to obtain the subset of files with data in such area:

# %%
info['lastLocationInRange'] = info.apply(lastLocationInRange,targeted_bbox=targeted_bbox,axis=1)
condition = info['lastLocationInRange'] == True
subset = info[condition]
subset.transpose()
# Out:
#                                                                          1623  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       45.1
# geospatial_lat_max                                                       45.1
# geospatial_lon_min                                                       36.4
# geospatial_lon_max                                                       36.4
# time_coverage_start                                      2016-01-01T06:00:00Z
# time_coverage_end                                        2016-01-31T06:00:00Z
# institution                 All-Russia Research Institute of Hydrometeorol...
# date_update                                              2021-02-01T18:12:37Z
# data_mode                                                                   R
# parameters                                           DEPH VGHS VEMH VGTA VDIR
# netcdf                                               BS_TS_MO_99001_201601.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           99001
# wmo_platform_code
# institution_edmo_code                                                     681
# last_latitude_observation                                                45.1
# last_longitude_observation                                               36.4
# last_date_observation                                    2018-06-30T18:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          1624  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       45.1
# geospatial_lat_max                                                       45.1
# geospatial_lon_min                                                       36.4
# geospatial_lon_max                                                       36.4
# time_coverage_start                                      2016-02-01T06:00:00Z
# time_coverage_end                                        2016-02-29T06:00:00Z
# institution                 All-Russia Research Institute of Hydrometeorol...
# date_update                                              2021-02-01T18:12:46Z
# data_mode                                                                   R
# parameters                                           DEPH VGHS VEMH VGTA VDIR
# netcdf                                               BS_TS_MO_99001_201602.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           99001
# wmo_platform_code
# institution_edmo_code                                                     681
# last_latitude_observation                                                45.1
# last_longitude_observation                                               36.4
# last_date_observation                                    2018-06-30T18:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          1625  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       45.1
# geospatial_lat_max                                                       45.1
# geospatial_lon_min                                                       36.4
# geospatial_lon_max                                                       36.4
# time_coverage_start                                      2016-03-01T06:00:00Z
# time_coverage_end                                        2016-03-31T18:00:00Z
# institution                 All-Russia Research Institute of Hydrometeorol...
# date_update                                              2021-02-01T18:12:56Z
# data_mode                                                                   R
# parameters                                           DEPH VGHS VEMH VGTA VDIR
# netcdf                                               BS_TS_MO_99001_201603.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           99001
# wmo_platform_code
# institution_edmo_code                                                     681
# last_latitude_observation                                                45.1
# last_longitude_observation                                               36.4
# last_date_observation                                    2018-06-30T18:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          1626  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       45.1
# geospatial_lat_max                                                       45.1
# geospatial_lon_min                                                       36.4
# geospatial_lon_max                                                       36.4
# time_coverage_start                                      2016-04-01T06:00:00Z
# time_coverage_end                                        2016-04-30T18:00:00Z
# institution                 All-Russia Research Institute of Hydrometeorol...
# date_update                                              2021-02-01T18:13:07Z
# data_mode                                                                   R
# parameters                                           DEPH VGHS VEMH VGTA VDIR
# netcdf                                               BS_TS_MO_99001_201604.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           99001
# wmo_platform_code
# institution_edmo_code                                                     681
# last_latitude_observation                                                45.1
# last_longitude_observation                                               36.4
# last_date_observation                                    2018-06-30T18:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          1627  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       45.1
# geospatial_lat_max                                                       45.1
# geospatial_lon_min                                                       36.4
# geospatial_lon_max                                                       36.4
# time_coverage_start                                      2016-05-01T06:00:00Z
# time_coverage_end                                        2016-05-31T18:00:00Z
# institution                 All-Russia Research Institute of Hydrometeorol...
# date_update                                              2021-02-01T18:13:17Z
# data_mode                                                                   R
# parameters                                           DEPH VGHS VEMH VGTA VDIR
# netcdf                                               BS_TS_MO_99001_201605.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           99001
# wmo_platform_code
# institution_edmo_code                                                     681
# last_latitude_observation                                                45.1
# last_longitude_observation                                               36.4
# last_date_observation                                    2018-06-30T18:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          1628  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       45.1
# geospatial_lat_max                                                       45.1
# geospatial_lon_min                                                       36.4
# geospatial_lon_max                                                       36.4
# time_coverage_start                                      2016-06-01T06:00:00Z
# time_coverage_end                                        2016-06-30T18:00:00Z
# institution                 All-Russia Research Institute of Hydrometeorol...
# date_update                                              2021-02-01T18:13:28Z
# data_mode                                                                   R
# parameters                                           DEPH VGHS VEMH VGTA VDIR
# netcdf                                               BS_TS_MO_99001_201606.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           99001
# wmo_platform_code
# institution_edmo_code                                                     681
# last_latitude_observation                                                45.1
# last_longitude_observation                                               36.4
# last_date_observation                                    2018-06-30T18:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          1629  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       45.1
# geospatial_lat_max                                                       45.1
# geospatial_lon_min                                                       36.4
# geospatial_lon_max                                                       36.4
# time_coverage_start                                      2016-07-01T06:00:00Z
# time_coverage_end                                        2016-07-31T18:00:00Z
# institution                 All-Russia Research Institute of Hydrometeorol...
# date_update                                              2021-02-01T18:13:38Z
# data_mode                                                                   R
# parameters                                           DEPH VGHS VEMH VGTA VDIR
# netcdf                                               BS_TS_MO_99001_201607.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           99001
# wmo_platform_code
# institution_edmo_code                                                     681
# last_latitude_observation                                                45.1
# last_longitude_observation                                               36.4
# last_date_observation                                    2018-06-30T18:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          1630  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       45.1
# geospatial_lat_max                                                       45.1
# geospatial_lon_min                                                       36.4
# geospatial_lon_max                                                       36.4
# time_coverage_start                                      2016-08-01T06:00:00Z
# time_coverage_end                                        2016-08-31T18:00:00Z
# institution                 All-Russia Research Institute of Hydrometeorol...
# date_update                                              2021-02-01T18:13:49Z
# data_mode                                                                   R
# parameters                                           DEPH VGHS VEMH VGTA VDIR
# netcdf                                               BS_TS_MO_99001_201608.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           99001
# wmo_platform_code
# institution_edmo_code                                                     681
# last_latitude_observation                                                45.1
# last_longitude_observation                                               36.4
# last_date_observation                                    2018-06-30T18:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          1631  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       45.1
# geospatial_lat_max                                                       45.1
# geospatial_lon_min                                                       36.4
# geospatial_lon_max                                                       36.4
# time_coverage_start                                      2016-09-01T06:00:00Z
# time_coverage_end                                        2016-09-30T06:00:00Z
# institution                 All-Russia Research Institute of Hydrometeorol...
# date_update                                              2021-02-01T18:13:59Z
# data_mode                                                                   R
# parameters                                           DEPH VGHS VEMH VGTA VDIR
# netcdf                                               BS_TS_MO_99001_201609.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           99001
# wmo_platform_code
# institution_edmo_code                                                     681
# last_latitude_observation                                                45.1
# last_longitude_observation                                               36.4
# last_date_observation                                    2018-06-30T18:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          1632  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       45.1
# geospatial_lat_max                                                       45.1
# geospatial_lon_min                                                       36.4
# geospatial_lon_max                                                       36.4
# time_coverage_start                                      2017-01-01T06:00:00Z
# time_coverage_end                                        2017-01-31T06:00:00Z
# institution                 All-Russia Research Institute of Hydrometeorol...
# date_update                                              2021-02-01T18:14:31Z
# data_mode                                                                   R
# parameters                                           DEPH VGHS VEMH VGTA VDIR
# netcdf                                               BS_TS_MO_99001_201701.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           99001
# wmo_platform_code
# institution_edmo_code                                                     681
# last_latitude_observation                                                45.1
# last_longitude_observation                                               36.4
# last_date_observation                                    2018-06-30T18:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
# spatialOverlap              ...
# lastLocationInRange         ...
#
#                                                                          3257  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     45.450
# geospatial_lat_max                                                     46.670
# geospatial_lon_min                                                     34.930
# geospatial_lon_max                                                     37.950
# time_coverage_start                                      1952-06-03T08:00:00Z
# time_coverage_end                                        1953-07-24T08:06:00Z
# institution                                               Unknown institution
# date_update                                              2020-01-26T19:06:32Z
# data_mode                                                                   R
# parameters                                 DEPH TEMP PSAL DOX1 PHPH SLCA PHOS
# netcdf                                                   GL_PR_CT_EXOC1458.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        EXOC1458
# wmo_platform_code
# institution_edmo_code
# last_latitude_observation                                              45.455
# last_longitude_observation                                             37.413
# last_date_observation                                    1953-07-24T08:06:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          3260  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.37
# geospatial_lat_max                                                      47.18
# geospatial_lon_min                                                      36.00
# geospatial_lon_max                                                      39.25
# time_coverage_start                                      1989-04-13T23:58:48Z
# time_coverage_end                                        1995-10-08T12:04:12Z
# institution                                               Unknown institution
# date_update                                              2020-01-26T19:12:32Z
# data_mode                                                                   R
# parameters                                           DEPH TEMP DOX1 PSAL PHPH
# netcdf                                                   GL_PR_CT_EXOC1551.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        EXOC1551
# wmo_platform_code
# institution_edmo_code
# last_latitude_observation                                               46.72
# last_longitude_observation                                              38.27
# last_date_observation                                    1995-10-08T12:04:12Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          3262  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      46.12
# geospatial_lat_max                                                      47.17
# geospatial_lon_min                                                      35.37
# geospatial_lon_max                                                      38.96
# time_coverage_start                                      1955-07-07T09:34:48Z
# time_coverage_end                                        1955-10-23T10:10:12Z
# institution                                               Unknown institution
# date_update                                              2020-01-26T19:17:39Z
# data_mode                                                                   R
# parameters                            DEPH PHOS ALK3 PHPH TEMP SLCA DOX1 PSAL
# netcdf                                                   GL_PR_CT_EXOC1614.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        EXOC1614
# wmo_platform_code
# institution_edmo_code
# last_latitude_observation                                               46.98
# last_longitude_observation                                              37.57
# last_date_observation                                    1955-10-23T10:10:12Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          3264  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      41.65
# geospatial_lat_max                                                      46.97
# geospatial_lon_min                                                      36.55
# geospatial_lon_max                                                      41.67
# time_coverage_start                                      1965-11-20T06:00:00Z
# time_coverage_end                                        1973-10-12T07:00:00Z
# institution                                               Unknown institution
# date_update                                              2020-01-26T19:19:10Z
# data_mode                                                                   R
# parameters                            DEPH ALK3 DOX1 PHPH TEMP SLCA PSAL PHOS
# netcdf                                                   GL_PR_CT_EXOC1649.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        EXOC1649
# wmo_platform_code
# institution_edmo_code
# last_latitude_observation                                               45.37
# last_longitude_observation                                              36.72
# last_date_observation                                    1973-10-12T07:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          3268  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    46.6663
# geospatial_lat_max                                                    47.2716
# geospatial_lon_min                                                    37.3330
# geospatial_lon_max                                                    39.3050
# time_coverage_start                                      2003-05-13T08:40:48Z
# time_coverage_end                                        2006-12-17T07:46:12Z
# institution                                               Unknown institution
# date_update                                              2020-01-27T11:42:54Z
# data_mode                                                                   R
# parameters                            DEPH PRES TEMP PSAL DOX1 PHPH NTRA PHOS
# netcdf                                                    GL_PR_CT_OCL0393.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                         OCL0393
# wmo_platform_code                                                     OCL0393
# institution_edmo_code
# last_latitude_observation                                             47.0888
# last_longitude_observation                                            39.2504
# last_date_observation                                    2006-12-17T07:46:12Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          3269  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    45.1410
# geospatial_lat_max                                                    47.0380
# geospatial_lon_min                                                    35.6320
# geospatial_lon_max                                                    38.8670
# time_coverage_start                                      2002-06-20T04:52:12Z
# time_coverage_end                                        2002-06-23T16:37:12Z
# institution                                               Unknown institution
# date_update                                              2020-01-27T11:42:54Z
# data_mode                                                                   R
# parameters                                                     DEPH TEMP PSAL
# netcdf                                                    GL_PR_CT_OCL0394.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                         OCL0394
# wmo_platform_code                                                     OCL0394
# institution_edmo_code
# last_latitude_observation                                             46.8218
# last_longitude_observation                                            37.5423
# last_date_observation                                    2002-06-23T16:37:12Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          3270  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    45.7020
# geospatial_lat_max                                                    47.0674
# geospatial_lon_min                                                    36.4751
# geospatial_lon_max                                                    38.8562
# time_coverage_start                                      2006-06-17T00:00:00Z
# time_coverage_end                                        2006-07-01T05:19:48Z
# institution                                               Unknown institution
# date_update                                              2020-01-27T11:42:54Z
# data_mode                                                                   R
# parameters                            DEPH PRES PSAL TEMP DOX1 PHPH NTRA PHOS
# netcdf                                                    GL_PR_CT_OCL0395.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                         OCL0395
# wmo_platform_code                                                     OCL0395
# institution_edmo_code
# last_latitude_observation                                             46.2585
# last_longitude_observation                                            37.6398
# last_date_observation                                    2006-07-01T05:19:48Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          3271  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     45.007
# geospatial_lat_max                                                     47.127
# geospatial_lon_min                                                     36.489
# geospatial_lon_max                                                     39.345
# time_coverage_start                                      2001-06-29T12:30:00Z
# time_coverage_end                                        2001-07-04T14:01:12Z
# institution                                               Unknown institution
# date_update                                              2020-01-27T11:42:54Z
# data_mode                                                                   R
# parameters                                                     DEPH TEMP PSAL
# netcdf                                                    GL_PR_CT_OCL0396.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                         OCL0396
# wmo_platform_code                                                     OCL0396
# institution_edmo_code
# last_latitude_observation                                              47.127
# last_longitude_observation                                             39.345
# last_date_observation                                    2001-07-04T14:01:12Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          3281  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     45.450
# geospatial_lat_max                                                     46.620
# geospatial_lon_min                                                     35.780
# geospatial_lon_max                                                     37.758
# time_coverage_start                                      1959-07-23T18:25:12Z
# time_coverage_end                                        1959-08-25T10:42:00Z
# institution                                               Unknown institution
# date_update                                              2020-01-27T18:20:41Z
# data_mode                                                                   R
# parameters                                 DEPH DOX1 NTRA SLCA TEMP PHOS PSAL
# netcdf                                                       GL_PR_CT_UILZ.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            UILZ
# wmo_platform_code                                                        UILZ
# institution_edmo_code
# last_latitude_observation                                              45.450
# last_longitude_observation                                             36.700
# last_date_observation                                    1959-08-25T10:42:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          3297
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       45.4
# geospatial_lat_max                                                       45.4
# geospatial_lon_min                                                       36.5
# geospatial_lon_max                                                       36.5
# time_coverage_start                                      1984-01-01T09:00:00Z
# time_coverage_end                                        1986-12-31T09:00:00Z
# institution                 All-Russia Research Institute of Hydrometeorol...
# date_update                                              2021-01-06T12:52:33Z
# data_mode                                                                   D
# parameters                                           DEPH VGHS VEMH VGTA VDIR
# netcdf                                                      BS_TS_MO_99041.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           99041
# wmo_platform_code
# institution_edmo_code                                                     681
# last_latitude_observation                                                45.4
# last_longitude_observation                                               36.5
# last_date_observation                                    1986-12-31T09:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
# [24 rows x 163 columns]

# %% [markdown]
# Let's check now if the bbox of the above files truely overlaps with the targeted area!: `run the next cells`

# %%
numberOfFiles = 177 #we will check just a sample of files not all

# %%
m = folium.Map(location=[39.3, 0], zoom_start=5)
m.add_child(folium.vector_layers.Polygon(locations=edges_))
for platform, files in subset[:numberOfFiles].groupby(['platform_code', 'data_type']):
    color = "%06x" % random.randint(0, 0xFFFFFF)
    #Last reported position to map as marker
    i = len(files)-1
    m.add_child(folium.Marker([files.iloc[i]['last_latitude_observation'], files.iloc[i]['last_longitude_observation']], popup=files.iloc[i]['platform_code']+' last position' ))
#Zooming closer
m.fit_bounds(edges, max_zoom=5)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e2c3c16b63a042139d450c7f44a97b29%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e2c3c16b63a042139d450c7f44a97b29%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e2c3c16b63a042139d450c7f44a97b29%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e2c3c16b63a042139d450c7f44a97b29%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.3%2C%200.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# If you do not see any map when running the next cell please change your navigator (try chrome!).
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if everything went well, just check if the markers (last platform position) is indeed within the one you were interested in (targeted bbox)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>IMPORTANT</b>
#
# ***
# If you are not satisfied with the resulting output please revisit the [definition of the lastLocationInRange](#LocationInRange) function and replace the rule applied (`contains`) by any of the available ones [here](https://shapely.readthedocs.io/en/stable/manual.html#binary-predicates)
# </div>

# %% [markdown]
# #### 4.1.5. By data type

# %% [markdown]
# Let's look for files produced by a certain data type.<br>`Please set a data type` next `and run the cell`:

# %%
targeted_data_type = 'PF' # try others: TG for Tide Gauges, PF for profilers etc =>Product User Manual: https://archimer.ifremer.fr/doc/00324/43494/

# %% [markdown]
# `Run the next cell` to obtain just the files reported by such data type:

# %%
condition = info['data_type'] == targeted_data_type
subset = info[condition]
subset.transpose()
# Out:
#                                                                          1146  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   41.53158
# geospatial_lat_max                                                   41.53158
# geospatial_lon_min                                                   31.00612
# geospatial_lon_max                                                   31.00612
# time_coverage_start                                      2021-01-13T05:15:20Z
# time_coverage_end                                        2021-01-13T05:15:20Z
# institution                 Institute of Oceanology Bulgarian Academy of S...
# date_update                                              2021-01-13T09:04:14Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# netcdf                                           GL_PR_PF_7900595_20210113.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900595
# wmo_platform_code                                                     7900595
# institution_edmo_code                                                    1843
# last_latitude_observation                                            41.63867
# last_longitude_observation                                           31.25180
# last_date_observation                                    2021-02-12T05:55:20Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          1147  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   41.54839
# geospatial_lat_max                                                   41.54839
# geospatial_lon_min                                                   31.06703
# geospatial_lon_max                                                   31.06703
# time_coverage_start                                      2021-01-23T05:53:20Z
# time_coverage_end                                        2021-01-23T05:53:20Z
# institution                 Institute of Oceanology Bulgarian Academy of S...
# date_update                                              2021-01-23T09:02:37Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# netcdf                                           GL_PR_PF_7900595_20210123.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900595
# wmo_platform_code                                                     7900595
# institution_edmo_code                                                    1843
# last_latitude_observation                                            41.63867
# last_longitude_observation                                           31.25180
# last_date_observation                                    2021-02-12T05:55:20Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          1148  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   41.54230
# geospatial_lat_max                                                   41.54230
# geospatial_lon_min                                                   31.10671
# geospatial_lon_max                                                   31.10671
# time_coverage_start                                      2021-02-02T06:00:20Z
# time_coverage_end                                        2021-02-02T06:00:20Z
# institution                 Institute of Oceanology Bulgarian Academy of S...
# date_update                                              2021-02-02T09:02:35Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# netcdf                                           GL_PR_PF_7900595_20210202.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900595
# wmo_platform_code                                                     7900595
# institution_edmo_code                                                    1843
# last_latitude_observation                                            41.63867
# last_longitude_observation                                           31.25180
# last_date_observation                                    2021-02-12T05:55:20Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          1149  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   43.12584
# geospatial_lat_max                                                   43.16163
# geospatial_lon_min                                                   28.99784
# geospatial_lon_max                                                   29.14848
# time_coverage_start                                      2019-08-10T11:52:00Z
# time_coverage_end                                        2019-08-22T06:05:20Z
# institution                 Institute of Oceanology Bulgarian Academy of S...
# date_update                                              2020-08-30T14:24:40Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# netcdf                                             GL_PR_PF_7900595_201908.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900595
# wmo_platform_code                                                     7900595
# institution_edmo_code                                                    1843
# last_latitude_observation                                            41.63867
# last_longitude_observation                                           31.25180
# last_date_observation                                    2021-02-12T05:55:20Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          1150  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   42.78776
# geospatial_lat_max                                                   42.85567
# geospatial_lon_min                                                   28.74693
# geospatial_lon_max                                                   28.86196
# time_coverage_start                                      2019-09-01T05:55:20Z
# time_coverage_end                                        2019-09-21T06:05:20Z
# institution                 Institute of Oceanology Bulgarian Academy of S...
# date_update                                              2020-08-30T14:25:17Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# netcdf                                             GL_PR_PF_7900595_201909.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900595
# wmo_platform_code                                                     7900595
# institution_edmo_code                                                    1843
# last_latitude_observation                                            41.63867
# last_longitude_observation                                           31.25180
# last_date_observation                                    2021-02-12T05:55:20Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          1151  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   42.66157
# geospatial_lat_max                                                   42.74062
# geospatial_lon_min                                                   28.58523
# geospatial_lon_max                                                   28.70844
# time_coverage_start                                      2019-10-01T06:00:20Z
# time_coverage_end                                        2019-10-31T04:57:20Z
# institution                 Institute of Oceanology Bulgarian Academy of S...
# date_update                                              2020-08-30T14:25:17Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# netcdf                                             GL_PR_PF_7900595_201910.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900595
# wmo_platform_code                                                     7900595
# institution_edmo_code                                                    1843
# last_latitude_observation                                            41.63867
# last_longitude_observation                                           31.25180
# last_date_observation                                    2021-02-12T05:55:20Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          1152  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   42.57828
# geospatial_lat_max                                                   42.68038
# geospatial_lon_min                                                   28.56046
# geospatial_lon_max                                                   28.60200
# time_coverage_start                                      2019-11-10T05:53:20Z
# time_coverage_end                                        2019-11-30T05:44:20Z
# institution                 Institute of Oceanology Bulgarian Academy of S...
# date_update                                              2020-08-30T14:25:19Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# netcdf                                             GL_PR_PF_7900595_201911.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900595
# wmo_platform_code                                                     7900595
# institution_edmo_code                                                    1843
# last_latitude_observation                                            41.63867
# last_longitude_observation                                           31.25180
# last_date_observation                                    2021-02-12T05:55:20Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          1153  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   42.16962
# geospatial_lat_max                                                   42.36724
# geospatial_lon_min                                                   28.70539
# geospatial_lon_max                                                   28.79420
# time_coverage_start                                      2019-12-10T05:00:20Z
# time_coverage_end                                        2019-12-30T06:03:20Z
# institution                 Institute of Oceanology Bulgarian Academy of S...
# date_update                                              2020-08-30T14:25:18Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# netcdf                                             GL_PR_PF_7900595_201912.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900595
# wmo_platform_code                                                     7900595
# institution_edmo_code                                                    1843
# last_latitude_observation                                            41.63867
# last_longitude_observation                                           31.25180
# last_date_observation                                    2021-02-12T05:55:20Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          1154  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   41.87564
# geospatial_lat_max                                                   42.02903
# geospatial_lon_min                                                   28.80593
# geospatial_lon_max                                                   29.01579
# time_coverage_start                                      2020-01-09T05:44:20Z
# time_coverage_end                                        2020-01-29T05:55:20Z
# institution                 Institute of Oceanology Bulgarian Academy of S...
# date_update                                              2020-08-30T14:25:18Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# netcdf                                             GL_PR_PF_7900595_202001.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900595
# wmo_platform_code                                                     7900595
# institution_edmo_code                                                    1843
# last_latitude_observation                                            41.63867
# last_longitude_observation                                           31.25180
# last_date_observation                                    2021-02-12T05:55:20Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          1155  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   41.61606
# geospatial_lat_max                                                   41.66728
# geospatial_lon_min                                                   29.01589
# geospatial_lon_max                                                   29.11678
# time_coverage_start                                      2020-02-08T05:04:20Z
# time_coverage_end                                        2020-02-28T05:58:20Z
# institution                 Institute of Oceanology Bulgarian Academy of S...
# date_update                                              2020-08-30T14:25:18Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# netcdf                                             GL_PR_PF_7900595_202002.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900595
# wmo_platform_code                                                     7900595
# institution_edmo_code                                                    1843
# last_latitude_observation                                            41.63867
# last_longitude_observation                                           31.25180
# last_date_observation                                    2021-02-12T05:55:20Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
# spatialOverlap              ...
# lastLocationInRange         ...
#
#                                                                          3307  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   41.48616
# geospatial_lat_max                                                   42.03287
# geospatial_lon_min                                                   29.42788
# geospatial_lon_max                                                   33.11721
# time_coverage_start                                      2014-05-02T11:54:00Z
# time_coverage_end                                        2014-11-10T18:27:00Z
# institution                 Institute of Marine Sciences Middle East Techn...
# date_update                                              2020-08-03T04:55:35Z
# data_mode                                                                   D
# parameters                  PRES TEMP PSAL DOX2 PRES_ADJUSTED PRES_ADJUSTE...
# netcdf                                                    GL_PR_PF_6901899.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901899
# wmo_platform_code                                                     6901899
# institution_edmo_code                                                     696
# last_latitude_observation                                            42.02821
# last_longitude_observation                                           33.11225
# last_date_observation                                    2014-11-10T18:27:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          3308  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.214
# geospatial_lat_max                                                     43.466
# geospatial_lon_min                                                     28.554
# geospatial_lon_max                                                     41.421
# time_coverage_start                                      2012-06-08T12:55:00Z
# time_coverage_end                                        2015-04-21T06:48:00Z
# institution                 OGS Istituto Nazionale di Oceanografia e di Ge...
# date_update                                              2019-12-22T19:39:18Z
# data_mode                                                                   D
# parameters                  PRES TEMP PSAL PRES_ADJUSTED PRES_ADJUSTED_ERR...
# netcdf                                                    GL_PR_PF_6901959.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901959
# wmo_platform_code                                                     6901959
# institution_edmo_code                                                     120
# last_latitude_observation                                              43.271
# last_longitude_observation                                             40.021
# last_date_observation                                    2015-04-21T06:48:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          3309  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     42.093
# geospatial_lat_max                                                     43.216
# geospatial_lon_min                                                     27.821
# geospatial_lon_max                                                     29.638
# time_coverage_start                                      2012-06-09T11:45:00Z
# time_coverage_end                                        2012-10-14T06:15:00Z
# institution                 OGS Istituto Nazionale di Oceanografia e di Ge...
# date_update                                              2019-05-07T22:55:39Z
# data_mode                                                                   D
# parameters                  PRES TEMP PSAL PRES_ADJUSTED PRES_ADJUSTED_ERR...
# netcdf                                                    GL_PR_PF_6901960.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901960
# wmo_platform_code                                                     6901960
# institution_edmo_code                                                     120
# last_latitude_observation                                              42.263
# last_longitude_observation                                             27.821
# last_date_observation                                    2012-10-09T06:27:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          3310  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.269
# geospatial_lat_max                                                     44.829
# geospatial_lon_min                                                     29.028
# geospatial_lon_max                                                     40.889
# time_coverage_start                                      2012-11-06T22:50:00Z
# time_coverage_end                                        2015-09-19T06:57:00Z
# institution                 OGS Istituto Nazionale di Oceanografia e di Ge...
# date_update                                              2020-02-23T18:37:33Z
# data_mode                                                                   D
# parameters                  PRES TEMP PSAL PRES_ADJUSTED PRES_ADJUSTED_ERR...
# netcdf                                                    GL_PR_PF_6901961.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901961
# wmo_platform_code                                                     6901961
# institution_edmo_code                                                     120
# last_latitude_observation                                              42.166
# last_longitude_observation                                             39.798
# last_date_observation                                    2015-09-19T06:57:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          3311  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.024
# geospatial_lat_max                                                     44.738
# geospatial_lon_min                                                     28.409
# geospatial_lon_max                                                     41.492
# time_coverage_start                                      2012-08-17T05:34:00Z
# time_coverage_end                                        2015-07-20T06:41:00Z
# institution                 OGS Istituto Nazionale di Oceanografia e di Ge...
# date_update                                              2020-02-23T18:37:34Z
# data_mode                                                                   D
# parameters                  PRES PSAL_ADJUSTED_ERROR PSAL PRES_ADJUSTED_ER...
# netcdf                                                    GL_PR_PF_6901962.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901962
# wmo_platform_code                                                     6901962
# institution_edmo_code                                                     120
# last_latitude_observation                                              42.776
# last_longitude_observation                                             41.245
# last_date_observation                                    2015-07-20T06:41:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          3312  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   41.37962
# geospatial_lat_max                                                   44.15164
# geospatial_lon_min                                                   30.72870
# geospatial_lon_max                                                   33.39479
# time_coverage_start                                      2009-06-06T08:59:58Z
# time_coverage_end                                        2012-03-07T11:39:34Z
# institution                 Alfred-Wegener-Institute for Polar- and Marine...
# date_update                                              2020-05-17T17:58:57Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# netcdf                                                    GL_PR_PF_7900465.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900465
# wmo_platform_code                                                     7900465
# institution_edmo_code                                                    1368
# last_latitude_observation                                            42.22889
# last_longitude_observation                                           33.39479
# last_date_observation                                    2012-03-07T11:39:34Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          3313  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   41.19950
# geospatial_lat_max                                                   44.40115
# geospatial_lon_min                                                   28.45000
# geospatial_lon_max                                                   36.83396
# time_coverage_start                                      2009-06-06T11:17:29Z
# time_coverage_end                                        2012-11-27T12:22:22Z
# institution                 Helmholtz-Zentrum Geesthacht - Centre for Mate...
# date_update                                              2019-09-28T08:30:39Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# netcdf                                                    GL_PR_PF_7900466.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900466
# wmo_platform_code                                                     7900466
# institution_edmo_code                                                    2842
# last_latitude_observation                                            41.97348
# last_longitude_observation                                           36.83396
# last_date_observation                                    2012-11-27T12:22:22Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          3314  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     40.974
# geospatial_lat_max                                                     42.993
# geospatial_lon_min                                                     28.963
# geospatial_lon_max                                                     41.681
# time_coverage_start                                      2013-08-29T09:14:00Z
# time_coverage_end                                        2015-07-02T06:29:00Z
# institution                 Institute of Oceanology Bulgarian Academy of S...
# date_update                                              2020-02-23T19:14:12Z
# data_mode                                                                   D
# parameters                  PRES TEMP PSAL PRES_ADJUSTED PRES_ADJUSTED_ERR...
# netcdf                                                    GL_PR_PF_7900590.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900590
# wmo_platform_code                                                     7900590
# institution_edmo_code                                                    1843
# last_latitude_observation                                              41.705
# last_longitude_observation                                             41.681
# last_date_observation                                    2015-07-02T06:29:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          3315  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   41.40882
# geospatial_lat_max                                                   42.33315
# geospatial_lon_min                                                   29.00295
# geospatial_lon_max                                                   36.53380
# time_coverage_start                                      2013-12-15T11:29:00Z
# time_coverage_end                                        2014-10-15T09:05:00Z
# institution                 Institute of Oceanology Bulgarian Academy of S...
# date_update                                              2020-11-24T20:20:58Z
# data_mode                                                                   M
# parameters                  PRES TEMP PSAL DOX2 DOX2_ADJUSTED DOX2_ADJUSTE...
# netcdf                                                    GL_PR_PF_7900592.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900592
# wmo_platform_code                                                     7900592
# institution_edmo_code                                                    1843
# last_latitude_observation                                            41.88728
# last_longitude_observation                                           36.53380
# last_date_observation                                    2014-10-15T09:05:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          3316
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   41.56190
# geospatial_lat_max                                                   42.99394
# geospatial_lon_min                                                   28.58905
# geospatial_lon_max                                                   32.08098
# time_coverage_start                                      2014-06-29T04:39:03Z
# time_coverage_end                                        2015-04-15T04:43:00Z
# institution                 Institute of Oceanology Bulgarian Academy of S...
# date_update                                              2020-11-29T15:04:38Z
# data_mode                                                                   R
# parameters                  PRES TEMP PSAL DOX2 DOX2_ADJUSTED DOX2_ADJUSTE...
# netcdf                                                    GL_PR_PF_7900593.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900593
# wmo_platform_code                                                     7900593
# institution_edmo_code                                                    1843
# last_latitude_observation                                            41.72407
# last_longitude_observation                                           32.08098
# last_date_observation                                    2015-04-15T04:43:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
# [24 rows x 787 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the subset only contains the aimed data type (targeted_data_type) just check the `data_type` column of the above output.
# </div>

# %% [markdown]
# #### 4.1.6. By file type

# %% [markdown]
# Let's look for certain types of files.<br>`Please set a file type` next `and run the cell`:

# %%
targeted_file_type = 'TS' # try others: TS for Time Series...=>Product User Manual: https://archimer.ifremer.fr/doc/00324/43494/

# %% [markdown]
# `Run the next cell` to obtain just the above type of files:

# %%
condition = info['file_type'] == targeted_file_type
subset = info[condition]
subset.transpose()
# Out:
#                                                                          0     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-13T06:00:00Z
# time_coverage_end                                        2021-01-13T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:00Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210113.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          1     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-14T06:00:00Z
# time_coverage_end                                        2021-01-14T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:09Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210114.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          2     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-15T12:00:00Z
# time_coverage_end                                        2021-01-15T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:17Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210115.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          3     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-16T06:00:00Z
# time_coverage_end                                        2021-01-16T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:24Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210116.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          4     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-17T06:00:00Z
# time_coverage_end                                        2021-01-17T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:32Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210117.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          5     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-18T06:00:00Z
# time_coverage_end                                        2021-01-18T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:40Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210118.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          6     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-19T06:00:00Z
# time_coverage_end                                        2021-01-19T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:48Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210119.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          7     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-20T06:00:00Z
# time_coverage_end                                        2021-01-20T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:29:56Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210120.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          8     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-21T06:00:00Z
# time_coverage_end                                        2021-01-21T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:30:04Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210121.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          9     \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.15
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.67
# geospatial_lon_max                                                      29.67
# time_coverage_start                                      2021-01-22T06:00:00Z
# time_coverage_end                                        2021-01-22T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-02-12T07:30:11Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                             BS_TS_MO_15360_20210122.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
# spatialOverlap              ...
# lastLocationInRange         ...
#
#                                                                          3050  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    42.5069
# geospatial_lat_max                                                    42.5071
# geospatial_lon_min                                                    27.6349
# geospatial_lon_max                                                    27.6349
# time_coverage_start                                      2020-12-01T00:24:01Z
# time_coverage_end                                        2020-12-30T17:06:55Z
# institution                 Institute of Oceanology Bulgarian Academy of S...
# date_update                                              2021-02-01T18:23:39Z
# data_mode                                                                   R
# parameters                       DEPH TEMP VHM0 VTPK VMDR VPED VPSP WSPD WDIR
# netcdf                                            BS_TS_MO_SPOT0776_202012.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                        SPOT0776
# wmo_platform_code
# institution_edmo_code                                                    1843
# last_latitude_observation                                             42.5071
# last_longitude_observation                                            27.6350
# last_date_observation                                    2020-12-30T17:06:55Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          3288  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.127
# geospatial_lat_max                                                     44.368
# geospatial_lon_min                                                     28.452
# geospatial_lon_max                                                     30.828
# time_coverage_start                                      2005-01-31T15:00:00Z
# time_coverage_end                                        2005-10-15T11:10:00Z
# institution                                               Unknown institution
# date_update                                              2019-05-06T19:07:07Z
# data_mode                                                                   R
# parameters                                           DEPH TEMP ATMP ATPT ATMS
# netcdf                                                      GL_TS_DB_61557.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                           61557
# wmo_platform_code                                                       61557
# institution_edmo_code
# last_latitude_observation                                              41.127
# last_longitude_observation                                             29.100
# last_date_observation                                    2005-09-19T13:40:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          3289  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.698
# geospatial_lat_max                                                     42.628
# geospatial_lon_min                                                     31.470
# geospatial_lon_max                                                     36.218
# time_coverage_start                                      2008-09-20T12:40:00Z
# time_coverage_end                                        2008-10-28T18:00:00Z
# institution                                               Unknown institution
# date_update                                              2019-05-06T19:08:19Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_TS_DB_61664.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                           61664
# wmo_platform_code                                                       61664
# institution_edmo_code
# last_latitude_observation                                              41.883
# last_longitude_observation                                             35.283
# last_date_observation                                    2008-10-28T18:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          3290  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     42.379
# geospatial_lat_max                                                     43.277
# geospatial_lon_min                                                     32.800
# geospatial_lon_max                                                     33.472
# time_coverage_start                                      2008-09-05T13:00:00Z
# time_coverage_end                                        2008-09-29T18:10:00Z
# institution                                               Unknown institution
# date_update                                              2019-05-06T19:08:19Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_TS_DB_61666.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                           61666
# wmo_platform_code                                                       61666
# institution_edmo_code
# last_latitude_observation                                              42.386
# last_longitude_observation                                             33.472
# last_date_observation                                    2008-09-29T18:10:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          3291  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.375
# geospatial_lat_max                                                     43.192
# geospatial_lon_min                                                     29.320
# geospatial_lon_max                                                     34.907
# time_coverage_start                                      2008-09-21T11:40:00Z
# time_coverage_end                                        2008-11-06T18:30:00Z
# institution                                               Unknown institution
# date_update                                              2020-04-26T16:11:19Z
# data_mode                                                                   R
# parameters                                                          DEPH TEMP
# netcdf                                                      GL_TS_DB_61670.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                           61670
# wmo_platform_code                                                       61670
# institution_edmo_code
# last_latitude_observation                                              43.153
# last_longitude_observation                                             34.903
# last_date_observation                                    2008-11-06T18:30:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          3292  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.331
# geospatial_lat_max                                                     44.401
# geospatial_lon_min                                                     28.675
# geospatial_lon_max                                                     40.219
# time_coverage_start                                      2005-01-31T15:00:00Z
# time_coverage_end                                        2005-08-31T13:00:00Z
# institution                                               Unknown institution
# date_update                                              2019-05-06T19:09:36Z
# data_mode                                                                   R
# parameters                                           DEPH TEMP ATMP ATPT ATMS
# netcdf                                                      GL_TS_DB_61767.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                           61767
# wmo_platform_code                                                       61767
# institution_edmo_code
# last_latitude_observation                                              43.566
# last_longitude_observation                                             34.486
# last_date_observation                                    2005-08-31T13:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          3293  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     44.024
# geospatial_lat_max                                                     44.870
# geospatial_lon_min                                                     28.664
# geospatial_lon_max                                                     30.826
# time_coverage_start                                      2005-04-12T09:10:00Z
# time_coverage_end                                        2005-09-09T13:25:00Z
# institution                                               Unknown institution
# date_update                                              2019-05-06T19:09:34Z
# data_mode                                                                   R
# parameters                                           DEPH TEMP ATMP ATPT ATMS
# netcdf                                                      GL_TS_DB_61768.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                           61768
# wmo_platform_code                                                       61768
# institution_edmo_code
# last_latitude_observation                                              44.202
# last_longitude_observation                                             28.675
# last_date_observation                                    2005-09-09T13:17:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          3295  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.100
# geospatial_lat_max                                                     43.335
# geospatial_lon_min                                                     28.382
# geospatial_lon_max                                                     32.330
# time_coverage_start                                      2005-04-12T10:10:00Z
# time_coverage_end                                        2005-10-07T15:20:00Z
# institution                                               Unknown institution
# date_update                                              2020-04-26T16:11:20Z
# data_mode                                                                   R
# parameters                                           DEPH TEMP ATMP ATPT ATMS
# netcdf                                                      GL_TS_DB_61769.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                           61769
# wmo_platform_code                                                       61769
# institution_edmo_code
# last_latitude_observation                                              41.707
# last_longitude_observation                                             32.227
# last_date_observation                                    2005-09-29T04:20:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          3297  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       45.4
# geospatial_lat_max                                                       45.4
# geospatial_lon_min                                                       36.5
# geospatial_lon_max                                                       36.5
# time_coverage_start                                      1984-01-01T09:00:00Z
# time_coverage_end                                        1986-12-31T09:00:00Z
# institution                 All-Russia Research Institute of Hydrometeorol...
# date_update                                              2021-01-06T12:52:33Z
# data_mode                                                                   D
# parameters                                           DEPH VGHS VEMH VGTA VDIR
# netcdf                                                      BS_TS_MO_99041.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           99041
# wmo_platform_code
# institution_edmo_code                                                     681
# last_latitude_observation                                                45.4
# last_longitude_observation                                               36.5
# last_date_observation                                    1986-12-31T09:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          3317
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     44.416
# geospatial_lat_max                                                     44.416
# geospatial_lon_min                                                     34.050
# geospatial_lon_max                                                     34.050
# time_coverage_start                                      2010-12-05T00:00:00Z
# time_coverage_end                                        2012-03-22T13:00:00Z
# institution                          Marine Hydrophysical Institute (Ukraine)
# date_update                                              2021-01-06T12:52:46Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                                   BS_TS_TG_Kaciveli.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                        Kaciveli
# wmo_platform_code
# institution_edmo_code                                                     727
# last_latitude_observation                                              44.416
# last_longitude_observation                                             34.050
# last_date_observation                                    2012-03-22T13:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
# [24 rows x 2271 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the subset matches the aimed file type (targeted_file_type) just check the `file_type` column of the above output.
# </div>

# %% [markdown]
# #### 4.1.7. By parameter

# %% [markdown]
# Let's look for files containing a certain parameter.<br>`Please set a parameter code` next `and run the cell`:

# %%
targeted_parameter = 'PSAL' #try others: TEMP, SLEV etc => In Situ parameter list: https://archimer.ifremer.fr/doc/00422/53381/

# %% [markdown]
# Run the next cell to obtain just the files reporting such parameter:

# %%
condition = info['parameters'].str.contains(targeted_parameter)
subset = info[condition]
subset.transpose()
# Out:
#                                                                          514   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     44.318
# geospatial_lat_max                                                     44.318
# geospatial_lon_min                                                     30.417
# geospatial_lon_max                                                     30.417
# time_coverage_start                                      2021-01-13T00:00:00Z
# time_coverage_end                                        2021-01-13T23:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-02-12T07:29:04Z
# data_mode                                                                   R
# parameters                  DEPH TEMP PSAL FLU2 OSAT DOXY TUR4 HCDT HCSP R...
# netcdf                                           BS_TS_MO_EUXRo02_20210113.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                         EUXRo02
# wmo_platform_code
# institution_edmo_code                                                     850
# last_latitude_observation                                              44.318
# last_longitude_observation                                             30.417
# last_date_observation                                    2021-01-25T11:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          515   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     44.318
# geospatial_lat_max                                                     44.318
# geospatial_lon_min                                                     30.417
# geospatial_lon_max                                                     30.417
# time_coverage_start                                      2021-01-14T00:00:00Z
# time_coverage_end                                        2021-01-14T23:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-02-12T07:29:12Z
# data_mode                                                                   R
# parameters                  DEPH TEMP PSAL FLU2 OSAT DOXY TUR4 HCDT HCSP R...
# netcdf                                           BS_TS_MO_EUXRo02_20210114.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                         EUXRo02
# wmo_platform_code
# institution_edmo_code                                                     850
# last_latitude_observation                                              44.318
# last_longitude_observation                                             30.417
# last_date_observation                                    2021-01-25T11:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          516   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     44.318
# geospatial_lat_max                                                     44.318
# geospatial_lon_min                                                     30.417
# geospatial_lon_max                                                     30.417
# time_coverage_start                                      2021-01-15T00:00:00Z
# time_coverage_end                                        2021-01-15T23:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-02-12T07:29:19Z
# data_mode                                                                   R
# parameters                  DEPH TEMP PSAL FLU2 OSAT DOXY TUR4 HCDT HCSP R...
# netcdf                                           BS_TS_MO_EUXRo02_20210115.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                         EUXRo02
# wmo_platform_code
# institution_edmo_code                                                     850
# last_latitude_observation                                              44.318
# last_longitude_observation                                             30.417
# last_date_observation                                    2021-01-25T11:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          517   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     44.318
# geospatial_lat_max                                                     44.318
# geospatial_lon_min                                                     30.417
# geospatial_lon_max                                                     30.417
# time_coverage_start                                      2021-01-16T00:00:00Z
# time_coverage_end                                        2021-01-16T23:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-02-12T07:29:27Z
# data_mode                                                                   R
# parameters                  DEPH TEMP PSAL FLU2 OSAT DOXY TUR4 HCDT HCSP R...
# netcdf                                           BS_TS_MO_EUXRo02_20210116.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                         EUXRo02
# wmo_platform_code
# institution_edmo_code                                                     850
# last_latitude_observation                                              44.318
# last_longitude_observation                                             30.417
# last_date_observation                                    2021-01-25T11:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          518   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     44.318
# geospatial_lat_max                                                     44.318
# geospatial_lon_min                                                     30.417
# geospatial_lon_max                                                     30.417
# time_coverage_start                                      2021-01-17T00:00:00Z
# time_coverage_end                                        2021-01-17T23:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-02-12T07:29:35Z
# data_mode                                                                   R
# parameters                  DEPH TEMP PSAL FLU2 OSAT DOXY TUR4 HCDT HCSP R...
# netcdf                                           BS_TS_MO_EUXRo02_20210117.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                         EUXRo02
# wmo_platform_code
# institution_edmo_code                                                     850
# last_latitude_observation                                              44.318
# last_longitude_observation                                             30.417
# last_date_observation                                    2021-01-25T11:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          519   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     44.318
# geospatial_lat_max                                                     44.318
# geospatial_lon_min                                                     30.417
# geospatial_lon_max                                                     30.417
# time_coverage_start                                      2021-01-18T00:00:00Z
# time_coverage_end                                        2021-01-18T23:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-02-12T07:29:43Z
# data_mode                                                                   R
# parameters                  DEPH TEMP PSAL FLU2 OSAT DOXY TUR4 HCDT HCSP R...
# netcdf                                           BS_TS_MO_EUXRo02_20210118.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                         EUXRo02
# wmo_platform_code
# institution_edmo_code                                                     850
# last_latitude_observation                                              44.318
# last_longitude_observation                                             30.417
# last_date_observation                                    2021-01-25T11:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          520   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     44.318
# geospatial_lat_max                                                     44.318
# geospatial_lon_min                                                     30.417
# geospatial_lon_max                                                     30.417
# time_coverage_start                                      2021-01-19T00:00:00Z
# time_coverage_end                                        2021-01-19T23:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-02-12T07:29:51Z
# data_mode                                                                   R
# parameters                  DEPH TEMP PSAL FLU2 OSAT DOXY TUR4 HCDT HCSP R...
# netcdf                                           BS_TS_MO_EUXRo02_20210119.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                         EUXRo02
# wmo_platform_code
# institution_edmo_code                                                     850
# last_latitude_observation                                              44.318
# last_longitude_observation                                             30.417
# last_date_observation                                    2021-01-25T11:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          521   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     44.318
# geospatial_lat_max                                                     44.318
# geospatial_lon_min                                                     30.417
# geospatial_lon_max                                                     30.417
# time_coverage_start                                      2021-01-20T00:00:00Z
# time_coverage_end                                        2021-01-20T23:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-02-12T07:29:59Z
# data_mode                                                                   R
# parameters                  DEPH TEMP PSAL FLU2 OSAT DOXY TUR4 HCDT HCSP R...
# netcdf                                           BS_TS_MO_EUXRo02_20210120.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                         EUXRo02
# wmo_platform_code
# institution_edmo_code                                                     850
# last_latitude_observation                                              44.318
# last_longitude_observation                                             30.417
# last_date_observation                                    2021-01-25T11:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          522   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     44.318
# geospatial_lat_max                                                     44.318
# geospatial_lon_min                                                     30.417
# geospatial_lon_max                                                     30.417
# time_coverage_start                                      2021-01-21T00:00:00Z
# time_coverage_end                                        2021-01-21T23:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-02-12T07:30:06Z
# data_mode                                                                   R
# parameters                  DEPH TEMP PSAL FLU2 OSAT DOXY TUR4 HCDT HCSP R...
# netcdf                                           BS_TS_MO_EUXRo02_20210121.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                         EUXRo02
# wmo_platform_code
# institution_edmo_code                                                     850
# last_latitude_observation                                              44.318
# last_longitude_observation                                             30.417
# last_date_observation                                    2021-01-25T11:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          523   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     44.318
# geospatial_lat_max                                                     44.318
# geospatial_lon_min                                                     30.417
# geospatial_lon_max                                                     30.417
# time_coverage_start                                      2021-01-22T00:00:00Z
# time_coverage_end                                        2021-01-22T23:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-02-12T07:30:13Z
# data_mode                                                                   R
# parameters                  DEPH TEMP PSAL FLU2 OSAT DOXY TUR4 HCDT HCSP R...
# netcdf                                           BS_TS_MO_EUXRo02_20210122.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                         EUXRo02
# wmo_platform_code
# institution_edmo_code                                                     850
# last_latitude_observation                                              44.318
# last_longitude_observation                                             30.417
# last_date_observation                                    2021-01-25T11:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
# spatialOverlap              ...
# lastLocationInRange         ...
#
#                                                                          3307  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   41.48616
# geospatial_lat_max                                                   42.03287
# geospatial_lon_min                                                   29.42788
# geospatial_lon_max                                                   33.11721
# time_coverage_start                                      2014-05-02T11:54:00Z
# time_coverage_end                                        2014-11-10T18:27:00Z
# institution                 Institute of Marine Sciences Middle East Techn...
# date_update                                              2020-08-03T04:55:35Z
# data_mode                                                                   D
# parameters                  PRES TEMP PSAL DOX2 PRES_ADJUSTED PRES_ADJUSTE...
# netcdf                                                    GL_PR_PF_6901899.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901899
# wmo_platform_code                                                     6901899
# institution_edmo_code                                                     696
# last_latitude_observation                                            42.02821
# last_longitude_observation                                           33.11225
# last_date_observation                                    2014-11-10T18:27:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          3308  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.214
# geospatial_lat_max                                                     43.466
# geospatial_lon_min                                                     28.554
# geospatial_lon_max                                                     41.421
# time_coverage_start                                      2012-06-08T12:55:00Z
# time_coverage_end                                        2015-04-21T06:48:00Z
# institution                 OGS Istituto Nazionale di Oceanografia e di Ge...
# date_update                                              2019-12-22T19:39:18Z
# data_mode                                                                   D
# parameters                  PRES TEMP PSAL PRES_ADJUSTED PRES_ADJUSTED_ERR...
# netcdf                                                    GL_PR_PF_6901959.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901959
# wmo_platform_code                                                     6901959
# institution_edmo_code                                                     120
# last_latitude_observation                                              43.271
# last_longitude_observation                                             40.021
# last_date_observation                                    2015-04-21T06:48:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          3309  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     42.093
# geospatial_lat_max                                                     43.216
# geospatial_lon_min                                                     27.821
# geospatial_lon_max                                                     29.638
# time_coverage_start                                      2012-06-09T11:45:00Z
# time_coverage_end                                        2012-10-14T06:15:00Z
# institution                 OGS Istituto Nazionale di Oceanografia e di Ge...
# date_update                                              2019-05-07T22:55:39Z
# data_mode                                                                   D
# parameters                  PRES TEMP PSAL PRES_ADJUSTED PRES_ADJUSTED_ERR...
# netcdf                                                    GL_PR_PF_6901960.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901960
# wmo_platform_code                                                     6901960
# institution_edmo_code                                                     120
# last_latitude_observation                                              42.263
# last_longitude_observation                                             27.821
# last_date_observation                                    2012-10-09T06:27:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          3310  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.269
# geospatial_lat_max                                                     44.829
# geospatial_lon_min                                                     29.028
# geospatial_lon_max                                                     40.889
# time_coverage_start                                      2012-11-06T22:50:00Z
# time_coverage_end                                        2015-09-19T06:57:00Z
# institution                 OGS Istituto Nazionale di Oceanografia e di Ge...
# date_update                                              2020-02-23T18:37:33Z
# data_mode                                                                   D
# parameters                  PRES TEMP PSAL PRES_ADJUSTED PRES_ADJUSTED_ERR...
# netcdf                                                    GL_PR_PF_6901961.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901961
# wmo_platform_code                                                     6901961
# institution_edmo_code                                                     120
# last_latitude_observation                                              42.166
# last_longitude_observation                                             39.798
# last_date_observation                                    2015-09-19T06:57:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          3311  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     41.024
# geospatial_lat_max                                                     44.738
# geospatial_lon_min                                                     28.409
# geospatial_lon_max                                                     41.492
# time_coverage_start                                      2012-08-17T05:34:00Z
# time_coverage_end                                        2015-07-20T06:41:00Z
# institution                 OGS Istituto Nazionale di Oceanografia e di Ge...
# date_update                                              2020-02-23T18:37:34Z
# data_mode                                                                   D
# parameters                  PRES PSAL_ADJUSTED_ERROR PSAL PRES_ADJUSTED_ER...
# netcdf                                                    GL_PR_PF_6901962.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6901962
# wmo_platform_code                                                     6901962
# institution_edmo_code                                                     120
# last_latitude_observation                                              42.776
# last_longitude_observation                                             41.245
# last_date_observation                                    2015-07-20T06:41:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          3312  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   41.37962
# geospatial_lat_max                                                   44.15164
# geospatial_lon_min                                                   30.72870
# geospatial_lon_max                                                   33.39479
# time_coverage_start                                      2009-06-06T08:59:58Z
# time_coverage_end                                        2012-03-07T11:39:34Z
# institution                 Alfred-Wegener-Institute for Polar- and Marine...
# date_update                                              2020-05-17T17:58:57Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# netcdf                                                    GL_PR_PF_7900465.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900465
# wmo_platform_code                                                     7900465
# institution_edmo_code                                                    1368
# last_latitude_observation                                            42.22889
# last_longitude_observation                                           33.39479
# last_date_observation                                    2012-03-07T11:39:34Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          3313  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   41.19950
# geospatial_lat_max                                                   44.40115
# geospatial_lon_min                                                   28.45000
# geospatial_lon_max                                                   36.83396
# time_coverage_start                                      2009-06-06T11:17:29Z
# time_coverage_end                                        2012-11-27T12:22:22Z
# institution                 Helmholtz-Zentrum Geesthacht - Centre for Mate...
# date_update                                              2019-09-28T08:30:39Z
# data_mode                                                                   R
# parameters                                                     PRES TEMP PSAL
# netcdf                                                    GL_PR_PF_7900466.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900466
# wmo_platform_code                                                     7900466
# institution_edmo_code                                                    2842
# last_latitude_observation                                            41.97348
# last_longitude_observation                                           36.83396
# last_date_observation                                    2012-11-27T12:22:22Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          3314  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     40.974
# geospatial_lat_max                                                     42.993
# geospatial_lon_min                                                     28.963
# geospatial_lon_max                                                     41.681
# time_coverage_start                                      2013-08-29T09:14:00Z
# time_coverage_end                                        2015-07-02T06:29:00Z
# institution                 Institute of Oceanology Bulgarian Academy of S...
# date_update                                              2020-02-23T19:14:12Z
# data_mode                                                                   D
# parameters                  PRES TEMP PSAL PRES_ADJUSTED PRES_ADJUSTED_ERR...
# netcdf                                                    GL_PR_PF_7900590.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900590
# wmo_platform_code                                                     7900590
# institution_edmo_code                                                    1843
# last_latitude_observation                                              41.705
# last_longitude_observation                                             41.681
# last_date_observation                                    2015-07-02T06:29:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          3315  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   41.40882
# geospatial_lat_max                                                   42.33315
# geospatial_lon_min                                                   29.00295
# geospatial_lon_max                                                   36.53380
# time_coverage_start                                      2013-12-15T11:29:00Z
# time_coverage_end                                        2014-10-15T09:05:00Z
# institution                 Institute of Oceanology Bulgarian Academy of S...
# date_update                                              2020-11-24T20:20:58Z
# data_mode                                                                   M
# parameters                  PRES TEMP PSAL DOX2 DOX2_ADJUSTED DOX2_ADJUSTE...
# netcdf                                                    GL_PR_PF_7900592.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900592
# wmo_platform_code                                                     7900592
# institution_edmo_code                                                    1843
# last_latitude_observation                                            41.88728
# last_longitude_observation                                           36.53380
# last_date_observation                                    2014-10-15T09:05:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          3316
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   41.56190
# geospatial_lat_max                                                   42.99394
# geospatial_lon_min                                                   28.58905
# geospatial_lon_max                                                   32.08098
# time_coverage_start                                      2014-06-29T04:39:03Z
# time_coverage_end                                        2015-04-15T04:43:00Z
# institution                 Institute of Oceanology Bulgarian Academy of S...
# date_update                                              2020-11-29T15:04:38Z
# data_mode                                                                   R
# parameters                  PRES TEMP PSAL DOX2 DOX2_ADJUSTED DOX2_ADJUSTE...
# netcdf                                                    GL_PR_PF_7900593.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         7900593
# wmo_platform_code                                                     7900593
# institution_edmo_code                                                    1843
# last_latitude_observation                                            41.72407
# last_longitude_observation                                           32.08098
# last_date_observation                                    2015-04-15T04:43:00Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
# [24 rows x 1322 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the subset only contains the aimed parameter (targeted_parameter) just check the `parameters` column of the above output.
# </div>

# %% [markdown]
# #### 4.1.8. By platform code

# %% [markdown]
# Let's look for files produced by a certain platform.<br>`Please set a platform code` next `and run the cell`:

# %%
targeted_platform_code = 'Constanta'

# %% [markdown]
# Run the next cell to obtain just the files reported by such platform:

# %%
condition = info['platform_code']==targeted_platform_code
subset = info[condition]
subset.transpose()
# Out:
#                                                                          1903  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    44.1475
# geospatial_lat_max                                                    44.1475
# geospatial_lon_min                                                    28.5952
# geospatial_lon_max                                                    28.5952
# time_coverage_start                                      2016-01-01T00:00:00Z
# time_coverage_end                                        2016-01-31T23:00:00Z
# institution                 National Institute for Marine Research and Dev...
# date_update                                              2021-02-01T18:12:41Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                           BS_TS_TG_Constanta_201601.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                       Constanta
# wmo_platform_code
# institution_edmo_code                                                     697
# last_latitude_observation                                             44.1475
# last_longitude_observation                                            28.5952
# last_date_observation                                    2020-06-30T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          1904  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    44.1475
# geospatial_lat_max                                                    44.1475
# geospatial_lon_min                                                    28.5952
# geospatial_lon_max                                                    28.5952
# time_coverage_start                                      2016-02-01T00:00:00Z
# time_coverage_end                                        2016-02-29T23:00:00Z
# institution                 National Institute for Marine Research and Dev...
# date_update                                              2021-02-01T18:12:50Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                           BS_TS_TG_Constanta_201602.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                       Constanta
# wmo_platform_code
# institution_edmo_code                                                     697
# last_latitude_observation                                             44.1475
# last_longitude_observation                                            28.5952
# last_date_observation                                    2020-06-30T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          1905  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    44.1475
# geospatial_lat_max                                                    44.1475
# geospatial_lon_min                                                    28.5952
# geospatial_lon_max                                                    28.5952
# time_coverage_start                                      2016-03-01T00:00:00Z
# time_coverage_end                                        2016-03-31T23:00:00Z
# institution                 National Institute for Marine Research and Dev...
# date_update                                              2021-02-01T18:13:01Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                           BS_TS_TG_Constanta_201603.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                       Constanta
# wmo_platform_code
# institution_edmo_code                                                     697
# last_latitude_observation                                             44.1475
# last_longitude_observation                                            28.5952
# last_date_observation                                    2020-06-30T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          1906  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    44.1475
# geospatial_lat_max                                                    44.1475
# geospatial_lon_min                                                    28.5952
# geospatial_lon_max                                                    28.5952
# time_coverage_start                                      2016-04-01T00:00:00Z
# time_coverage_end                                        2016-04-30T23:00:00Z
# institution                 National Institute for Marine Research and Dev...
# date_update                                              2021-02-01T18:13:11Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                           BS_TS_TG_Constanta_201604.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                       Constanta
# wmo_platform_code
# institution_edmo_code                                                     697
# last_latitude_observation                                             44.1475
# last_longitude_observation                                            28.5952
# last_date_observation                                    2020-06-30T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          1907  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    44.1475
# geospatial_lat_max                                                    44.1475
# geospatial_lon_min                                                    28.5952
# geospatial_lon_max                                                    28.5952
# time_coverage_start                                      2016-05-01T00:00:00Z
# time_coverage_end                                        2016-05-31T23:00:00Z
# institution                 National Institute for Marine Research and Dev...
# date_update                                              2021-02-01T18:13:22Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                           BS_TS_TG_Constanta_201605.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                       Constanta
# wmo_platform_code
# institution_edmo_code                                                     697
# last_latitude_observation                                             44.1475
# last_longitude_observation                                            28.5952
# last_date_observation                                    2020-06-30T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          1908  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    44.1475
# geospatial_lat_max                                                    44.1475
# geospatial_lon_min                                                    28.5952
# geospatial_lon_max                                                    28.5952
# time_coverage_start                                      2016-06-01T00:00:00Z
# time_coverage_end                                        2016-06-30T23:00:00Z
# institution                 National Institute for Marine Research and Dev...
# date_update                                              2021-02-01T18:13:32Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                           BS_TS_TG_Constanta_201606.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                       Constanta
# wmo_platform_code
# institution_edmo_code                                                     697
# last_latitude_observation                                             44.1475
# last_longitude_observation                                            28.5952
# last_date_observation                                    2020-06-30T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          1909  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    44.1475
# geospatial_lat_max                                                    44.1475
# geospatial_lon_min                                                    28.5952
# geospatial_lon_max                                                    28.5952
# time_coverage_start                                      2016-07-01T00:00:00Z
# time_coverage_end                                        2016-07-31T23:00:00Z
# institution                 National Institute for Marine Research and Dev...
# date_update                                              2021-02-01T18:13:43Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                           BS_TS_TG_Constanta_201607.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                       Constanta
# wmo_platform_code
# institution_edmo_code                                                     697
# last_latitude_observation                                             44.1475
# last_longitude_observation                                            28.5952
# last_date_observation                                    2020-06-30T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          1910  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    44.1475
# geospatial_lat_max                                                    44.1475
# geospatial_lon_min                                                    28.5952
# geospatial_lon_max                                                    28.5952
# time_coverage_start                                      2016-08-01T00:00:00Z
# time_coverage_end                                        2016-08-31T23:00:00Z
# institution                 National Institute for Marine Research and Dev...
# date_update                                              2021-02-01T18:13:53Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                           BS_TS_TG_Constanta_201608.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                       Constanta
# wmo_platform_code
# institution_edmo_code                                                     697
# last_latitude_observation                                             44.1475
# last_longitude_observation                                            28.5952
# last_date_observation                                    2020-06-30T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          1911  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    44.1475
# geospatial_lat_max                                                    44.1475
# geospatial_lon_min                                                    28.5952
# geospatial_lon_max                                                    28.5952
# time_coverage_start                                      2016-09-01T00:00:00Z
# time_coverage_end                                        2016-09-30T23:00:00Z
# institution                 National Institute for Marine Research and Dev...
# date_update                                              2021-02-01T18:14:03Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                           BS_TS_TG_Constanta_201609.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                       Constanta
# wmo_platform_code
# institution_edmo_code                                                     697
# last_latitude_observation                                             44.1475
# last_longitude_observation                                            28.5952
# last_date_observation                                    2020-06-30T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          1912  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    44.1475
# geospatial_lat_max                                                    44.1475
# geospatial_lon_min                                                    28.5952
# geospatial_lon_max                                                    28.5952
# time_coverage_start                                      2016-10-01T00:00:00Z
# time_coverage_end                                        2016-10-31T23:00:00Z
# institution                 National Institute for Marine Research and Dev...
# date_update                                              2021-02-01T18:14:12Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                           BS_TS_TG_Constanta_201610.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                       Constanta
# wmo_platform_code
# institution_edmo_code                                                     697
# last_latitude_observation                                             44.1475
# last_longitude_observation                                            28.5952
# last_date_observation                                    2020-06-30T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
# spatialOverlap              ...
# lastLocationInRange         ...
#
#                                                                          1946  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    44.1475
# geospatial_lat_max                                                    44.1475
# geospatial_lon_min                                                    28.5952
# geospatial_lon_max                                                    28.5952
# time_coverage_start                                      2019-10-01T00:00:00Z
# time_coverage_end                                        2019-10-31T23:00:00Z
# institution                 National Institute for Marine Research and Dev...
# date_update                                              2021-02-01T18:21:24Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                           BS_TS_TG_Constanta_201910.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                       Constanta
# wmo_platform_code
# institution_edmo_code                                                     697
# last_latitude_observation                                             44.1475
# last_longitude_observation                                            28.5952
# last_date_observation                                    2020-06-30T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          1947  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    44.1475
# geospatial_lat_max                                                    44.1475
# geospatial_lon_min                                                    28.5952
# geospatial_lon_max                                                    28.5952
# time_coverage_start                                      2019-11-01T00:00:00Z
# time_coverage_end                                        2019-11-30T23:00:00Z
# institution                 National Institute for Marine Research and Dev...
# date_update                                              2021-02-01T18:21:34Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                           BS_TS_TG_Constanta_201911.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                       Constanta
# wmo_platform_code
# institution_edmo_code                                                     697
# last_latitude_observation                                             44.1475
# last_longitude_observation                                            28.5952
# last_date_observation                                    2020-06-30T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          1948  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    44.1475
# geospatial_lat_max                                                    44.1475
# geospatial_lon_min                                                    28.5952
# geospatial_lon_max                                                    28.5952
# time_coverage_start                                      2019-12-01T00:00:00Z
# time_coverage_end                                        2019-12-30T05:00:00Z
# institution                 National Institute for Marine Research and Dev...
# date_update                                              2021-02-01T18:21:44Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                           BS_TS_TG_Constanta_201912.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                       Constanta
# wmo_platform_code
# institution_edmo_code                                                     697
# last_latitude_observation                                             44.1475
# last_longitude_observation                                            28.5952
# last_date_observation                                    2020-06-30T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          1949  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    44.1475
# geospatial_lat_max                                                    44.1475
# geospatial_lon_min                                                    28.5952
# geospatial_lon_max                                                    28.5952
# time_coverage_start                                      2020-01-06T05:00:00Z
# time_coverage_end                                        2020-01-31T23:00:00Z
# institution                 National Institute for Marine Research and Dev...
# date_update                                              2021-02-01T18:21:54Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                           BS_TS_TG_Constanta_202001.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                       Constanta
# wmo_platform_code
# institution_edmo_code                                                     697
# last_latitude_observation                                             44.1475
# last_longitude_observation                                            28.5952
# last_date_observation                                    2020-06-30T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          1950  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    44.1475
# geospatial_lat_max                                                    44.1475
# geospatial_lon_min                                                    28.5952
# geospatial_lon_max                                                    28.5952
# time_coverage_start                                      2020-02-01T00:00:00Z
# time_coverage_end                                        2020-02-29T23:00:00Z
# institution                 National Institute for Marine Research and Dev...
# date_update                                              2021-02-01T18:22:04Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                           BS_TS_TG_Constanta_202002.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                       Constanta
# wmo_platform_code
# institution_edmo_code                                                     697
# last_latitude_observation                                             44.1475
# last_longitude_observation                                            28.5952
# last_date_observation                                    2020-06-30T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          1951  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    44.1475
# geospatial_lat_max                                                    44.1475
# geospatial_lon_min                                                    28.5952
# geospatial_lon_max                                                    28.5952
# time_coverage_start                                      2020-03-01T00:00:00Z
# time_coverage_end                                        2020-03-31T23:00:00Z
# institution                 National Institute for Marine Research and Dev...
# date_update                                              2021-02-01T18:22:13Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                           BS_TS_TG_Constanta_202003.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                       Constanta
# wmo_platform_code
# institution_edmo_code                                                     697
# last_latitude_observation                                             44.1475
# last_longitude_observation                                            28.5952
# last_date_observation                                    2020-06-30T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          1952  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    44.1475
# geospatial_lat_max                                                    44.1475
# geospatial_lon_min                                                    28.5952
# geospatial_lon_max                                                    28.5952
# time_coverage_start                                      2020-04-01T00:00:00Z
# time_coverage_end                                        2020-04-30T23:00:00Z
# institution                 National Institute for Marine Research and Dev...
# date_update                                              2021-02-01T18:22:23Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                           BS_TS_TG_Constanta_202004.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                       Constanta
# wmo_platform_code
# institution_edmo_code                                                     697
# last_latitude_observation                                             44.1475
# last_longitude_observation                                            28.5952
# last_date_observation                                    2020-06-30T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          1953  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    44.1475
# geospatial_lat_max                                                    44.1475
# geospatial_lon_min                                                    28.5952
# geospatial_lon_max                                                    28.5952
# time_coverage_start                                      2020-05-01T00:00:00Z
# time_coverage_end                                        2020-05-31T00:00:00Z
# institution                 National Institute for Marine Research and Dev...
# date_update                                              2021-02-01T18:22:33Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                           BS_TS_TG_Constanta_202005.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                       Constanta
# wmo_platform_code
# institution_edmo_code                                                     697
# last_latitude_observation                                             44.1475
# last_longitude_observation                                            28.5952
# last_date_observation                                    2020-06-30T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          1954  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    44.1475
# geospatial_lat_max                                                    44.1475
# geospatial_lon_min                                                    28.5952
# geospatial_lon_max                                                    28.5952
# time_coverage_start                                      2020-06-01T00:00:00Z
# time_coverage_end                                        2020-06-30T23:00:00Z
# institution                 National Institute for Marine Research and Dev...
# date_update                                              2021-02-01T18:22:40Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                           BS_TS_TG_Constanta_202006.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                       Constanta
# wmo_platform_code
# institution_edmo_code                                                     697
# last_latitude_observation                                             44.1475
# last_longitude_observation                                            28.5952
# last_date_observation                                    2020-06-30T23:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          1955
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    44.1600
# geospatial_lat_max                                                    44.1600
# geospatial_lon_min                                                    28.6000
# geospatial_lon_max                                                    28.6000
# time_coverage_start                                      2015-01-01T00:00:00Z
# time_coverage_end                                        2020-05-31T00:00:00Z
# institution                 National Institute for Marine Research and Dev...
# date_update                                              2021-01-06T12:52:38Z
# data_mode                                                                   R
# parameters                                                          DEPH SLEV
# netcdf                                                  BS_TS_TG_Constanta.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                       Constanta
# wmo_platform_code
# institution_edmo_code                                                     697
# last_latitude_observation                                             44.1475
# last_longitude_observation                                            28.5952
# last_date_observation                                    2020-06-30T23:00:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
# [24 rows x 53 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the subset matches the aimed platform (targeted_platform_code) just check the `platform_code` column of the above output.
# </div>

# %% [markdown]
# #### 4.1.9. By provider

# %% [markdown]
# Let's look for files produced by a certain provider.<br>`Please set a provider code` next `and run the cell`:

# %%
targeted_provider_code = '850'

# %% [markdown]
# Run the next cell to obtain just the files reported by such platform:

# %%
info['institution_edmo_code'] = ' '+info['institution_edmo_code']+' '

# %%
condition = info['institution_edmo_code'].str.contains(targeted_provider_code, na=False)
subset = info[condition]
subset.transpose()
# Out:
#                                                                          483   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    43.8022
# geospatial_lat_max                                                    43.8022
# geospatial_lon_min                                                    28.6055
# geospatial_lon_max                                                    28.6055
# time_coverage_start                                      2021-01-13T08:30:00Z
# time_coverage_end                                        2021-01-14T00:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-02-12T07:29:03Z
# data_mode                                                                   R
# parameters                  DEPH TEMP HCSP EWCT NSCT HCDT ATMS DRYT WSPD WDIR
# netcdf                                                BS_TS_MO_CG_20210113.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                              CG
# wmo_platform_code
# institution_edmo_code                                                    850
# last_latitude_observation                                             43.8022
# last_longitude_observation                                            28.6055
# last_date_observation                                    2021-01-25T11:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          484   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    43.8022
# geospatial_lat_max                                                    43.8022
# geospatial_lon_min                                                    28.6055
# geospatial_lon_max                                                    28.6055
# time_coverage_start                                      2021-01-14T00:15:00Z
# time_coverage_end                                        2021-01-15T00:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-02-12T07:29:11Z
# data_mode                                                                   R
# parameters                  DEPH TEMP HCSP EWCT NSCT HCDT ATMS DRYT WSPD WDIR
# netcdf                                                BS_TS_MO_CG_20210114.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                              CG
# wmo_platform_code
# institution_edmo_code                                                    850
# last_latitude_observation                                             43.8022
# last_longitude_observation                                            28.6055
# last_date_observation                                    2021-01-25T11:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          485   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    43.8022
# geospatial_lat_max                                                    43.8022
# geospatial_lon_min                                                    28.6055
# geospatial_lon_max                                                    28.6055
# time_coverage_start                                      2021-01-15T00:15:00Z
# time_coverage_end                                        2021-01-16T00:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-02-12T07:29:19Z
# data_mode                                                                   R
# parameters                  DEPH TEMP HCSP EWCT NSCT HCDT ATMS DRYT WSPD WDIR
# netcdf                                                BS_TS_MO_CG_20210115.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                              CG
# wmo_platform_code
# institution_edmo_code                                                    850
# last_latitude_observation                                             43.8022
# last_longitude_observation                                            28.6055
# last_date_observation                                    2021-01-25T11:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          486   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    43.8022
# geospatial_lat_max                                                    43.8022
# geospatial_lon_min                                                    28.6055
# geospatial_lon_max                                                    28.6055
# time_coverage_start                                      2021-01-16T00:15:00Z
# time_coverage_end                                        2021-01-17T00:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-02-12T07:29:26Z
# data_mode                                                                   R
# parameters                  DEPH TEMP HCSP EWCT NSCT HCDT ATMS DRYT WSPD WDIR
# netcdf                                                BS_TS_MO_CG_20210116.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                              CG
# wmo_platform_code
# institution_edmo_code                                                    850
# last_latitude_observation                                             43.8022
# last_longitude_observation                                            28.6055
# last_date_observation                                    2021-01-25T11:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          487   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    43.8022
# geospatial_lat_max                                                    43.8022
# geospatial_lon_min                                                    28.6055
# geospatial_lon_max                                                    28.6055
# time_coverage_start                                      2021-01-17T00:15:00Z
# time_coverage_end                                        2021-01-18T00:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-02-12T07:29:34Z
# data_mode                                                                   R
# parameters                  DEPH TEMP HCSP EWCT NSCT HCDT ATMS DRYT WSPD WDIR
# netcdf                                                BS_TS_MO_CG_20210117.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                              CG
# wmo_platform_code
# institution_edmo_code                                                    850
# last_latitude_observation                                             43.8022
# last_longitude_observation                                            28.6055
# last_date_observation                                    2021-01-25T11:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          488   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    43.8022
# geospatial_lat_max                                                    43.8022
# geospatial_lon_min                                                    28.6055
# geospatial_lon_max                                                    28.6055
# time_coverage_start                                      2021-01-18T00:15:00Z
# time_coverage_end                                        2021-01-19T00:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-02-12T07:29:42Z
# data_mode                                                                   R
# parameters                  DEPH TEMP HCSP EWCT NSCT HCDT ATMS DRYT WSPD WDIR
# netcdf                                                BS_TS_MO_CG_20210118.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                              CG
# wmo_platform_code
# institution_edmo_code                                                    850
# last_latitude_observation                                             43.8022
# last_longitude_observation                                            28.6055
# last_date_observation                                    2021-01-25T11:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          489   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    43.8022
# geospatial_lat_max                                                    43.8022
# geospatial_lon_min                                                    28.6055
# geospatial_lon_max                                                    28.6055
# time_coverage_start                                      2021-01-19T00:15:00Z
# time_coverage_end                                        2021-01-20T00:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-02-12T07:29:50Z
# data_mode                                                                   R
# parameters                  DEPH TEMP HCSP EWCT NSCT HCDT ATMS DRYT WSPD WDIR
# netcdf                                                BS_TS_MO_CG_20210119.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                              CG
# wmo_platform_code
# institution_edmo_code                                                    850
# last_latitude_observation                                             43.8022
# last_longitude_observation                                            28.6055
# last_date_observation                                    2021-01-25T11:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          490   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    43.8022
# geospatial_lat_max                                                    43.8022
# geospatial_lon_min                                                    28.6055
# geospatial_lon_max                                                    28.6055
# time_coverage_start                                      2021-01-20T00:15:00Z
# time_coverage_end                                        2021-01-21T00:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-02-12T07:29:58Z
# data_mode                                                                   R
# parameters                  DEPH TEMP HCSP EWCT NSCT HCDT ATMS DRYT WSPD WDIR
# netcdf                                                BS_TS_MO_CG_20210120.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                              CG
# wmo_platform_code
# institution_edmo_code                                                    850
# last_latitude_observation                                             43.8022
# last_longitude_observation                                            28.6055
# last_date_observation                                    2021-01-25T11:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          491   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    43.8022
# geospatial_lat_max                                                    43.8022
# geospatial_lon_min                                                    28.6055
# geospatial_lon_max                                                    28.6055
# time_coverage_start                                      2021-01-21T00:15:00Z
# time_coverage_end                                        2021-01-22T00:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-02-12T07:30:05Z
# data_mode                                                                   R
# parameters                  DEPH TEMP HCSP EWCT NSCT HCDT ATMS DRYT WSPD WDIR
# netcdf                                                BS_TS_MO_CG_20210121.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                              CG
# wmo_platform_code
# institution_edmo_code                                                    850
# last_latitude_observation                                             43.8022
# last_longitude_observation                                            28.6055
# last_date_observation                                    2021-01-25T11:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          492   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    43.8022
# geospatial_lat_max                                                    43.8022
# geospatial_lon_min                                                    28.6055
# geospatial_lon_max                                                    28.6055
# time_coverage_start                                      2021-01-22T00:15:00Z
# time_coverage_end                                        2021-01-23T00:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-02-12T07:30:13Z
# data_mode                                                                   R
# parameters                  DEPH TEMP HCSP EWCT NSCT HCDT ATMS DRYT WSPD WDIR
# netcdf                                                BS_TS_MO_CG_20210122.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                              CG
# wmo_platform_code
# institution_edmo_code                                                    850
# last_latitude_observation                                             43.8022
# last_longitude_observation                                            28.6055
# last_date_observation                                    2021-01-25T11:00:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
# spatialOverlap              ...
# lastLocationInRange         ...
#
#                                                                          2007  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   44.46815
# geospatial_lat_max                                                   44.71711
# geospatial_lon_min                                                   34.85083
# geospatial_lon_max                                                   36.20567
# time_coverage_start                                      2018-02-02T22:13:00Z
# time_coverage_end                                        2018-02-28T23:09:00Z
# institution                 National Research and Development Institute fo...
# date_update                                              2020-08-07T12:27:07Z
# data_mode                                                                   M
# parameters                  PRES PSAL TEMP DOX2_ADJUSTED_ERROR DOX2 DOX2_A...
# netcdf                                             GL_PR_PF_6900807_201802.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6900807
# wmo_platform_code                                                     6900807
# institution_edmo_code                                                    850
# last_latitude_observation                                            42.96071
# last_longitude_observation                                           32.46556
# last_date_observation                                    2016-06-29T00:25:00Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          2008  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   44.24190
# geospatial_lat_max                                                   44.71745
# geospatial_lon_min                                                   34.01200
# geospatial_lon_max                                                   34.85582
# time_coverage_start                                      2018-03-01T01:00:00Z
# time_coverage_end                                        2018-03-31T01:05:00Z
# institution                 National Research and Development Institute fo...
# date_update                                              2020-08-07T12:27:06Z
# data_mode                                                                   M
# parameters                  PRES PSAL TEMP DOX2 DOX2_ADJUSTED DOX2_ADJUSTE...
# netcdf                                             GL_PR_PF_6900807_201803.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6900807
# wmo_platform_code                                                     6900807
# institution_edmo_code                                                    850
# last_latitude_observation                                            42.96071
# last_longitude_observation                                           32.46556
# last_date_observation                                    2016-06-29T00:25:00Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          2009  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   44.20134
# geospatial_lat_max                                                   44.23203
# geospatial_lon_min                                                   33.67711
# geospatial_lon_max                                                   33.90920
# time_coverage_start                                      2018-04-05T23:09:00Z
# time_coverage_end                                        2018-04-30T00:45:00Z
# institution                 National Research and Development Institute fo...
# date_update                                              2020-08-07T12:27:06Z
# data_mode                                                                   M
# parameters                  PRES PSAL TEMP DOX2 DOX2_ADJUSTED DOX2_ADJUSTE...
# netcdf                                             GL_PR_PF_6900807_201804.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6900807
# wmo_platform_code                                                     6900807
# institution_edmo_code                                                    850
# last_latitude_observation                                            42.96071
# last_longitude_observation                                           32.46556
# last_date_observation                                    2016-06-29T00:25:00Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          2010  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   44.15463
# geospatial_lat_max                                                   44.20901
# geospatial_lon_min                                                   33.38175
# geospatial_lon_max                                                   33.64930
# time_coverage_start                                      2018-05-05T23:09:00Z
# time_coverage_end                                        2018-05-30T00:33:00Z
# institution                 National Research and Development Institute fo...
# date_update                                              2020-08-07T12:27:06Z
# data_mode                                                                   M
# parameters                  PRES PSAL TEMP DOX2 DOX2_ADJUSTED DOX2_ADJUSTE...
# netcdf                                             GL_PR_PF_6900807_201805.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6900807
# wmo_platform_code                                                     6900807
# institution_edmo_code                                                    850
# last_latitude_observation                                            42.96071
# last_longitude_observation                                           32.46556
# last_date_observation                                    2016-06-29T00:25:00Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          2011  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   44.06264
# geospatial_lat_max                                                   44.21351
# geospatial_lon_min                                                   32.21328
# geospatial_lon_max                                                   33.46765
# time_coverage_start                                      2018-06-03T22:44:00Z
# time_coverage_end                                        2018-06-29T00:32:00Z
# institution                 National Research and Development Institute fo...
# date_update                                              2020-08-07T12:27:06Z
# data_mode                                                                   M
# parameters                  PRES PSAL TEMP DOX2_ADJUSTED_ERROR DOX2 DOX2_A...
# netcdf                                             GL_PR_PF_6900807_201806.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6900807
# wmo_platform_code                                                     6900807
# institution_edmo_code                                                    850
# last_latitude_observation                                            42.96071
# last_longitude_observation                                           32.46556
# last_date_observation                                    2016-06-29T00:25:00Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          2012  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   44.25191
# geospatial_lat_max                                                   44.65724
# geospatial_lon_min                                                   31.93450
# geospatial_lon_max                                                   32.30629
# time_coverage_start                                      2018-07-04T22:46:00Z
# time_coverage_end                                        2018-07-27T00:31:00Z
# institution                 National Research and Development Institute fo...
# date_update                                              2020-08-07T12:27:06Z
# data_mode                                                                   M
# parameters                  PRES TEMP PSAL DOX2_ADJUSTED_ERROR DOX2 DOX2_A...
# netcdf                                             GL_PR_PF_6900807_201807.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6900807
# wmo_platform_code                                                     6900807
# institution_edmo_code                                                    850
# last_latitude_observation                                            42.96071
# last_longitude_observation                                           32.46556
# last_date_observation                                    2016-06-29T00:25:00Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          2013  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   43.79445
# geospatial_lat_max                                                   44.27208
# geospatial_lon_min                                                   31.01222
# geospatial_lon_max                                                   31.77948
# time_coverage_start                                      2018-08-01T22:42:00Z
# time_coverage_end                                        2018-08-29T00:23:00Z
# institution                 National Research and Development Institute fo...
# date_update                                              2020-08-07T12:27:07Z
# data_mode                                                                   M
# parameters                  PRES PSAL TEMP DOX2_ADJUSTED_ERROR DOX2 DOX2_A...
# netcdf                                             GL_PR_PF_6900807_201808.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6900807
# wmo_platform_code                                                     6900807
# institution_edmo_code                                                    850
# last_latitude_observation                                            42.96071
# last_longitude_observation                                           32.46556
# last_date_observation                                    2016-06-29T00:25:00Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          2014  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   43.59872
# geospatial_lat_max                                                   43.69978
# geospatial_lon_min                                                   30.58385
# geospatial_lon_max                                                   30.81094
# time_coverage_start                                      2018-09-02T22:47:00Z
# time_coverage_end                                        2018-09-08T22:46:00Z
# institution                 National Research and Development Institute fo...
# date_update                                              2020-08-07T12:27:07Z
# data_mode                                                                   M
# parameters                  PRES PSAL TEMP DOX2_ADJUSTED_ERROR DOX2 DOX2_A...
# netcdf                                             GL_PR_PF_6900807_201809.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6900807
# wmo_platform_code                                                     6900807
# institution_edmo_code                                                    850
# last_latitude_observation                                            42.96071
# last_longitude_observation                                           32.46556
# last_date_observation                                    2016-06-29T00:25:00Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                          2015  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                   41.41943
# geospatial_lat_max                                                   44.71745
# geospatial_lon_min                                                   28.53202
# geospatial_lon_max                                                   39.59654
# time_coverage_start                                      2014-11-28T09:56:00Z
# time_coverage_end                                        2018-09-08T22:46:00Z
# institution                 National Research and Development Institute fo...
# date_update                                              2021-01-10T22:04:26Z
# data_mode                                                                   M
# parameters                  PRES TEMP PSAL DOX2 DOX2_ADJUSTED DOX2_ADJUSTE...
# netcdf                                                    GL_PR_PF_6900807.nc
# file_type                                                                  PR
# data_type                                                                  PF
# platform_code                                                         6900807
# wmo_platform_code                                                     6900807
# institution_edmo_code                                                    850
# last_latitude_observation                                            42.96071
# last_longitude_observation                                           32.46556
# last_date_observation                                    2016-06-29T00:25:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          2757
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    42.5000
# geospatial_lat_max                                                    45.0711
# geospatial_lon_min                                                    27.8333
# geospatial_lon_max                                                    29.7381
# time_coverage_start                                      2017-05-11T01:40:00Z
# time_coverage_end                                        2017-05-25T07:31:00Z
# institution                 GeoEcoMar - National Institute of Marine Geolo...
# date_update                                              2021-02-01T18:24:03Z
# data_mode                                                                   D
# parameters                                                     PRES TEMP PSAL
# netcdf                                                BS_PR_CT_YQPT_201705.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            YQPT
# wmo_platform_code
# institution_edmo_code                                                    850
# last_latitude_observation                                             43.3667
# last_longitude_observation                                            28.5000
# last_date_observation                                    2017-05-25T07:31:00Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
# [24 rows x 268 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the subset matches the aimed provider (targeted_provider_code) just check the `insitution_edmo_code` column of the above output.
# </div>

# %% [markdown]
# #### 4.1.10. Subsetting by several criterias at once

# %% [markdown]
# Set the collection of interest, range of time and bbox to find only the files that matches:

# %%
targeted_collection = 'history'
targeted_range = '2019-01-01T00:00:00Z/2019-12-01T23:59:59Z'
targeted_data_type = 'MO'
targeted_geospatial_lat_min = 40.0  # enter min latitude of your bounding box
targeted_geospatial_lat_max = 48.0  # enter max latitude of your bounding box
targeted_geospatial_lon_min = 28.0  # enter min longitude of your bounding box
targeted_geospatial_lon_max = 43.0  # enter max longitude of your bounding box
targeted_bbox = [targeted_geospatial_lon_min, targeted_geospatial_lat_min, targeted_geospatial_lon_max, targeted_geospatial_lat_max]  # (minx, miny, maxx, maxy)

# %% [markdown]
# Run the next cell to apply yhe above filters:

# %%
info['timeOverlap'] = info.apply(timeOverlap,targeted_range=targeted_range,axis=1)
condition1 = info['timeOverlap'] == True
info['spatialOverlap'] = info.apply(spatialOverlap,targeted_bbox=targeted_bbox,axis=1)
condition2 = info['spatialOverlap'] == True

condition3 = info['data_type'] == targeted_data_type
condition4 = info['file_name'].str.contains(targeted_collection)
subset = info[condition1 & condition2 & condition3 & condition4]
subset.transpose()
# Out:
#                                                                          61    \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      45.20
# geospatial_lat_max                                                      45.15
# geospatial_lon_min                                                      29.70
# geospatial_lon_max                                                      29.70
# time_coverage_start                                      2018-08-16T06:00:00Z
# time_coverage_end                                        2020-08-31T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-01-06T12:52:26Z
# data_mode                                                                   D
# parameters                                                          DEPH TEMP
# netcdf                                                      BS_TS_MO_15360.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15360
# wmo_platform_code                                                       15360
# institution_edmo_code
# last_latitude_observation                                               45.15
# last_longitude_observation                                              29.67
# last_date_observation                                    2021-02-12T06:00:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          117   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      44.70
# geospatial_lat_max                                                      44.68
# geospatial_lon_min                                                      29.00
# geospatial_lon_max                                                      29.00
# time_coverage_start                                      2018-08-17T12:00:00Z
# time_coverage_end                                        2020-08-31T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-01-06T12:52:26Z
# data_mode                                                                   D
# parameters                                                          DEPH TEMP
# netcdf                                                      BS_TS_MO_15428.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15428
# wmo_platform_code                                                       15428
# institution_edmo_code
# last_latitude_observation                                               44.68
# last_longitude_observation                                              28.98
# last_date_observation                                    2021-02-11T12:00:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          179   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      44.20
# geospatial_lat_max                                                      44.22
# geospatial_lon_min                                                      28.60
# geospatial_lon_max                                                      28.60
# time_coverage_start                                      2018-08-16T06:00:00Z
# time_coverage_end                                        2020-04-30T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-01-06T12:52:26Z
# data_mode                                                                   D
# parameters                                                          DEPH TEMP
# netcdf                                                      BS_TS_MO_15480.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15480
# wmo_platform_code                                                       15480
# institution_edmo_code
# last_latitude_observation                                               44.22
# last_longitude_observation                                              28.63
# last_date_observation                                    2021-02-12T06:00:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          235   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      43.80
# geospatial_lat_max                                                      43.80
# geospatial_lon_min                                                      28.60
# geospatial_lon_max                                                      28.60
# time_coverage_start                                      2018-08-16T12:00:00Z
# time_coverage_end                                        2020-08-31T12:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-01-06T12:52:27Z
# data_mode                                                                   D
# parameters                                                          DEPH TEMP
# netcdf                                                      BS_TS_MO_15499.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15499
# wmo_platform_code                                                       15499
# institution_edmo_code
# last_latitude_observation                                               43.80
# last_longitude_observation                                              28.58
# last_date_observation                                    2021-02-11T12:00:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          297   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      43.20
# geospatial_lat_max                                                      43.20
# geospatial_lon_min                                                      28.00
# geospatial_lon_max                                                      28.00
# time_coverage_start                                      2018-08-16T06:00:00Z
# time_coverage_end                                        2020-08-31T18:00:00Z
# institution                 National Institute of Meteorology and Hydrolog...
# date_update                                              2021-01-06T12:52:27Z
# data_mode                                                                   D
# parameters                                                          DEPH TEMP
# netcdf                                                      BS_TS_MO_15552.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           15552
# wmo_platform_code                                                       15552
# institution_edmo_code                                                    961
# last_latitude_observation                                               43.20
# last_longitude_observation                                              27.95
# last_date_observation                                    2021-02-12T06:00:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          585   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     44.318
# geospatial_lat_max                                                     44.318
# geospatial_lon_min                                                     30.417
# geospatial_lon_max                                                     30.417
# time_coverage_start                                      2014-01-01T00:00:00Z
# time_coverage_end                                        2020-05-31T23:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-01-06T12:52:40Z
# data_mode                                                                   D
# parameters                  DEPH TEMP PSAL FLU2 OSAT DOXY TUR4 HCDT HCSP R...
# netcdf                                                    BS_TS_MO_EUXRo02.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                         EUXRo02
# wmo_platform_code
# institution_edmo_code                                                    850
# last_latitude_observation                                              44.318
# last_longitude_observation                                             30.417
# last_date_observation                                    2021-01-25T11:00:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          657   \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     43.980
# geospatial_lat_max                                                     43.980
# geospatial_lon_min                                                     29.936
# geospatial_lon_max                                                     29.936
# time_coverage_start                                      2014-01-01T00:00:00Z
# time_coverage_end                                        2020-05-31T23:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-01-06T12:52:42Z
# data_mode                                                                   D
# parameters                  DEPH TEMP PSAL FLU2 OSAT DOXY TUR4 HCDT HCSP R...
# netcdf                                                    BS_TS_MO_EUXRo03.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                         EUXRo03
# wmo_platform_code
# institution_edmo_code                                                    850
# last_latitude_observation                                              43.980
# last_longitude_observation                                             29.936
# last_date_observation                                    2021-01-25T11:00:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          1145  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                    43.2259
# geospatial_lat_max                                                    43.2238
# geospatial_lon_min                                                    28.0121
# geospatial_lon_max                                                    28.0121
# time_coverage_start                                      2019-07-13T12:09:23Z
# time_coverage_end                                        2020-06-14T03:32:15Z
# institution                                               Unknown institution
# date_update                                              2021-01-06T12:52:53Z
# data_mode                                                                   D
# parameters                                      DEPH VHM0 VZMX VTPK VPED VPSP
# netcdf                                                     BS_TS_MO_WD3044.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                          WD3044
# wmo_platform_code                                                      WD3044
# institution_edmo_code
# last_latitude_observation                                             43.2039
# last_longitude_observation                                            27.9595
# last_date_observation                                    2021-02-12T06:19:02Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          1793  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                     44.700
# geospatial_lat_max                                                     44.700
# geospatial_lon_min                                                     30.779
# geospatial_lon_max                                                     30.779
# time_coverage_start                                      2014-01-01T00:00:00Z
# time_coverage_end                                        2020-05-31T23:00:00Z
# institution                 National Institute of Marine Geology and Geo-e...
# date_update                                              2021-01-06T12:52:39Z
# data_mode                                                                   D
# parameters                  DEPH TEMP PSAL FLU2 OSAT DOXY TUR4 HCDT HCSP R...
# netcdf                                                    BS_TS_MO_EUXRo01.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                         EUXRo01
# wmo_platform_code
# institution_edmo_code                                                    850
# last_latitude_observation                                              44.700
# last_longitude_observation                                             30.779
# last_date_observation                                    2020-12-03T00:00:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          2372  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       46.2
# geospatial_lat_max                                                       46.2
# geospatial_lon_min                                                       30.4
# geospatial_lon_max                                                       30.4
# time_coverage_start                                      2017-01-01T12:00:00Z
# time_coverage_end                                        2019-04-14T18:00:00Z
# institution                 All-Russia Research Institute of Hydrometeorol...
# date_update                                              2021-01-06T12:52:33Z
# data_mode                                                                   D
# parameters                                                     DEPH TEMP DRYT
# netcdf                                                      BS_TS_MO_Anapa.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           Anapa
# wmo_platform_code
# institution_edmo_code
# last_latitude_observation                                                46.2
# last_longitude_observation                                               30.4
# last_date_observation                                    2019-04-14T18:00:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
# spatialOverlap              ...
# lastLocationInRange         ...
#
#                                                                          2456  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       46.1
# geospatial_lat_max                                                       46.1
# geospatial_lon_min                                                       33.3
# geospatial_lon_max                                                       33.3
# time_coverage_start                                      2017-01-01T06:00:00Z
# time_coverage_end                                        2019-04-14T18:00:00Z
# institution                 All-Russia Research Institute of Hydrometeorol...
# date_update                                              2021-01-06T12:52:44Z
# data_mode                                                                   D
# parameters                                                     DEPH TEMP DRYT
# netcdf                                                 BS_TS_MO_Gelendzhik.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                      Gelendzhik
# wmo_platform_code
# institution_edmo_code
# last_latitude_observation                                                46.1
# last_longitude_observation                                               33.3
# last_date_observation                                    2019-04-14T18:00:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          2484  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       45.5
# geospatial_lat_max                                                       44.6
# geospatial_lon_min                                                       29.6
# geospatial_lon_max                                                       29.6
# time_coverage_start                                      2017-01-05T18:00:00Z
# time_coverage_end                                        2019-04-14T18:00:00Z
# institution                 All-Russia Research Institute of Hydrometeorol...
# date_update                                              2021-01-06T12:52:45Z
# data_mode                                                                   D
# parameters                                                     DEPH TEMP DRYT
# netcdf                                                   BS_TS_MO_Hersones.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                        Hersones
# wmo_platform_code
# institution_edmo_code
# last_latitude_observation                                                44.6
# last_longitude_observation                                               33.4
# last_date_observation                                    2019-04-14T18:00:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          2512  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      44.88
# geospatial_lat_max                                                      44.88
# geospatial_lon_min                                                      37.28
# geospatial_lon_max                                                      37.28
# time_coverage_start                                      2017-01-01T06:00:00Z
# time_coverage_end                                        2019-04-14T18:00:00Z
# institution                 All-Russia Research Institute of Hydrometeorol...
# date_update                                              2021-01-06T12:52:45Z
# data_mode                                                                   D
# parameters                                                     DEPH TEMP DRYT
# netcdf                                                      BS_TS_MO_Horly.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           Horly
# wmo_platform_code
# institution_edmo_code
# last_latitude_observation                                               44.88
# last_longitude_observation                                              37.28
# last_date_observation                                    2019-04-14T18:00:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          2540  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       44.6
# geospatial_lat_max                                                       44.6
# geospatial_lon_min                                                       38.1
# geospatial_lon_max                                                       38.1
# time_coverage_start                                      2017-01-01T06:00:00Z
# time_coverage_end                                        2019-04-14T18:00:00Z
# institution                 All-Russia Research Institute of Hydrometeorol...
# date_update                                              2021-01-06T12:52:45Z
# data_mode                                                                   D
# parameters                                                     DEPH TEMP DRYT
# netcdf                                                 BS_TS_MO_Illichevsk.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                      Illichevsk
# wmo_platform_code
# institution_edmo_code
# last_latitude_observation                                                44.6
# last_longitude_observation                                               38.1
# last_date_observation                                    2019-04-14T18:00:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          2568  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      44.72
# geospatial_lat_max                                                      44.72
# geospatial_lon_min                                                      37.77
# geospatial_lon_max                                                      37.77
# time_coverage_start                                      2017-01-01T06:00:00Z
# time_coverage_end                                        2019-04-14T18:00:00Z
# institution                 All-Russia Research Institute of Hydrometeorol...
# date_update                                              2021-01-06T12:52:46Z
# data_mode                                                                   D
# parameters                                                     DEPH TEMP DRYT
# netcdf                                                   BS_TS_MO_Nikolaev.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                        Nikolaev
# wmo_platform_code
# institution_edmo_code
# last_latitude_observation                                               44.72
# last_longitude_observation                                              37.77
# last_date_observation                                    2019-04-14T18:00:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          2596  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      44.10
# geospatial_lat_max                                                      44.10
# geospatial_lon_min                                                      39.08
# geospatial_lon_max                                                      39.08
# time_coverage_start                                      2017-01-01T06:00:00Z
# time_coverage_end                                        2019-04-14T18:00:00Z
# institution                 All-Russia Research Institute of Hydrometeorol...
# date_update                                              2021-01-06T12:52:47Z
# data_mode                                                                   D
# parameters                                                     DEPH TEMP DRYT
# netcdf                                               BS_TS_MO_Novorossiysk.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                    Novorossiysk
# wmo_platform_code
# institution_edmo_code
# last_latitude_observation                                               44.10
# last_longitude_observation                                              39.08
# last_date_observation                                    2019-04-14T18:00:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          2624  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                      43.58
# geospatial_lat_max                                                      43.58
# geospatial_lon_min                                                      39.77
# geospatial_lon_max                                                      39.77
# time_coverage_start                                      2017-01-01T06:00:00Z
# time_coverage_end                                        2019-04-14T18:00:00Z
# institution                 All-Russia Research Institute of Hydrometeorol...
# date_update                                              2021-01-06T12:52:47Z
# data_mode                                                                   D
# parameters                                                     DEPH TEMP DRYT
# netcdf                                                 BS_TS_MO_Odessaport.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                      Odessaport
# wmo_platform_code
# institution_edmo_code
# last_latitude_observation                                               43.58
# last_longitude_observation                                              39.77
# last_date_observation                                    2019-04-14T18:00:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          2652  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       45.5
# geospatial_lat_max                                                       45.5
# geospatial_lon_min                                                       29.6
# geospatial_lon_max                                                       29.6
# time_coverage_start                                      2017-01-01T06:00:00Z
# time_coverage_end                                        2019-04-14T18:00:00Z
# institution                 All-Russia Research Institute of Hydrometeorol...
# date_update                                              2021-01-06T12:52:48Z
# data_mode                                                                   D
# parameters                                                     DEPH TEMP DRYT
# netcdf                                                 BS_TS_MO_Primorskoe.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                      Primorskoe
# wmo_platform_code
# institution_edmo_code
# last_latitude_observation                                                45.5
# last_longitude_observation                                               29.6
# last_date_observation                                    2019-04-14T18:00:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          2680  \
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       46.1
# geospatial_lat_max                                                       46.1
# geospatial_lon_min                                                       30.5
# geospatial_lon_max                                                       30.5
# time_coverage_start                                      2017-01-01T06:00:00Z
# time_coverage_end                                        2019-04-14T18:00:00Z
# institution                 All-Russia Research Institute of Hydrometeorol...
# date_update                                              2021-01-06T12:52:49Z
# data_mode                                                                   D
# parameters                                                     DEPH TEMP DRYT
# netcdf                                                      BS_TS_MO_Sochi.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                           Sochi
# wmo_platform_code
# institution_edmo_code
# last_latitude_observation                                                46.1
# last_longitude_observation                                               30.5
# last_date_observation                                    2019-04-14T18:00:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                          2708
# # product_id                                                  COP-BLACKSEA-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BS_NRT_OBSER...
# geospatial_lat_min                                                       46.9
# geospatial_lat_max                                                       46.9
# geospatial_lon_min                                                       31.9
# geospatial_lon_max                                                       31.9
# time_coverage_start                                      2017-01-05T06:00:00Z
# time_coverage_end                                        2019-04-14T18:00:00Z
# institution                 All-Russia Research Institute of Hydrometeorol...
# date_update                                              2021-01-06T12:52:50Z
# data_mode                                                                   D
# parameters                                                     DEPH TEMP DRYT
# netcdf                                                     BS_TS_MO_Tuapse.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                          Tuapse
# wmo_platform_code
# institution_edmo_code
# last_latitude_observation                                                46.9
# last_longitude_observation                                               31.9
# last_date_observation                                    2019-04-14T18:00:00Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
# [24 rows x 22 columns]

# %% [markdown]
# ### 4.2. Exporting

# %% [markdown]
# If you just want to export the above table containing ftp link to download each file in subset and some more metadata as csv for sharing it (a lot more compact than sharing the actual files), just run the next cell:

# %%
subset.to_csv('subsetOffiles.csv')

# %% [markdown]
# ### 4.3. Downloading

# %% [markdown]
# After you have created your own subset (see above examples about how-to), we will loop over the files in such subset and download each of them from the FTP server thanks to the `file_name` column, field that contains the ftp link to the file.<br> Run the next cells:

# %%
output_directory = os.getcwd()# Defaults to the current working directory; change it as you please

# %%
treshold = 5 #Please set a number maxima for files to download. 
#This is just an example and we do not wanna trigger the download of too many files

# %%
with ftputil.FTPHost(dataset['host'], usr, pas) as ftp_host:  # connect to CMEMS FTP
    for i in range(0, len(subset)):
        if i<treshold:
            filepath = subset.iloc[i]['file_name'].split(dataset['host'])[1]
            ncdf_file_name = filepath.split('/')[-1]
            if ftp_host.path.isfile(filepath):
                print('.....Downloading ' + ncdf_file_name)
                cwd = os.getcwd()
                os.chdir(output_directory)
                try:
                    ftp_host.download(filepath, ncdf_file_name)  # remote, local
                    print('Done!')
                except Exception as e:
                    print('error: FTP download is forbidden in the remote server...')
                os.chdir(cwd)
# Out:
# .....Downloading BS_TS_MO_15360.nc
# Done!
# .....Downloading BS_TS_MO_15428.nc
# Done!
# .....Downloading BS_TS_MO_15480.nc
# Done!
# .....Downloading BS_TS_MO_15499.nc
# Done!
# .....Downloading BS_TS_MO_15552.nc
# Done!

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the files have been donwloaded just check if you find them in the directory specified as <i>output directory</i>.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# FTP download is forbidden in the remote server for security reasons. <br>Please run this jupyter notebook locally for being able to actually download the files. Steps:
# 1. [Install anaconda](https://www.anaconda.com/distribution/): according to your OS (Windows,Linux,Mac...)
# 2. Run the following command at the Terminal (Mac/Linux) or Command Prompt (Windows): jupyter notebook
# </div>

# %% [markdown]
# ---
#
# # 5. Wrap-up
#
# So far you should already know how to subset the product/dataset by several subsetting criterias as well as exporting and downloading the resulting subset of files.<br> `If you don't please ask us! it is the moment!`
# <br>In the next tutorial we will see how to open and visualize some of the files donloaded. Ready? Let's go!

# %% [markdown]
# ---
#
# # 6. Next Tutorial
#
# _Click on one of the hyperlinks below to continue the training_
# <br>
# [**13-03-NearRealTime-product-managing-files-tideGauges.ipynb**](13-03-NearRealTime-product-managing-files-tideGauges.ipynb)<br>
# [**13-04-NearRealTime-product-managing-files-profilers.ipynb**](13-04-NearRealTime-product-managing-files-profilers.ipynb)<br>
# [**13-05-NearRealTime-product-managing-files-thermosal.ipynb**](13-05-NearRealTime-product-managing-files-thermosal.ipynb)<br>
